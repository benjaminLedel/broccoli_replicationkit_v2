# %%
import pandas as pd
import statistics
from autorank import autorank, plot_stats, create_report, latex_table, latex_report

def highlight_last_max(data, colormax='antiquewhite', colormaxlast='lightgreen'):
    colormax_attr = f'background-color: {colormax}'
    colormaxlast_attr = f'background-color: {colormaxlast}'
    max_value = data[:].max()
    is_max = [colormax_attr if v == max_value else '' for v in data]
    is_max[len(data) - list(reversed(data)).index(max_value) -  1] = colormaxlast_attr
    return is_max

def highlight_last_max2(data, colormax='antiquewhite', colormaxlast='lightgreen'):
    colormax_attr = f'background-color: {colormax}'
    colormaxlast_attr = f'background-color: {colormaxlast}'
    max_value = data[3:].max()
    is_max = [colormax_attr if v == max_value else '' for v in data]
    is_max[len(data) - list(reversed(data)).index(max_value) -  1] = colormaxlast_attr
    return is_max


data_mp = pd.read_csv('New_Multiple_MAP.txt',sep='\t')
data_mp["Blizzard"] =pd.Series([0.25329955166029233,
 0.28212555612176854,
 0.2196083801805703,
 0.4276761517615177,
 0.34613570420022016,
 0.36985416152082834,
 0.3306591710758379,
 0.15625,
 0.4404761904761904,
 0.4051932825471786,
 0.3947353231563758,
 0.34211790971649597,
 0.3125,
 0.03346560846560847,
 0.12801573426573426,
 0.03693624844940637,
 0.15298464874736062,
 0.29009648061164506,
 0.22787878787878788,
 0.30259418799022747,
 0.2627865961199294,
 0.27951693058315796,
 0.27953216374269,
 0.24171135316296616,
 0.06858332700437964,
 0.290383077883078,
 0.2451285017664331,
 0.3372113997113997,
 0.25048377898756685,
 0.28064914645103317,
 0.32914862914862913,
 0.21110005534081103,
 0.30032841952666367,
 0.17232800474987972,
 0.3023286951144094,
 0.37767131242741,
 0.20939153439153438,
 0.3022222222222222,
 0.2929629629629629,
 0.3148148148148148,
 0.3625,
 0.24442826794017264,
 0.27749493872628206,
 0.21585862780630227,
 0.11207729468599034,
 0.12808312719027007,
 0.0,
 0.18213345705971096,
 0.15299490919133774,
 0.4166666666666667,
                               0.3399490919133774])
data_mp["Broccoli"] =pd.Series([0.39566784883811845,
 0.430027474053388,
 0.3239035374639752,
 0.7104297448517306,
 0.6082115903790865,
 0.6507149570038221,
 0.6359934307187229,
 0.2772385912698413,
 0.7595238095238095,
 0.7807015509861284,
 0.7241626912958593,
 0.5866982722834633,
 0.47081043956043955,
 0.06600588840083639,
 0.24218499390387438,
 0.5574347653853113,
 0.48669867706178366,
 0.598045330388738,
 0.49616414614124954,
 0.5044225437053604,
 0.13088985417050855,
 0.5791312245115109,
 0.49120410940949544,
 0.6724066118988707,
 0.45822503345141063,
 0.5424761397533103,
 0.5662225946096914,
 0.2971773870861244,
 0.39566763455301546,
 0.5355459611935912,
 0.4686385474398487,
 0.5560667399357125,
 0.5524070832522946,
 0.6179396694904362,
 0.7576479076479076,
 0.7125,
 0.6363315696649031,
 0.29604232319891943,
 0.42980126153249787,
 0.4182216361826803,
 0.1956521739130435,
 0.298813895786032,
 0.25,
 0.3028710731042149,
 0.26037748769172925,
 0.2972222222222222,
 0.06982960618523808,
 0.31303432121,
 0.28164502374065437,
 0.3230403693882516,
 0.39344728932234735])
data_mp.style.apply(highlight_last_max,axis=1)
data_mp
# Out:
#       Group        Project  BugLocator  BRTracer   BLUiR  AmaLgam    BLIA  \
# 0    Apache          CAMEL      0.3585    0.3960  0.3487   0.3525  0.3479
# 1    Apache          HBASE      0.3626    0.4004  0.3533   0.3531  0.3823
# 2    Apache           HIVE      0.3048    0.3517  0.3177   0.3181  0.2888
# 3   Commons          CODEC      0.6390    0.6237  0.7488   0.7488  0.6734
# 4   Commons    COLLECTIONS      0.4443    0.5236  0.4057   0.4057  0.5692
# 5   Commons       COMPRESS      0.5414    0.5484  0.4839   0.4794  0.5791
# 6   Commons  CONFIGURATION      0.5174    0.5103  0.5063   0.5143  0.5750
# 7   Commons         CRYPTO      0.1628    0.1708  0.1982   0.1982  0.1588
# 8   Commons            CSV      0.6017    0.5813  0.6052   0.6290  0.3750
# 9   Commons             IO      0.7110    0.7152  0.6694   0.6693  0.7629
# 10  Commons           LANG      0.5576    0.5648  0.5674   0.5714  0.5988
# 11  Commons           MATH      0.4227    0.4459  0.4834   0.4965  0.4696
# ...

# %%
data = pd.DataFrame()
data['BugLocator'] = data_mp['BugLocator']
data['BRTracer'] =  data_mp['BRTracer']
data['BLUiR'] =  data_mp['BLUiR']
data['AmaLgam'] =  data_mp['AmaLgam']
data['BLIA'] =  data_mp['BLIA']
data['Locus'] =  data_mp['Locus']
data['Blizzard'] =  data_mp['Blizzard']
data['Broccoli'] =  data_mp['Broccoli']
#print(data.to_dict())
result = autorank(data, alpha=0.0125, verbose=False, approach='bayesian')
latex_report(result)
# Out:
# \documentclass{article}
#
# \usepackage{graphicx}
# \usepackage{booktabs}
#
# \begin{document}
#
# \section{Results}
# \label{sec:results}
#
# The statistical analysis was conducted for 8 populations with 51 paired samples.
# The family-wise significance level of the tests $\alpha$=0.013.
# We failed to reject the null hypothesis that the population is normal for all populations (minimal observed p-value=0.022). Therefore, we assume that all populations are normal.
# We used a bayesian signed rank test to determine differences between the mean values of the populations and report the mean value (M) and the standard deviation (SD) for each population. We distinguish between populations being pair-wise smaller, equal, or larger and make a decision for one of these cases if we estimate that the posterior probability is at least alpha=0.013.
# We used the effect size to define the region of practical equivalence (ROPE) around the mean value dynamically as 0.100*d.
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.violinplot (data=data.iloc[:,0:8], orient='h', color='lightgray',cut=0)
plt.savefig('experiment1_map.png')

# %%
data_mp = pd.read_csv('New_Multiple_noTest_MRR.txt',sep='\t')
data_mp["Blizzard"] = pd.Series([0.250615708650679,
 0.2783876477058297,
 0.21612420939738394,
 0.4258130081300814,
 0.3399560117302051,
 0.36924879424879437,
 0.33287771898883023,
 0.1388888888888889,
 0.42857142857142855,
 0.4018668831168831,
 0.38924774056353,
 0.33547351705833856,
 0.29166666666666663,
 0.035286935286935286,
 0.12176573426573427,
 0.038029511911090885,
 0.15797747450289823,
 0.27623391347881154,
 0.22833333333333336,
 0.29018616147329007,
 0.24074074074074073,
 0.27611885148292903,
 0.27953216374269,
 0.24246590327235493,
 0.06727272727272728,
 0.2912301099801101,
 0.2462437732552678,
 0.33342502405002405,
 0.24691585771131216,
 0.27569631626235397,
 0.32914862914862913,
 0.20839114523697272,
 0.30056173032143463,
 0.1718088624338624,
 0.30075620147048715,
 0.3776422764227642,
 0.20105820105820105,
 0.29666666666666663,
 0.2929629629629629,
 0.3148148148148148,
 0.3625,
 0.2402846492132206,
 0.2755330490405118,
 0.20918025772676935,
 0.11062801932367151,
 0.1283807462378891,
 0.0,
 0.1835957552771714,
 0.15311006453863593,
 0.38888888888888884,
                               0.35393971248652684 ])
data_mp["Broccoli"] =pd.Series([0.489204304544912,
 0.5284718239018517,
 0.42710302910144143,
 0.7637721357233551,
 0.6479190134835298,
 0.7333699245463955,
 0.6749959536348425,
 0.328125,
 0.7809523809523808,
 0.8089556277056278,
 0.7366032730774034,
 0.6470665984703324,
 0.6,
 0.07188012043211692,
 0.2558959669237463,
 0.6432816016823978,
 0.6773983315954119,
 0.6984853327651112,
 0.5759301373452069,
 0.5647358983476278,
 0.16615332999600985,
 0.6151282691864786,
 0.5333062571818848,
 0.7052876232563734,
 0.5041418926802941,
 0.61177009573236,
 0.6087445887445887,
 0.3622816329761493,
 0.4814044231488495,
 0.5897527744310794,
 0.6052603478910528,
 0.6821010975352784,
 0.5728969279356877,
 0.6457164404223228,
 0.7777777777777777,
 0.7125,
 0.6585537918871254,
 0.3971067439521115,
 0.4811314757110848,
 0.5037390928478732,
 0.20289855072463767,
 0.38159011565603823,
 0.25,
 0.38200476908414116,
 0.33814273700266234,
 0.2833333333333333,
 0.15104172712362748,
 0.4723232527874321,
 0.3787702190900558,
 0.48718923862390306,
 0.4646597780526351])

data_mp.style.apply(highlight_last_max,axis=1)
#data_mp
#statistics.mean(data["Blizzard"])
print(data_mp.to_latex(index=False))
# Out:
# \begin{tabular}{llrrrrrrrr}
# \toprule
#    Group &        Project &  BugLocator &  BRTracer &   BLUiR &  AmaLgam &    BLIA &   Locus &  Blizzard &  Broccoli \\
# \midrule
#   Apache &          CAMEL &      0.4658 &    0.5280 &  0.4511 &   0.4550 &  0.4566 &  0.5524 &  0.250616 &  0.489204 \\
#   Apache &          HBASE &      0.4433 &    0.4918 &  0.4284 &   0.4280 &  0.4576 &  0.5025 &  0.278388 &  0.528472 \\
#   Apache &           HIVE &      0.3848 &    0.4548 &  0.4098 &   0.4095 &  0.3627 &  0.4497 &  0.216124 &  0.427103 \\
#  Commons &          CODEC &      0.8230 &    0.7554 &  0.8016 &   0.8016 &  0.8241 &  0.7935 &  0.425813 &  0.763772 \\
#  Commons &    COLLECTIONS &      0.6296 &    0.6933 &  0.4581 &   0.4581 &  0.7252 &  0.7208 &  0.339956 &  0.647919 \\
#  Commons &       COMPRESS &      0.7165 &    0.7561 &  0.6139 &   0.6097 &  0.7871 &  0.7693 &  0.369249 &  0.733370 \\
# ...

# %%
data = pd.DataFrame()
data['BugLocator'] = data_mp['BugLocator']
data['BRTracer'] =  data_mp['BRTracer']
data['BLUiR'] =  data_mp['BLUiR']
data['AmaLgam'] =  data_mp['AmaLgam']
data['BLIA'] =  data_mp['BLIA']
data['Locus'] =  data_mp['Locus']
data['Blizzard'] =  data_mp['Blizzard']
data['Broccoli'] =  data_mp['Broccoli']
result = autorank(data, alpha=0.0125, verbose=False, approach='bayesian')
latex_report(result)
# Out:
# \documentclass{article}
#
# \usepackage{graphicx}
# \usepackage{booktabs}
#
# \begin{document}
#
# \section{Results}
# \label{sec:results}
#
# The statistical analysis was conducted for 8 populations with 51 paired samples.
# The family-wise significance level of the tests $\alpha$=0.013.
# We failed to reject the null hypothesis that the population is normal for all populations (minimal observed p-value=0.043). Therefore, we assume that all populations are normal.
# We used a bayesian signed rank test to determine differences between the mean values of the populations and report the mean value (M) and the standard deviation (SD) for each population. We distinguish between populations being pair-wise smaller, equal, or larger and make a decision for one of these cases if we estimate that the posterior probability is at least alpha=0.013.
# We used the effect size to define the region of practical equivalence (ROPE) around the mean value dynamically as 0.100*d.
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.violinplot (data=data.iloc[:,0:8], orient='h', color='lightgray',cut=0)
plt.savefig('experiment1_mrr.png')

# %%
create_report(result)
# Out:
# The statistical analysis was conducted for 8 populations with 51 paired samples.
# The family-wise significance level of the tests is alpha=0.013.
# We failed to reject the null hypothesis that the population is normal for all populations (minimal observed p-value=0.043). Therefore, we assume that all populations are normal.
# We used a bayesian signed rank test to determine differences between the mean values of the populations and report the mean value (M) and the standard deviation (SD) for each population. We distinguish between populations being pair-wise smaller, equal, or larger and make a decision for one of these cases if we estimate that the posterior probability is at least alpha=0.013.
# We used the effect size to define the region of practical equivalence (ROPE) around the mean value dynamically as 0.100*d.
# ...

# %% [markdown]
# ## HIT VALUES

# %%
data_mp = pd.read_csv('../../smartshark_other/results_other_bench4bl.csv')
data_mp["HIT1_Broccoli"] =pd.Series([0.34524847428073235,
 0.40442890442890445,
 0.3199343724364233,
 0.6829268292682927,
 0.5591397849462365,
 0.6571428571428571,
 0.562962962962963,
 0.375,
 0.6428571428571429,
 0.8409090909090909,
 0.6782178217821783,
 0.5535714285714286,
 0.0,
 0.02564102564102564,
 0.15384615384615385,                                   
 0.055944055944055944,
 0.40817702794009105, 
 0.36666666666666664,
 0.41836734693877553,
 0.25,
 0.5148514851485149,
 0.4444444444444444,
 0.631578947368421,
 0.529126213592233,
 0.4838709677419355,
 0.12631578947368421,
 0.5067567567567568,
 0.4482758620689655,
 0.6875,
 0.42424242424242425,
 0.49056603773584906,
 0.5454545454545454,
 0.26166902404526166,
 0.4166666666666667,
 0.5268022181146026,
 0.5238095238095238,
 0.5121951219512195,
 0.4444444444444444,
 0.5333333333333333,
 0.6666666666666666,
 0.625,
 0.5333333333333333,
 0.30158730158730157,
 0.43283582089552236,
 0.42441860465116277,
 0.21739130434782608,
 0.23214285714285715,
 1.0,
 0.31268436578171094,
 0.2175824175824176,
 0.0])
data_mp["HIT5_Broccoli"] =pd.Series([0.5649520488230165,
 0.668997668997669,
 0.5250205086136177,
 0.9512195121951219,
 0.8279569892473119,
 0.9238095238095239,
 0.8444444444444444,
 0.5,
 0.9285714285714286,
 0.9318181818181818,
 0.8564356435643564,
 0.75,
 1.0,
 0.1282051282051282,
 0.34615384615384615,
 0.2517482517482518,
 0.6366134678934262,
 0.48333333333333334,
 0.6224489795918368,
 0.5,
 0.8514851485148515,
 0.6666666666666666,
 0.7368421052631579,
 0.7063106796116505,
 0.6967741935483871,
 0.25263157894736843,
 0.75,
 0.7471264367816092,
 0.8958333333333334,
 0.7348484848484849,
 0.7735849056603774,
 0.7272727272727273,
 0.594059405940594,
 0.625,
 0.7301293900184843,
 0.6666666666666666,
 0.8048780487804879,
 0.7777777777777778,
 0.7333333333333333,
 1.0,
 0.875,
 0.7333333333333333,
 0.5079365079365079,
 0.6417910447761194,
 0.5930232558139535,
 0.30434782608695654,
 0.5,
 1.0,
 0.5191740412979351,
 0.41318681318681316,
 0.6666666666666666])
data_mp["HIT10_Broccoli"] =pd.Series([0.6573670444638187,
 0.7412587412587412,
 0.6365873666940115,
 0.975609756097561,
 0.8494623655913979,
 0.9714285714285714,
 0.8962962962962963,
 0.5,
 0.9285714285714286,
 0.9431818181818182,
 0.8663366336633663,
 0.8035714285714286,
 1.0,
 0.20512820512820512,
 0.4230769230769231,
 0.32867132867132864,
 0.7035789256731531,
 0.55,
 0.7244897959183674,
 0.6,
 0.8712871287128713,
 0.6666666666666666,
 0.8421052631578947,
 0.7742718446601942,
 0.7483870967741936,
 0.3263157894736842,
 0.8783783783783784,
 0.8390804597701149,
 0.9166666666666666,
 0.8257575757575758,
 0.8113207547169812,
 0.9090909090909091,
 0.7312588401697313,
 0.6666666666666666,
 0.7781885397412199,
 0.7714285714285715,
 0.8536585365853658,
 0.8888888888888888,
 0.8666666666666667,
 1.0,
 0.875,
 0.7333333333333333,
 0.6111111111111112,
 0.7164179104477612,
 0.6744186046511628,
 0.30434782608695654,
 0.6071428571428571,
 1.0,
 0.6076696165191741,
 0.4912087912087912,
 1.0])
data_mp["MAP_Broccoli"] =pd.Series([0.3659457139842377,
 0.41426505130378183,
 0.3190317997373462,
 0.7503564751316188,
 0.6435522409930926,
 0.6902797407863274,
 0.6343509961036702,
 0.4065190031463251,
 0.7188542938542939,
 0.849212006206723,
 0.7450297247460368,
 0.5804062032586277,
 0.35721153846153847,
 0.06606907377226977,
 0.2198359474812193,
 0.561248208475829,
 0.33863699346929366,
 0.605575008681965,
 0.5212957078338329,
 0.5204402146122917,
 0.1501336617038996,
 0.5805244442208808,
 0.5260782627024357,
 0.71258172014148,
 0.5057927566335629,
 0.5342503325611301,
 0.605297256323248,
 0.3408706340677093,
 0.4247647763426439,
 0.557086896039616,
 0.47346084038840036,
 0.5224797533114224,
 0.5467944552739874,
 0.6282447055861635,
 0.7227623456790123,
 0.68125,
 0.5941358024691359,
 0.3144102969567014,
 0.46606908961007704,
 0.42716543631078474,
 0.22826086956521738,
 0.28512300787838146,
 1.0,
 0.31968282929946934,
 0.2366387939465169,
 0.17841880341880342,
 0.07690308771588435,
 0.47716543631078474,                               
 0.3312786530139438,
 0.3786465522093176,
 0.3175004237106579])
data_mp["MRR_Broccoli"] = pd.Series([0.4495727355357287,
 0.5176895110741583,
 0.42114767470621933,
 0.8002120890774126,
 0.6860549844420811,
 0.7785276370055852,
 0.6813419097863309,
 0.41761363636363635,
 0.7519230769230768,
 0.8730113636363636,
 0.756091796266561,
 0.6430654834261291,
 0.375,
 0.07116429322311675,
 0.2493582397827664,
 0.6564175274324232,
 0.5418211604661772,
 0.6937491755705052,
 0.6130711925719452,
 0.5837903266770856,
 0.19044886395946428,
 0.62495533778898,
 0.5768335425963897,
 0.770342725913378,
 0.5617522702465886,
 0.6247391353430976,
 0.6454042081949058,
 0.4161818977247536,
 0.5047309737994878,
 0.6179780383806694,
 0.6032361378895454,
 0.6394844312547173,
 0.5779835390946502,
 0.6463780663780663,
 0.7333333333333334,
 0.68125,
 0.616358024691358,
 0.4189446047923951,
 0.5252437412767379,
 0.5077484018203389,
 0.2427536231884058,
 0.36429618911363987,
 1.0,
 0.41664180159589514,
 0.309704356405328,
 0.2111111111111111,
 0.1505315653103756,
 0.42529859638934586,
 0.545148586689124,
 0.5095148586689124,
 0.3917447878695928])
data_mp
# Out:
#                   project    bugs  version  MAP_buglocator  MRR_buglocator  \
# 0            Apache_CAMEL  1452.0       62        0.376696        0.466102
# 1            Apache_HBASE   858.0       70        0.368868        0.452408
# 2             Apache_HIVE  1219.0       21        0.276611        0.371965
# 3           Commons_CODEC    41.0        9        0.768098        0.847339
# 4     Commons_COLLECTIONS    93.0        7        0.588393        0.631820
# 5        Commons_COMPRESS   111.0       15        0.656692        0.733429
# 6   Commons_CONFIGURATION   135.0       11        0.651569        0.706430
# 7          Commons_CRYPTO     8.0        1        0.243720        0.244213
# 8             Commons_CSV    14.0        3        0.652888        0.674317
# 9              Commons_IO    88.0       13        0.795551        0.807161
# 10           Commons_LANG   209.0       16        0.661462        0.676411
# ...

# %%
data = pd.DataFrame()
new = data_mp["project"].str.split("_", n = 1, expand = True) 
data['Group'] = new[0]
data['Project'] = new[1]
data['BugLocator'] = data_mp['HIT1_buglocator']
data['BRTracer'] =  data_mp['HIT1_brtracer']
data['BLUiR'] =  data_mp['HIT1_bluir']
data['AmaLgam'] =  data_mp['HIT1_amalgam']
data['BLIA'] =  data_mp['HIT1_blia']
data['Locus'] =  data_mp['HIT1_locus']
data['Blizzard'] = data_mp['HIT1_blizzard']
data['Broccoli'] =  data_mp['HIT1_Broccoli']

result = autorank(data, alpha=0.0125, verbose=False, approach='bayesian')
create_report(result)
#data.style.apply(highlight_last_max2,axis=1)
#data
#print(data.to_latex())

# %%
data = pd.DataFrame()
new = data_mp["project"].str.split("_", n = 1, expand = True) 
data['Group'] = new[0]
data['Project'] = new[1]
data['BugLocator'] = data_mp['HIT5_buglocator']
data['BRTracer'] =  data_mp['HIT5_brtracer']
data['BLUiR'] =  data_mp['HIT5_bluir']
data['AmaLgam'] =  data_mp['HIT5_amalgam']
data['BLIA'] =  data_mp['HIT5_blia']
data['Locus'] =  data_mp['HIT5_locus']
data['Blizzard'] = data_mp['HIT5_blizzard']
data['Broccoli'] =  data_mp['HIT5_Broccoli']

#result = autorank(data, alpha=0.0125, verbose=False)
#create_report(result)
data.style.apply(highlight_last_max2,axis=1)
#print(data.to_latex(index=False))
# Out:
# <style  type="text/css" >
# ...

# %%
data = pd.DataFrame()
new = data_mp["project"].str.split("_", n = 1, expand = True) 
data['Group'] = new[0]
data['Project'] = new[1]
data['BugLocator'] = data_mp['HIT10_buglocator']
data['BRTracer'] =  data_mp['HIT10_brtracer']
data['BLUiR'] =  data_mp['HIT10_bluir']
data['AmaLgam'] =  data_mp['HIT10_amalgam']
data['BLIA'] =  data_mp['HIT10_blia']
data['Locus'] =  data_mp['HIT10_locus']
data['Blizzard'] = data_mp['HIT10_blizzard']
data['Broccoli'] =  data_mp['HIT10_Broccoli']

#result = autorank(data, alpha=0.0125, verbose=False)
#create_report(result)
data.style.apply(highlight_last_max2,axis=1)
#print(data.to_latex(index=False))
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# # SmartSHARK Experiment

# %%
data_mp = pd.read_csv('../../smartshark_other/results_other.csv')
data_mp["MAP_Broccoli"] =pd.Series([0.46161432249667517,
 0.38344973854027603,
 0.49974198938834796,
 0.3742026597140233,
 0.3272023809523809,
 0.6862103174603176,
 0.7620833333333333,
 0.7411440185830429,
 0.6593403713686736,
 0.6060394889663183,
 0.6006776556776556,
 0.5555555555555555,
 0.8228659611992947,
 0.5776467274152458,
 0.47739231824417006,
 0.7481240981240983,
 0.6232132158418923,
 0.7838461538461536,
 0.6331699346405228,
 0.6876781305114638,
 0.604128873771731,
 0.45003598331988176,
 0.30719642857142854,
 0.539390381534877,
 0.6486830843448491,
 0.32597539015606253,
 0.4225192469460906,
 0.4113593047732834,
 0.3778602700138028,
 0.6408080997664332,
 0.5190207914151578,
 0.5638630319148936,
 0.5259487319832148,
 0.5373252078609221,
 0.6394140493076663,
 0.3312369262950659,
 0.5302767443783064,
 0.5377685185185186])
data_mp["MRR_Broccoli"] =pd.Series([0.499087513793396,
 0.42686915887850474,
 0.5576836290071584,
 0.40089203725567363,
 0.34732142857142856,
 0.7420634920634921,
 0.8366666666666666,
 0.7778745644599303,
 0.7230158730158731,
 0.7251871209188283,
 0.6556593406593407,
 0.6666666666666666,
 0.8981481481481481,
 0.6356481481481482,
 0.5394973544973544,
 0.83513986013986,
 0.701100995953937,
 0.8245217745217744,
 0.7053921568627451,
 0.7570017636684303,
 0.626384164777022,
 0.4827649986548293,
 0.31840476190476186,
 0.5610091743119265,
 0.6591425459072517,
 0.34987995198079236,
 0.4466429851510499,
 0.4288402457757297,
 0.4107531055900622,
 0.68264157014157,
 0.5472347976749385,
 0.5836689463019251,
 0.5378808611567233,
 0.6097181729834791,
 0.6720027017899358,
 0.3465593084779131,
 0.5734672619047617,
 0.5660211640211642])
data_mp["HIT1_Broccoli"] =pd.Series([0.6437768240343348,
 0.5747126436781609,
 0.8607594936708861,
 0.5796460176991151,
 0.4146341463414634,
 0.7105263157894737,
 0.8333333333333334,
 0.3434343434343434,
 0.8888888888888888,
 0.753968253968254,
 0.7049180327868853,
 0.5714285714285714,
 0.9736842105263158,
 0.4032258064516129,
 0.5555555555555556,
 0.8395061728395061,
 0.34146341463414637,
 0.8260869565217391,
 0.8421052631578947,
 0.75,
 0.47474747474747475,
 0.8292682926829268,
 0.49645390070921985,
 0.5874125874125874,
 0.7551020408163265,
 0.2028985507246377,
 0.8,
 0.5893719806763285,
 0.5850622406639004,
 0.80625,
 0.8627450980392157,
 0.8050847457627118,
 0.582089552238806,
 0.6785714285714286,
 0.8095238095238095,
 0.6470588235294118,
 0.8589743589743589,
 0.6067415730337079])
data_mp["HIT5_Broccoli"] =pd.Series([0.8669527896995708,
 0.7758620689655172,
 0.9240506329113924,
 0.7389380530973452,
 0.5609756097560976,
 0.9210526315789473,
 0.9761904761904762,
 0.37373737373737376,
 1.0,
 0.9285714285714286,
 0.819672131147541,
 0.7142857142857143,
 1.0,
 0.5,
 0.7555555555555555,
 0.9012345679012346,
 0.4878048780487805,
 0.9855072463768116,
 0.9473684210526315,
 1.0,
 0.6868686868686869,
 0.9024390243902439,
 0.75177304964539,
 0.7692307692307693,
 0.9591836734693877,
 0.3188405797101449,
 0.9166666666666666,
 0.7874396135265701,
 0.8132780082987552,
 0.8875,
 0.9803921568627451,
 0.8728813559322034,
 0.835820895522388,
 0.8214285714285714,
 0.9761904761904762,
 0.8455882352941176,
 0.9871794871794872,
 0.7528089887640449])
data_mp["HIT10_Broccoli"] =pd.Series([0.9098712446351931,
 0.8275862068965517,
 0.9493670886075949,
 0.7876106194690266,
 0.5853658536585366,
 0.9473684210526315,
 0.9761904761904762,
 0.3838383838383838,
 1.0,
 0.9444444444444444,
 0.8360655737704918,
 0.7142857142857143,
 1.0,
 0.5161290322580645,
 0.8,
 0.9012345679012346,
 0.4878048780487805,
 1.0,
 0.9473684210526315,
 1.0,
 0.696969696969697,
 0.926829268292683,
 0.7872340425531915,
 0.8601398601398601,
 0.9591836734693877,
 0.36231884057971014,
 0.9333333333333333,
 0.8454106280193237,
 0.8630705394190872,
 0.91875,
 0.9803921568627451,
 0.9152542372881356,
 0.8731343283582089,
 0.8571428571428571,
 0.9761904761904762,
 0.8897058823529411,
 0.9871794871794872,
 0.7640449438202247])
# codec, collections, compress,configuration,io,lang,math,
data_mp = data_mp.drop([6,7,8,9,12,15,16])
data_mp
# Out:
#                          project   bugs  version  MAP_buglocator  \
# 0             smartshark_ant-ivy  374.0        6        0.390238
# 1             smartshark_archiva  214.0        7        0.205291
# 2             smartshark_calcite  306.0       16        0.362004
# 3             smartshark_cayenne  242.0        2        0.289970
# 4        smartshark_commons-bcel   28.0        6        0.335842
# 5   smartshark_commons-beanutils   24.0       10        0.515891
# 10       smartshark_commons-dbcp   65.0       11        0.362946
# 11   smartshark_commons-digester    6.0       14        0.583333
# 13        smartshark_commons-jcs   54.0        6        0.303888
# 14       smartshark_commons-jexl   45.0        6        0.254857
# 17        smartshark_commons-net  117.0       15        0.757696
# 18      smartshark_commons-scxml   17.0        5        0.398328
# 19  smartshark_commons-validator   45.0        7        0.634593
# ...

# %%
import matplotlib.pyplot as plt

data = pd.DataFrame()
data['Blizzard'] = data_mp['MAP_blizzard']
data['BugLocator'] = data_mp['MAP_buglocator']
data['BRTracer'] =  data_mp['MAP_brtracer']
data['BLUiR'] =  data_mp['MAP_bluir']
data['AmaLgam'] =  data_mp['MAP_amalgam']
data['BLIA'] =  data_mp['MAP_blia']
data['Locus'] =  data_mp['MAP_locus']
data['Broccoli'] =  data_mp['MAP_Broccoli']
#print(data.to_dict())

import seaborn as sns
sns.violinplot (data=data.iloc[:,0:8], orient='h', color='lightgray',cut=0)
plt.savefig('experiment2_map.png')

# %%
data.style.apply(highlight_last_max,axis=1)
#print(data.to_latex())
# Out:
# <style  type="text/css" >
# ...

# %%
result = autorank(data, alpha=0.0125, verbose=False, approach='bayesian')
latex_report(result)
#plot_stats(result)
# Out:
# \documentclass{article}
#
# \usepackage{graphicx}
# \usepackage{booktabs}
#
# \begin{document}
#
# \section{Results}
# \label{sec:results}
#
# The statistical analysis was conducted for 8 populations with 31 paired samples.
# The family-wise significance level of the tests $\alpha$=0.013.
# We rejected the null hypothesis that the population is normal for the population BLUiR (p=0.001). Therefore, we assume that not all populations are normal.
# We used a bayesian signed rank test to determine differences between the mean values of the populations and report the median (MD) and the median absolute deviation (MAD) for each population. We distinguish between populations being pair-wise smaller, equal, or larger and make a decision for one of these cases if we estimate that the posterior probability is at least alpha=0.013.
# We used the effect size to define the region of practical equivalence (ROPE) around the median dynamically as 0.100*gamma.
# ...

# %%
data = pd.DataFrame()
data['Blizzard'] = data_mp['MRR_blizzard']
data['BugLocator'] = data_mp['MRR_buglocator']
data['BRTracer'] =  data_mp['MRR_brtracer']
data['BLUiR'] =  data_mp['MRR_bluir']
data['AmaLgam'] =  data_mp['MRR_amalgam']
data['BLIA'] =  data_mp['MRR_blia']
data['Locus'] =  data_mp['MRR_locus']
data['Broccoli'] =  data_mp['MRR_Broccoli']
#result = autorank(data, alpha=0.0125, verbose=False)

import seaborn as sns
import matplotlib.pyplot as plt

sns.violinplot (data=data.iloc[:,0:8], orient='h', color='lightgray',cut=0)
plt.savefig('experiment2_mrr.png')

# %%
result = autorank(data, alpha=0.0125, verbose=False, approach='bayesian')
latex_report(result)
#plot_stats(result)
# Out:
# \documentclass{article}
#
# \usepackage{graphicx}
# \usepackage{booktabs}
#
# \begin{document}
#
# \section{Results}
# \label{sec:results}
#
# The statistical analysis was conducted for 8 populations with 31 paired samples.
# The family-wise significance level of the tests $\alpha$=0.013.
# We failed to reject the null hypothesis that the population is normal for all populations (minimal observed p-value=0.019). Therefore, we assume that all populations are normal.
# We used a bayesian signed rank test to determine differences between the mean values of the populations and report the mean value (M) and the standard deviation (SD) for each population. We distinguish between populations being pair-wise smaller, equal, or larger and make a decision for one of these cases if we estimate that the posterior probability is at least alpha=0.013.
# We used the effect size to define the region of practical equivalence (ROPE) around the mean value dynamically as 0.100*d.
# ...

# %%
#print(data.to_latex())
data.style.apply(highlight_last_max,axis=1)
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# ## HIT VALUES

# %%
data = pd.DataFrame()
data['Blizzard'] = data_mp['HIT1_blizzard']
data['BugLocator'] = data_mp['HIT1_buglocator']
data['BRTracer'] =  data_mp['HIT1_brtracer']
data['BLUiR'] =  data_mp['HIT1_bluir']
data['AmaLgam'] =  data_mp['HIT1_amalgam']
data['BLIA'] =  data_mp['HIT1_blia']
data['Locus'] =  data_mp['HIT1_locus']
data['Broccoli'] =  data_mp['HIT1_Broccoli']

result = autorank(data, alpha=0.0125, verbose=False)
#print(result)
data.style.apply(highlight_last_max,axis=1)
#print(data.to_latex())
# Out:
# /home/test/.local/lib/python3.6/site-packages/statsmodels/sandbox/stats/multicomp.py:775: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_yticklabels(np.insert(self.groupsunique.astype(str), 0, ''))
# <style  type="text/css" >
# ...

# %%
data = pd.DataFrame()
data['BugLocator'] = data_mp['HIT5_buglocator']
data['BRTracer'] =  data_mp['HIT5_brtracer']
data['BLUiR'] =  data_mp['HIT5_bluir']
data['AmaLgam'] =  data_mp['HIT5_amalgam']
data['BLIA'] =  data_mp['HIT5_blia']
data['Locus'] =  data_mp['HIT5_locus']
data['Blizzard'] = data_mp['HIT5_blizzard']
data['Broccoli'] =  data_mp['HIT5_Broccoli']

result = autorank(data, alpha=0.0125, verbose=False)
#create_report(result)
data.style.apply(highlight_last_max,axis=1)
#print(data.to_latex())
# Out:
# /home/test/.local/lib/python3.6/site-packages/statsmodels/sandbox/stats/multicomp.py:775: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_yticklabels(np.insert(self.groupsunique.astype(str), 0, ''))
# <style  type="text/css" >
# ...

# %%
data = pd.DataFrame()
data['BugLocator'] = data_mp['HIT10_buglocator']
data['BRTracer'] =  data_mp['HIT10_brtracer']
data['BLUiR'] =  data_mp['HIT10_bluir']
data['AmaLgam'] =  data_mp['HIT10_amalgam']
data['BLIA'] =  data_mp['HIT10_blia']
data['Locus'] =  data_mp['HIT10_locus']
data['Blizzard'] = data_mp['HIT10_blizzard']
data['Broccoli'] =  data_mp['HIT10_Broccoli']

result = autorank(data, alpha=0.0125, verbose=False)
#create_report(result)
data.style.apply(highlight_last_max,axis=1)
#print(data.to_latex())
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# # Time-Aware Matching

# %%
data_mp = pd.DataFrame()
data_mp["MAP_Broccoli"] =pd.Series([0.4782326691955461,
 0.4245268655947229,
 0.5361870110583382,
 0.38938984638570884,
 0.6849695050433967,
 0.6507234432234431,
 0.7598407029478459,
 0.7252247732426305,
 0.670369214119214,
 0.6524818045497771,
 0.6596870680204014,
 0.7275510204081632,
 0.8559550989345511,
 0.6394770044770045,
 0.4771707818930041,
 0.7836855526161077,
 0.6408520935901885,
 0.798077876984127,
 0.6572023809523809,
 0.6932774838330396,
 0.6640221737549983,
 0.5240175264550266,
 0.3234799672793094,
 0.5432892126148705,
 0.5809117096450984,
 0.3258135302932992,
 0.4581375947892193,
 0.4431050597958789,
 0.4591716452878814,
 0.6010855673409716,
 0.5150324880411842,
 0.6540711683835947,
 0.5875862068965516,
 0.5866464363523187,
 0.6003686942813656,
 0.38068253918915973,
 0.5661912372973879,
 0.4915120701058201])

data_mp["MAP_TimeAware"] =pd.Series([0.4639841127609943,
 0.4170694124423964,
 0.5020221631006637,
 0.3743722419811631,
 0.4821929824561403,
 0.6862103174603176,
 0.7518055555555557,
 0.7346726190476189,
 0.6499064091045227,
 0.5876355013550136,
 0.5232600732600731,
 0.6666666666666666,
 0.8228659611992947,
 0.5998639092389092,
 0.445018281928851,
 0.7320719954648529,
 0.6283598885682219,
 0.7752991452991451,
 0.6331699346405228,
 0.6876781305114638,
 0.6064992257065429,
 0.4416518886756983,
 0.31999627976190476,
 0.5363188721001222,
 0.635953548085901,
 0.32423517840184507,
 0.4225192469460906,
 0.3902507215007216,
 0.37855896001387823,
 0.5932089842109681,
 0.5136807630790413,
 0.5821066569484937,
 0.5512956588257794,
 0.5373252078609221,
 0.5438790386130811,
 0.3303873015873017,
 0.5226715015508114,
 0.4402682593307595
])

data_mp["MRR_Broccoli"] =pd.Series([0.5144008028578795,
 0.4665815295815297,
 0.5954907999684115,
 0.40724206349206343,
 0.6888341543513957,
 0.7134615384615385,
 0.8301587301587301,
 0.7551111111111112,
 0.7205766455766456,
 0.7593701996927803,
 0.7079794079794081,
 0.8571428571428571,
 0.9126712328767124,
 0.7001465201465201,
 0.5337092731829574,
 0.8406966490299824,
 0.6955479288812623,
 0.8217261904761906,
 0.7266666666666667,
 0.7625220458553792,
 0.6913576881134132,
 0.5400218253968254,
 0.3331323099415206,
 0.5715504037872458,
 0.6114802510151348,
 0.3385792274520599,
 0.4902197581800471,
 0.46744161888140945,
 0.5030003514320857,
 0.6319392230576443,
 0.5407276070396637,
 0.6774861181221602,
 0.61648056923919,
 0.6513165266106443,
 0.6318982387475539,
 0.4017489328194288,
 0.603358056185437,
 0.5321649029982362])

# Timeaware Results

data_mp["MRR_TimeAware"] =pd.Series([0.5017707799965863,
 0.46296296296296297,
 0.5612250510765362,
 0.39842916419679897,
 0.5118421052631579,
 0.7420634920634921,
 0.8272222222222222,
 0.7723214285714286,
 0.7135819107517223,
 0.7021518905665248,
 0.5728388278388279,
 0.8,
 0.8981481481481481,
 0.6600961538461539,
 0.515921409214092,
 0.8197023809523808,
 0.7050905884239216,
 0.8159747659747659,
 0.7053921568627451,
 0.7570017636684303,
 0.6292973286875726,
 0.4695122778456113,
 0.33167162698412694,
 0.5674145299145299,
 0.6437052598817306,
 0.3483346900013567,
 0.4466429851510499,
 0.4087258297258298,
 0.4116315378610461,
 0.6219503233392122,
 0.5389810090702949,
 0.5928219954648526,
 0.5638028303690955,
 0.6097181729834791,
 0.5889395474501857,
 0.3448825396825397,
 0.5648380355276905,
 0.4703775203775206])



print(data_mp.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &  MAP\_Broccoli &  MAP\_TimeAware &  MRR\_Broccoli &  MRR\_TimeAware \\
# \midrule
# 0  &      0.478233 &       0.463984 &      0.514401 &       0.501771 \\
# 1  &      0.424527 &       0.417069 &      0.466582 &       0.462963 \\
# 2  &      0.536187 &       0.502022 &      0.595491 &       0.561225 \\
# 3  &      0.389390 &       0.374372 &      0.407242 &       0.398429 \\
# 4  &      0.684970 &       0.482193 &      0.688834 &       0.511842 \\
# 5  &      0.650723 &       0.686210 &      0.713462 &       0.742063 \\
# 6  &      0.759841 &       0.751806 &      0.830159 &       0.827222 \\
# 7  &      0.725225 &       0.734673 &      0.755111 &       0.772321 \\
# 8  &      0.670369 &       0.649906 &      0.720577 &       0.713582 \\
# 9  &      0.652482 &       0.587636 &      0.759370 &       0.702152 \\
# 10 &      0.659687 &       0.523260 &      0.707979 &       0.572839 \\
# ...

# %%
data = pd.DataFrame()
data['Normal'] = data_mp['MRR_Broccoli']
data['Timeware'] = data_mp['MRR_TimeAware']
result = autorank(data, alpha=0.0125, verbose=False, approach='bayesian')
#print(result)
#data
data.style.apply(highlight_last_max,axis=1)
# Out:
# <style  type="text/css" >
# ...

# %%
latex_table(result)
latex_report(result)
# Out:
# \begin{table}[h]
# \centering
# \begin{tabular}{lrrlllrrl}
# \toprule
# {} &     M &    SD &              CI &   \$d\$ &   Magnitude &  $P(\textit{equal})$ &  $P(\textit{smaller})$ & Decision \\
# \midrule
# Normal   & 0.627 & 0.144 &  [0.553, 0.701] & 0.000 &  negligible &        - &          - &        - \\
# Timeware & 0.595 & 0.149 &  [0.518, 0.671] & 0.224 &       small &    0.009 &      0.991 &  smaller \\
# \bottomrule
# \end{tabular}
# \caption{Summary of populations}
# \label{tbl:stat_results}
# \end{table}
# \documentclass{article}
#
# \usepackage{graphicx}
# \usepackage{booktabs}
#
# \begin{document}
#
# \section{Results}
# \label{sec:results}
#
# The statistical analysis was conducted for 2 populations with 38 paired samples.
# The family-wise significance level of the tests $\alpha$=0.013.
# We failed to reject the null hypothesis that the population is normal for all populations (minimal observed p-value=0.597). Therefore, we assume that all populations are normal.
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import matplotlib.transforms as mtransforms

fig, ax = plt.subplots()
ax.scatter(data['Normal'], data['Timeware'],alpha=0.75)
line = mlines.Line2D([0, 1], [0, 1], color='red')
ax.add_line(line)
ax.set_xlim([0, 1])
ax.set_ylim([0, 1])
plt.xlabel('MultiVersion') 
plt.ylabel('TimeAware')
plt.savefig("experiment_timeaware_mrr.png",bbox_inches='tight')
plt.show()

# %%
data = pd.DataFrame()
data['Normal'] = data_mp['MAP_Broccoli']
data['Timeware'] = data_mp['MAP_TimeAware']
result = autorank(data, alpha=0.0125, verbose=False, approach='bayesian')
#print(result)
#data
data.style.apply(highlight_last_max,axis=1)
# Out:
# <style  type="text/css" >
# ...

# %%
latex_table(result)
latex_report(result)
# Out:
# \begin{table}[h]
# \centering
# \begin{tabular}{lrrlllrrl}
# \toprule
# {} &     M &    SD &              CI &   \$d\$ &   Magnitude &  $P(\textit{equal})$ &  $P(\textit{smaller})$ & Decision \\
# \midrule
# Normal   & 0.584 & 0.131 &  [0.517, 0.652] & 0.000 &  negligible &        - &          - &        - \\
# Timeware & 0.548 & 0.132 &  [0.480, 0.616] & 0.275 &       small &    0.000 &      1.000 &  smaller \\
# \bottomrule
# \end{tabular}
# \caption{Summary of populations}
# \label{tbl:stat_results}
# \end{table}
# \documentclass{article}
#
# \usepackage{graphicx}
# \usepackage{booktabs}
#
# \begin{document}
#
# \section{Results}
# \label{sec:results}
#
# The statistical analysis was conducted for 2 populations with 38 paired samples.
# The family-wise significance level of the tests $\alpha$=0.013.
# We failed to reject the null hypothesis that the population is normal for all populations (minimal observed p-value=0.716). Therefore, we assume that all populations are normal.
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import matplotlib.transforms as mtransforms

fig, ax = plt.subplots()
ax.scatter(data['Normal'], data['Timeware'],alpha=0.75)
line = mlines.Line2D([0, 1], [0, 1], color='red')
ax.add_line(line)
ax.set_xlim([0, 1])
ax.set_ylim([0, 1])
plt.xlabel('MultiVersion') 
plt.ylabel('TimeAware')
plt.savefig("experiment_timeaware_map.png",bbox_inches='tight')
plt.show()

# %% [markdown]
# ## HIT

# %%
data = pd.DataFrame()
data['Normal'] = data_mp['HIT1_Broccoli']
data['Timeware'] = data_mp['HIT1_TimeAware']
result = autorank(data, alpha=0.025, verbose=False)
#print(result)
#data
data.style.apply(highlight_last_max,axis=1)
# Out:
# <style  type="text/css" >
# ...

# %%
data = pd.DataFrame()
data['Normal'] = data_mp['HIT5_Broccoli']
data['Timeware'] = data_mp['HIT5_TimeAware']
result = autorank(data, alpha=0.025, verbose=False)
#print(result)
#data
data.style.apply(highlight_last_max,axis=1)
# Out:
# <style  type="text/css" >
# ...

# %%
data = pd.DataFrame()
data['Normal'] = data_mp['HIT10_Broccoli']
data['Timeware'] = data_mp['HIT10_TimeAware']
result = autorank(data, alpha=0.025, verbose=False)
#print(result)
#data
data.style.apply(highlight_last_max,axis=1)
# Out:
# <style  type="text/css" >
# ...
