# %%
def evaluate_for_key(key):
    resultData = pd.read_csv('results/' + key + '.csv')     
    bugs = resultData.bug.unique()
    print("Project " + key)
    print(len(bugs))
    count1 = 0;
    count5 = 0;
    count10 = 0;
    mapValue = 0;
    mrr = 0;
    for bug in bugs:
        subData = resultData[resultData['bug'] == bug]
        subDataSorted = subData.sort_values('Result2',ascending=False)
        
        if subDataSorted.iloc[0,-2] == 1:
            count1 += 1;
        if 1 in subDataSorted.values[0:5,-2]:
            count5 += 1;
        if 1 in subDataSorted.values[0:10,-2]:
            count10 += 1;
        
        summe = 0;
        rr = 0;
        retrieved_d = 0;
        i = 0
        c = 0
        for resultV in subDataSorted.values[:,-2]:
            if resultV == 1:
                c += 1
                retrieved_d += 1;
                summe += retrieved_d /(i+1)
            if resultV == 1 and rr == 0:    
                rr += (1/ (i+1))
            i += 1
        if c != 0:
            mapValue += (summe/c)
        else: 
            print("c zero!")
            mapValue +=0
            #rr = 1
        mrr += rr
    return count1/len(bugs),count5/len(bugs),count10/len(bugs),mapValue/len(bugs),mrr/len(bugs)

# %%
import os
import pandas as pd

data_mp = pd.read_csv('../statistic_smartshark.csv')
data_mp
# Out:
#                 Project Version  Bugs  Result
# 0    smartshark_ant-ivy   1.4.1    77     NaN
# 1    smartshark_ant-ivy   2.0.0   181     NaN
# 2    smartshark_ant-ivy   2.1.0    17     NaN
# 3    smartshark_ant-ivy   2.2.0    41     NaN
# 4    smartshark_ant-ivy   2.3.0    40     NaN
# ..                  ...     ...   ...     ...
# 393    smartshark_wss4j   1.5.0     2     NaN
# 394    smartshark_wss4j   1.6.0    45     NaN
# 395    smartshark_wss4j   2.0.0    53     NaN
# 396    smartshark_wss4j   2.1.0    29     NaN
# 397    smartshark_wss4j   2.2.0    21     NaN
#
# [398 rows x 4 columns]

# %%
import os
import pandas as pd

data_mp = pd.read_csv('../statistic_smartshark.csv')


data = pd.DataFrame()
for file in os.listdir("buglocator"):
    project, version = file.replace('smartshark_','').replace('_output.txt','').split("_")
    project = "smartshark_" + project
    print(project)
    print(version)
    element = data_mp.loc[(data_mp['Project'] == project) & (data_mp['Version'] == version), 'Bugs'].values[0]
    data = data.append({"project" : project, "version" : version, "bugs": element}, ignore_index=True)
# Out:
# smartshark_ant-ivy
# 1.4.1
# smartshark_ant-ivy
# 2.0.0
# smartshark_ant-ivy
# 2.1.0
# smartshark_ant-ivy
# 2.2.0
# smartshark_ant-ivy
# 2.3.0
# smartshark_ant-ivy
# 2.4.0
# smartshark_archiva
# 1.0
# smartshark_archiva
# 1.1
# smartshark_archiva
# 1.2
# smartshark_archiva
# 1.3
# smartshark_archiva
# 2.0.0
# smartshark_archiva
# 2.1.0
# smartshark_archiva
# 2.2.0
# smartshark_calcite
# 1.0.0
# smartshark_calcite
# 1.1.0
# smartshark_calcite
# 1.10.0
# smartshark_calcite
# 1.11.0
# smartshark_calcite
# 1.12.0
# smartshark_calcite
# 1.13.0
# smartshark_calcite
# 1.14.0
# smartshark_calcite
# 1.15.0
# smartshark_calcite
# 1.2.0
# smartshark_calcite
# 1.3.0
# smartshark_calcite
# 1.4.0
# smartshark_calcite
# 1.5.0
# smartshark_calcite
# 1.6.0
# smartshark_calcite
# 1.7.0
# smartshark_calcite
# 1.8.0
# smartshark_calcite
# 1.9.0
# smartshark_cayenne
# 3.0.0
# smartshark_cayenne
# 3.1.0
# smartshark_commons-bcel
# 5.0
# smartshark_commons-bcel
# 5.1
# smartshark_commons-bcel
# 5.2
# smartshark_commons-bcel
# 6.0
# smartshark_commons-bcel
# 6.1
# smartshark_commons-bcel
# 6.2
# smartshark_commons-beanutils
# 1.0
# smartshark_commons-beanutils
# 1.1
# smartshark_commons-beanutils
# 1.2
# smartshark_commons-beanutils
# 1.3
# smartshark_commons-beanutils
# 1.4
# smartshark_commons-beanutils
# 1.5
# smartshark_commons-beanutils
# 1.6
# smartshark_commons-beanutils
# 1.7.0
# smartshark_commons-beanutils
# 1.8.0
# smartshark_commons-beanutils
# 1.9.0
# smartshark_commons-codec
# 1.10
# smartshark_commons-codec
# 1.11
# smartshark_commons-codec
# 1.1
# smartshark_commons-codec
# 1.2
# smartshark_commons-codec
# 1.3
# smartshark_commons-codec
# 1.4
# smartshark_commons-codec
# 1.5
# smartshark_commons-codec
# 1.6
# smartshark_commons-codec
# 1.7
# smartshark_commons-codec
# 1.8
# smartshark_commons-codec
# 1.9
# smartshark_commons-collections
# 1.0
# smartshark_commons-collections
# 2.0
# smartshark_commons-collections
# 2.1
# smartshark_commons-collections
# 3.0
# smartshark_commons-collections
# 3.1
# smartshark_commons-collections
# 3.2
# smartshark_commons-collections
# 3.3
# smartshark_commons-collections
# 4.0
# smartshark_commons-collections
# 4.1
# smartshark_commons-compress
# 1.0
# smartshark_commons-compress
# 1.10
# smartshark_commons-compress
# 1.11
# smartshark_commons-compress
# 1.12
# smartshark_commons-compress
# 1.13
# smartshark_commons-compress
# 1.14
# smartshark_commons-compress
# 1.15
# smartshark_commons-compress
# 1.16
# smartshark_commons-compress
# 1.1
# smartshark_commons-compress
# 1.2
# smartshark_commons-compress
# 1.3
# smartshark_commons-compress
# 1.4
# smartshark_commons-compress
# 1.5
# smartshark_commons-compress
# 1.6
# smartshark_commons-compress
# 1.7
# smartshark_commons-compress
# 1.8
# smartshark_commons-compress
# 1.9
# smartshark_commons-configuration
# 1.0
# smartshark_commons-configuration
# 1.10
# smartshark_commons-configuration
# 1.1
# smartshark_commons-configuration
# 1.2
# smartshark_commons-configuration
# 1.3
# smartshark_commons-configuration
# 1.4
# smartshark_commons-configuration
# 1.5
# smartshark_commons-configuration
# 1.6
# smartshark_commons-configuration
# 1.7
# smartshark_commons-configuration
# 1.8
# smartshark_commons-configuration
# 1.9
# smartshark_commons-configuration
# 2.0
# smartshark_commons-configuration
# 2.1
# smartshark_commons-configuration
# 2.2
# smartshark_commons-dbcp
# 1.0
# smartshark_commons-dbcp
# 1.1
# smartshark_commons-dbcp
# 1.2
# smartshark_commons-dbcp
# 1.3
# smartshark_commons-dbcp
# 1.4
# smartshark_commons-dbcp
# 2.0
# smartshark_commons-dbcp
# 2.1
# smartshark_commons-dbcp
# 2.2.0
# smartshark_commons-dbcp
# 2.3.0
# smartshark_commons-dbcp
# 2.4.0
# smartshark_commons-dbcp
# 2.5.0
# smartshark_commons-digester
# 1.0
# smartshark_commons-digester
# 1.1
# smartshark_commons-digester
# 1.2
# smartshark_commons-digester
# 1.3
# smartshark_commons-digester
# 1.4
# smartshark_commons-digester
# 1.5
# smartshark_commons-digester
# 1.6
# smartshark_commons-digester
# 1.7
# smartshark_commons-digester
# 1.8
# smartshark_commons-digester
# 2.0
# smartshark_commons-digester
# 2.1
# smartshark_commons-digester
# 3.0
# smartshark_commons-digester
# 3.1
# smartshark_commons-digester
# 3.2
# smartshark_commons-io
# 1.0
# smartshark_commons-io
# 1.1
# smartshark_commons-io
# 1.2
# smartshark_commons-io
# 1.3
# smartshark_commons-io
# 1.4
# smartshark_commons-io
# 2.0
# smartshark_commons-io
# 2.1
# smartshark_commons-io
# 2.2
# smartshark_commons-io
# 2.3
# smartshark_commons-io
# 2.4
# smartshark_commons-io
# 2.5
# smartshark_commons-jcs
# 1.0
# smartshark_commons-jcs
# 1.1
# smartshark_commons-jcs
# 1.3
# smartshark_commons-jcs
# 2.0
# smartshark_commons-jcs
# 2.1
# smartshark_commons-jcs
# 2.2
# smartshark_commons-jexl
# 1.0
# smartshark_commons-jexl
# 1.1
# smartshark_commons-jexl
# 2.0
# smartshark_commons-jexl
# 2.1
# smartshark_commons-jexl
# 3.0
# smartshark_commons-jexl
# 3.1
# smartshark_commons-lang
# 1.0
# smartshark_commons-lang
# 2.0
# smartshark_commons-lang
# 2.1
# smartshark_commons-lang
# 2.2
# smartshark_commons-lang
# 2.3
# smartshark_commons-lang
# 2.4
# smartshark_commons-lang
# 2.5
# smartshark_commons-lang
# 2.6
# smartshark_commons-lang
# 3.0
# smartshark_commons-lang
# 3.1
# smartshark_commons-lang
# 3.2
# smartshark_commons-lang
# 3.3
# smartshark_commons-lang
# 3.4
# smartshark_commons-lang
# 3.5
# smartshark_commons-lang
# 3.6
# smartshark_commons-lang
# 3.7
# smartshark_commons-math
# 1.0
# smartshark_commons-math
# 1.1
# smartshark_commons-math
# 1.2
# smartshark_commons-math
# 2.0
# smartshark_commons-math
# 2.1
# smartshark_commons-math
# 2.2
# smartshark_commons-math
# 3.0
# smartshark_commons-math
# 3.1
# smartshark_commons-math
# 3.2
# smartshark_commons-math
# 3.3
# smartshark_commons-math
# 3.4
# smartshark_commons-math
# 3.5
# smartshark_commons-math
# 3.6
# smartshark_commons-net
# 1.0.0
# smartshark_commons-net
# 1.1.0
# smartshark_commons-net
# 1.2.0
# smartshark_commons-net
# 1.3.0
# smartshark_commons-net
# 1.4.0
# smartshark_commons-net
# 2.0
# smartshark_commons-net
# 2.1
# smartshark_commons-net
# 2.2
# smartshark_commons-net
# 3.0
# smartshark_commons-net
# 3.1
# smartshark_commons-net
# 3.2
# smartshark_commons-net
# 3.3
# smartshark_commons-net
# 3.4
# smartshark_commons-net
# 3.5
# smartshark_commons-net
# 3.6
# smartshark_commons-scxml
# 0.5
# smartshark_commons-scxml
# 0.6
# smartshark_commons-scxml
# 0.7
# smartshark_commons-scxml
# 0.8
# smartshark_commons-scxml
# 0.9
# smartshark_commons-validator
# 1.0
# smartshark_commons-validator
# 1.1.0
# smartshark_commons-validator
# 1.2.0
# smartshark_commons-validator
# 1.3.0
# smartshark_commons-validator
# 1.4.0
# smartshark_commons-validator
# 1.5.0
# smartshark_commons-validator
# 1.6.0
# smartshark_commons-vfs
# 1.0
# smartshark_commons-vfs
# 2.0
# smartshark_commons-vfs
# 2.1
# smartshark_commons-vfs
# 2.2
# smartshark_deltaspike
# 0.1
# smartshark_deltaspike
# 0.2
# smartshark_deltaspike
# 0.3
# smartshark_deltaspike
# 0.4
# smartshark_deltaspike
# 0.5
# smartshark_deltaspike
# 0.6
# smartshark_deltaspike
# 0.7
# smartshark_deltaspike
# 1.0.0
# smartshark_deltaspike
# 1.1.0
# smartshark_deltaspike
# 1.2.0
# smartshark_deltaspike
# 1.3.0
# smartshark_deltaspike
# 1.4.0
# smartshark_deltaspike
# 1.5.0
# smartshark_deltaspike
# 1.6.0
# smartshark_deltaspike
# 1.7.0
# smartshark_deltaspike
# 1.8.0
# smartshark_eagle
# 0.3.0
# smartshark_eagle
# 0.4.0
# smartshark_eagle
# 0.5.0
# smartshark_giraph
# 0.1.0
# smartshark_giraph
# 1.0.0
# smartshark_giraph
# 1.1.0
# smartshark_gora
# 0.1
# smartshark_gora
# 0.2
# smartshark_gora
# 0.3
# smartshark_gora
# 0.4
# smartshark_gora
# 0.5
# smartshark_gora
# 0.6
# smartshark_gora
# 0.7
# smartshark_gora
# 0.8
# smartshark_jspwiki
# 1.4.0
# smartshark_jspwiki
# 1.5.0
# smartshark_jspwiki
# 1.6.0
# smartshark_jspwiki
# 1.7.0
# smartshark_jspwiki
# 1.8.0
# smartshark_jspwiki
# 2.0.36
# smartshark_jspwiki
# 2.10.0
# smartshark_jspwiki
# 2.2.19
# smartshark_jspwiki
# 2.4.56
# smartshark_jspwiki
# 2.6.0
# smartshark_jspwiki
# 2.8.0
# smartshark_jspwiki
# 2.9.0
# smartshark_knox
# 0.10.0
# smartshark_knox
# 0.11.0
# smartshark_knox
# 0.12.0
# smartshark_knox
# 0.13.0
# smartshark_knox
# 0.14.0
# smartshark_knox
# 0.3.0
# smartshark_knox
# 0.4.0
# smartshark_knox
# 0.5.0
# smartshark_knox
# 0.6.0
# smartshark_knox
# 0.7.0
# smartshark_knox
# 0.8.0
# smartshark_knox
# 0.9.0
# smartshark_knox
# 1.0.0
# smartshark_kylin
# 0.6.1
# smartshark_kylin
# 0.7.1
# smartshark_kylin
# 1.0
# smartshark_kylin
# 1.1
# smartshark_kylin
# 1.2
# smartshark_kylin
# 1.3
# smartshark_kylin
# 1.5.0
# smartshark_kylin
# 1.6.0
# smartshark_kylin
# 2.0.0
# smartshark_kylin
# 2.1.0
# smartshark_kylin
# 2.2.0
# smartshark_lens
# 2.6.0
# smartshark_lens
# 2.7.0
# smartshark_mahout
# 0.10.0
# smartshark_mahout
# 0.11.0
# smartshark_mahout
# 0.12.0
# smartshark_mahout
# 0.13.0
# smartshark_mahout
# 0.1
# smartshark_mahout
# 0.2
# smartshark_mahout
# 0.3
# smartshark_mahout
# 0.4
# smartshark_mahout
# 0.5
# smartshark_mahout
# 0.6
# smartshark_mahout
# 0.7
# smartshark_mahout
# 0.8
# smartshark_mahout
# 0.9
# smartshark_manifoldcf
# 0.4
# smartshark_manifoldcf
# 0.5
# smartshark_manifoldcf
# 0.6
# smartshark_manifoldcf
# 1.0
# smartshark_manifoldcf
# 1.10
# smartshark_manifoldcf
# 1.1
# smartshark_manifoldcf
# 1.2
# smartshark_manifoldcf
# 1.3
# smartshark_manifoldcf
# 1.4
# smartshark_manifoldcf
# 1.5
# smartshark_manifoldcf
# 1.6
# smartshark_manifoldcf
# 1.7
# smartshark_manifoldcf
# 1.8
# smartshark_manifoldcf
# 1.9
# smartshark_manifoldcf
# 2.0
# smartshark_manifoldcf
# 2.10
# smartshark_manifoldcf
# 2.1
# smartshark_manifoldcf
# 2.2
# smartshark_manifoldcf
# 2.3
# smartshark_manifoldcf
# 2.4
# smartshark_manifoldcf
# 2.5
# smartshark_manifoldcf
# 2.6
# smartshark_manifoldcf
# 2.7
# smartshark_manifoldcf
# 2.8
# smartshark_manifoldcf
# 2.9
# smartshark_nutch
# 0.7
# smartshark_nutch
# 0.8
# smartshark_nutch
# 0.9
# smartshark_nutch
# 1.0
# smartshark_nutch
# 1.10
# smartshark_nutch
# 1.11
# smartshark_nutch
# 1.12
# smartshark_nutch
# 1.13
# smartshark_nutch
# 1.14
# smartshark_nutch
# 1.1
# smartshark_nutch
# 1.2
# smartshark_nutch
# 1.3
# smartshark_nutch
# 1.4
# smartshark_nutch
# 1.5
# smartshark_nutch
# 1.6
# smartshark_nutch
# 1.7
# smartshark_nutch
# 1.8
# smartshark_nutch
# 1.9
# smartshark_nutch
# 2.0
# smartshark_nutch
# 2.1
# smartshark_nutch
# 2.2
# smartshark_nutch
# 2.3
# smartshark_opennlp
# 1.7.0
# smartshark_opennlp
# 1.8.0
# smartshark_parquet-mr
# 1.0.0
# smartshark_parquet-mr
# 1.1.0
# smartshark_parquet-mr
# 1.2.0
# smartshark_parquet-mr
# 1.3.0
# smartshark_parquet-mr
# 1.4.0
# smartshark_parquet-mr
# 1.5.0
# smartshark_parquet-mr
# 1.6.0
# smartshark_parquet-mr
# 1.7.0
# smartshark_parquet-mr
# 1.8.0
# smartshark_parquet-mr
# 1.9.0
# smartshark_santuario-java
# 1.0.0
# smartshark_santuario-java
# 1.2
# smartshark_santuario-java
# 1.4.5
# smartshark_santuario-java
# 1.5.9
# smartshark_santuario-java
# 2.0.0
# smartshark_santuario-java
# 2.1.0
# smartshark_systemml
# 0.10
# smartshark_systemml
# 0.11
# smartshark_systemml
# 0.12
# smartshark_systemml
# 0.13
# smartshark_systemml
# 0.14
# smartshark_systemml
# 0.15
# smartshark_systemml
# 0.9
# smartshark_systemml
# 1.0.0
# smartshark_systemml
# 1.1.0
# smartshark_systemml
# 1.2.0
# smartshark_tika
# 0.10
# smartshark_tika
# 0.1
# smartshark_tika
# 0.2
# smartshark_tika
# 0.3
# smartshark_tika
# 0.4
# smartshark_tika
# 0.5
# smartshark_tika
# 0.6
# smartshark_tika
# 0.7
# smartshark_tika
# 0.8
# smartshark_tika
# 0.9
# smartshark_tika
# 1.0
# smartshark_tika
# 1.10
# smartshark_tika
# 1.11
# smartshark_tika
# 1.12
# smartshark_tika
# 1.13
# smartshark_tika
# 1.14
# smartshark_tika
# 1.15
# smartshark_tika
# 1.16
# smartshark_tika
# 1.17
# smartshark_tika
# 1.1
# smartshark_tika
# 1.2
# smartshark_tika
# 1.3
# smartshark_tika
# 1.4
# smartshark_tika
# 1.5
# smartshark_tika
# 1.6
# smartshark_tika
# 1.7
# smartshark_tika
# 1.8
# smartshark_tika
# 1.9
# smartshark_wss4j
# 1.5.0
# smartshark_wss4j
# 1.6.0
# smartshark_wss4j
# 2.0.0
# smartshark_wss4j
# 2.1.0
# smartshark_wss4j
# 2.2.0

# %%
agg_funcs = {'bugs' : 'sum', 
         'version' : 'count'
}

data = data.groupby("project").agg(agg_funcs)
data
# Out:
#                                    bugs  version
# project
# smartshark_ant-ivy                374.0        6
# smartshark_archiva                214.0        7
# smartshark_calcite                306.0       16
# smartshark_cayenne                242.0        2
# smartshark_commons-bcel            28.0        6
# smartshark_commons-beanutils       24.0       10
# smartshark_commons-codec           30.0       11
# smartshark_commons-collections     41.0        9
# smartshark_commons-compress       106.0       17
# smartshark_commons-configuration  123.0       14
# smartshark_commons-dbcp            65.0       11
# smartshark_commons-digester         6.0       14
# smartshark_commons-io              45.0       11
# smartshark_commons-jcs             54.0        6
# smartshark_commons-jexl            45.0        6
# smartshark_commons-lang           143.0       16
# smartshark_commons-math           204.0       13
# smartshark_commons-net            117.0       15
# smartshark_commons-scxml           17.0        5
# smartshark_commons-validator       45.0        7
# smartshark_commons-vfs             84.0        4
# smartshark_deltaspike             118.0       16
# smartshark_eagle                  100.0        3
# smartshark_giraph                 109.0        3
# smartshark_gora                    51.0        8
# smartshark_jspwiki                119.0       12
# smartshark_knox                   124.0       13
# smartshark_kylin                  279.0       11
# smartshark_lens                   184.0        2
# smartshark_mahout                 222.0       13
# smartshark_manifoldcf             262.0       25
# smartshark_nutch                  376.0       22
# smartshark_opennlp                 87.0        2
# smartshark_parquet-mr              49.0       10
# smartshark_santuario-java          47.0        6
# smartshark_systemml               258.0       10
# smartshark_tika                   320.0       28
# smartshark_wss4j                  150.0        5

# %%
from pandas.errors import EmptyDataError

def evaluateForAlgo(base):
    data_map = dict()
    data_mrr = dict()
    data_hit1 = dict()
    data_hit5 = dict()
    data_hit10 = dict()
    
    for file in os.listdir(base):
        project, version = file.replace('smartshark_','').replace('_output.txt','').split("_")
        project = 'smartshark_' +  project
        if project not in data_map:
            data_map[project] = 0
            data_mrr[project] = 0
            data_hit1[project] = 0
            data_hit5[project] = 0
            data_hit10[project] = 0
        try:
            data_mp = pd.read_csv(base + "/" + file, header=None,delim_whitespace=True)  
            a_group = data_mp.groupby(0)
            for name, group in a_group:
                rr = 0;
                
                summe = 0;
                retrieved_d = 0;   
                c = 0
                best_value = -1;
                for index, element in group.iterrows():
                    if element[2] < best_value or best_value == -1:
                        best_value = element[2]
                    c += 1
                    retrieved_d += 1;
                    summe += retrieved_d /(element[2]+1)
                if best_value != -1:
                    data_mrr[project] += (1/ (best_value+1))
                data_map[project] += (summe/c)
                
                # These outputs are zero based!
                if best_value != -1 and best_value <= 0:
                    data_hit1[project] += 1
                if best_value != -1 and best_value <= 4:
                    data_hit5[project] += 1
                if best_value != -1 and best_value <= 9:
                    data_hit10[project] += 1
        except EmptyDataError:
             data_mp = pd.DataFrame()
    

    #data_mrr[project] = (1/ (data_mp[2]+1))    
    #print(data_mp)
    #c += 1
    #retrieved_d += 1;
    #summe += retrieved_d /(i+1)
    data['MAP_' + base] = pd.Series(data_map)  /data["bugs"]
    data['MRR_' + base] =  pd.Series(data_mrr) / data["bugs"]
    data['HIT1_' + base] =  pd.Series(data_hit1)  / data["bugs"]
    data['HIT5_' + base] =  pd.Series(data_hit5) / data["bugs"]
    data['HIT10_' + base] =  pd.Series(data_hit10) / data["bugs"]

# %%
evaluateForAlgo('buglocator')
evaluateForAlgo('bluir')
evaluateForAlgo('brtracer')
evaluateForAlgo('amalgam')
evaluateForAlgo('blia')
evaluateForAlgo('locus')
evaluateForAlgo('blizzard')
data.to_csv('results_other.csv')
data
# Out:
#                                    bugs  version  MAP_buglocator  \
# project
# smartshark_ant-ivy                374.0        6        0.390238
# smartshark_archiva                214.0        7        0.205291
# smartshark_calcite                306.0       16        0.362004
# smartshark_cayenne                242.0        2        0.289970
# smartshark_commons-bcel            28.0        6        0.335842
# smartshark_commons-beanutils       24.0       10        0.515891
# smartshark_commons-codec           30.0       11        0.660454
# smartshark_commons-collections     41.0        9        0.209991
# smartshark_commons-compress       106.0       17        0.589493
# smartshark_commons-configuration  123.0       14        0.509977
# smartshark_commons-dbcp            65.0       11        0.362946
# smartshark_commons-digester         6.0       14        0.583333
# smartshark_commons-io              45.0       11        0.804999
# smartshark_commons-jcs             54.0        6        0.303888
# smartshark_commons-jexl            45.0        6        0.254857
# smartshark_commons-lang           143.0       16        0.577554
# smartshark_commons-math           204.0       13        0.366663
# smartshark_commons-net            117.0       15        0.757696
# smartshark_commons-scxml           17.0        5        0.398328
# smartshark_commons-validator       45.0        7        0.634593
# smartshark_commons-vfs             84.0        4        0.336728
# smartshark_deltaspike             118.0       16        0.436944
# smartshark_eagle                  100.0        3        0.248688
# smartshark_giraph                 109.0        3        0.385187
# smartshark_gora                    51.0        8        0.568033
# smartshark_jspwiki                119.0       12        0.084489
# smartshark_knox                   124.0       13        0.387693
# smartshark_kylin                  279.0       11        0.367787
# smartshark_lens                   184.0        2        0.300424
# smartshark_mahout                 222.0       13        0.504056
# smartshark_manifoldcf             262.0       25        0.445142
# smartshark_nutch                  376.0       22        0.453102
# smartshark_opennlp                 87.0        2        0.467758
# smartshark_parquet-mr              49.0       10        0.472863
# smartshark_santuario-java          47.0        6        0.490680
# smartshark_systemml               258.0       10        0.223307
# smartshark_tika                   320.0       28        0.463094
# smartshark_wss4j                  150.0        5        0.262678
#
#                                   MRR_buglocator  HIT1_buglocator  \
# project
# smartshark_ant-ivy                      0.507787         0.350267
# smartshark_archiva                      0.314665         0.200935
# smartshark_calcite                      0.573255         0.434641
# smartshark_cayenne                      0.410786         0.280992
# smartshark_commons-bcel                 0.450298         0.357143
# smartshark_commons-beanutils            0.708285         0.625000
# smartshark_commons-codec                0.877500         0.800000
# smartshark_commons-collections          0.294715         0.268293
# smartshark_commons-compress             0.741259         0.613208
# smartshark_commons-configuration        0.667532         0.560976
# smartshark_commons-dbcp                 0.448418         0.338462
# smartshark_commons-digester             0.583333         0.333333
# smartshark_commons-io                   0.890598         0.822222
# smartshark_commons-jcs                  0.397585         0.333333
# smartshark_commons-jexl                 0.405581         0.333333
# smartshark_commons-lang                 0.727030         0.608392
# smartshark_commons-math                 0.502379         0.431373
# smartshark_commons-net                  0.830534         0.752137
# smartshark_commons-scxml                0.525560         0.352941
# smartshark_commons-validator            0.745397         0.622222
# smartshark_commons-vfs                  0.404811         0.345238
# smartshark_deltaspike                   0.520585         0.389831
# smartshark_eagle                        0.372153         0.250000
# smartshark_giraph                       0.480869         0.366972
# smartshark_gora                         0.657885         0.509804
# smartshark_jspwiki                      0.123673         0.100840
# smartshark_knox                         0.511557         0.370968
# smartshark_kylin                        0.448951         0.326165
# smartshark_lens                         0.480496         0.375000
# smartshark_mahout                       0.636575         0.522523
# smartshark_manifoldcf                   0.534746         0.400763
# smartshark_nutch                        0.510856         0.406915
# smartshark_opennlp                      0.541031         0.413793
# smartshark_parquet-mr                   0.645096         0.571429
# smartshark_santuario-java               0.597219         0.510638
# smartshark_systemml                     0.342008         0.224806
# smartshark_tika                         0.616276         0.484375
# smartshark_wss4j                        0.323039         0.253333
#
#                                   HIT5_buglocator  HIT10_buglocator  \
# project
# smartshark_ant-ivy                       0.703209          0.812834
# smartshark_archiva                       0.425234          0.560748
# smartshark_calcite                       0.748366          0.849673
# smartshark_cayenne                       0.545455          0.657025
# smartshark_commons-bcel                  0.607143          0.642857
# smartshark_commons-beanutils             0.791667          0.875000
# smartshark_commons-codec                 0.966667          1.000000
# smartshark_commons-collections           0.341463          0.341463
# smartshark_commons-compress              0.905660          0.971698
# smartshark_commons-configuration         0.813008          0.829268
# smartshark_commons-dbcp                  0.600000          0.630769
# smartshark_commons-digester              0.833333          0.833333
# smartshark_commons-io                    0.977778          0.977778
# smartshark_commons-jcs                   0.462963          0.500000
# smartshark_commons-jexl                  0.511111          0.555556
# smartshark_commons-lang                  0.888112          0.916084
# smartshark_commons-math                  0.602941          0.627451
# smartshark_commons-net                   0.931624          0.965812
# smartshark_commons-scxml                 0.823529          1.000000
# smartshark_commons-validator             0.933333          0.977778
# smartshark_commons-vfs                   0.488095          0.523810
# smartshark_deltaspike                    0.661017          0.771186
# smartshark_eagle                         0.520000          0.620000
# smartshark_giraph                        0.614679          0.669725
# smartshark_gora                          0.862745          0.921569
# smartshark_jspwiki                       0.151261          0.184874
# smartshark_knox                          0.685484          0.766129
# smartshark_kylin                         0.620072          0.691756
# smartshark_lens                          0.603261          0.744565
# smartshark_mahout                        0.774775          0.806306
# smartshark_manifoldcf                    0.694656          0.805344
# smartshark_nutch                         0.640957          0.686170
# smartshark_opennlp                       0.724138          0.793103
# smartshark_parquet-mr                    0.693878          0.775510
# smartshark_santuario-java                0.723404          0.765957
# smartshark_systemml                      0.476744          0.593023
# smartshark_tika                          0.762500          0.856250
# smartshark_wss4j                         0.393333          0.440000
#
#                                   MAP_bluir  MRR_bluir  HIT1_bluir  ...  \
# project                                                             ...
# smartshark_ant-ivy                 0.452082   0.447456    0.326203  ...
# smartshark_archiva                 0.309811   0.301384    0.191589  ...
# smartshark_calcite                 0.482388   0.487828    0.369281  ...
# smartshark_cayenne                 0.320181   0.349688    0.247934  ...
# smartshark_commons-bcel            0.255740   0.251786    0.178571  ...
# smartshark_commons-beanutils       0.549294   0.609552    0.541667  ...
# smartshark_commons-codec           0.682252   0.760008    0.700000  ...
# smartshark_commons-collections     0.192485   0.238328    0.219512  ...
# smartshark_commons-compress        0.526409   0.579104    0.490566  ...
# smartshark_commons-configuration   0.495816   0.510190    0.447154  ...
# smartshark_commons-dbcp            0.265410   0.276410    0.215385  ...
# smartshark_commons-digester        0.513889   0.500000    0.333333  ...
# smartshark_commons-io              0.625472   0.648783    0.600000  ...
# smartshark_commons-jcs             0.198352   0.206041    0.166667  ...
# smartshark_commons-jexl            0.309314   0.265904    0.177778  ...
# smartshark_commons-lang            0.508108   0.528144    0.447552  ...
# smartshark_commons-math            0.344365   0.353266    0.284314  ...
# smartshark_commons-net             0.647473   0.626864    0.555556  ...
# smartshark_commons-scxml           0.547092   0.474157    0.294118  ...
# smartshark_commons-validator       0.690180   0.675212    0.577778  ...
# smartshark_commons-vfs             0.335355   0.357395    0.309524  ...
# smartshark_deltaspike              0.316029   0.312629    0.245763  ...
# smartshark_eagle                   0.296099   0.294178    0.180000  ...
# smartshark_giraph                  0.219029   0.229035    0.174312  ...
# smartshark_gora                    0.401889   0.391488    0.294118  ...
# smartshark_jspwiki                 0.077290   0.073212    0.058824  ...
# smartshark_knox                    0.442024   0.457785    0.354839  ...
# smartshark_kylin                   0.331271   0.322363    0.240143  ...
# smartshark_lens                    0.321388   0.328536    0.250000  ...
# smartshark_mahout                  0.456864   0.463299    0.369369  ...
# smartshark_manifoldcf              0.585691   0.578284    0.446565  ...
# smartshark_nutch                   0.412601   0.412224    0.335106  ...
# smartshark_opennlp                 0.439160   0.430390    0.344828  ...
# smartshark_parquet-mr              0.442623   0.442167    0.367347  ...
# smartshark_santuario-java          0.501296   0.464933    0.404255  ...
# smartshark_systemml                0.275636   0.293698    0.201550  ...
# smartshark_tika                    0.550030   0.558498    0.456250  ...
# smartshark_wss4j                   0.189150   0.192375    0.146667  ...
#
#                                   MAP_locus  MRR_locus  HIT1_locus  \
# project
# smartshark_ant-ivy                 0.371438   0.464967    0.331551
# smartshark_archiva                 0.179104   0.269727    0.168224
# smartshark_calcite                 0.300452   0.475130    0.336601
# smartshark_cayenne                 0.182501   0.269904    0.198347
# smartshark_commons-bcel            0.232546   0.279258    0.178571
# smartshark_commons-beanutils       0.260726   0.371895    0.291667
# smartshark_commons-codec           0.446427   0.582764    0.500000
# smartshark_commons-collections     0.136678   0.159972    0.121951
# smartshark_commons-compress        0.380591   0.512839    0.358491
# smartshark_commons-configuration   0.334939   0.428548    0.308943
# smartshark_commons-dbcp            0.210462   0.286095    0.200000
# smartshark_commons-digester        0.027778   0.027778    0.000000
# smartshark_commons-io              0.251659   0.277409    0.177778
# smartshark_commons-jcs             0.169063   0.201739    0.148148
# smartshark_commons-jexl            0.241374   0.383866    0.288889
# smartshark_commons-lang            0.393276   0.472469    0.391608
# smartshark_commons-math            0.217015   0.267318    0.200980
# smartshark_commons-net             0.574736   0.611000    0.504274
# smartshark_commons-scxml           0.260388   0.378175    0.235294
# smartshark_commons-validator       0.455882   0.494762    0.355556
# smartshark_commons-vfs             0.023923   0.023923    0.023810
# smartshark_deltaspike              0.264562   0.319387    0.186441
# smartshark_eagle                   0.216504   0.311256    0.190000
# smartshark_giraph                  0.270718   0.305481    0.192661
# smartshark_gora                    0.363479   0.416824    0.274510
# smartshark_jspwiki                 0.074270   0.088165    0.058824
# smartshark_knox                    0.305243   0.405056    0.258065
# smartshark_kylin                   0.272751   0.332273    0.218638
# smartshark_lens                    0.261586   0.408012    0.260870
# smartshark_mahout                  0.225595   0.280598    0.184685
# smartshark_manifoldcf              0.544708   0.650394    0.530534
# smartshark_nutch                   0.372920   0.430201    0.340426
# smartshark_opennlp                 0.318779   0.382945    0.275862
# smartshark_parquet-mr              0.208646   0.259887    0.163265
# smartshark_santuario-java          0.400176   0.472031    0.361702
# smartshark_systemml                0.244510   0.354479    0.220930
# smartshark_tika                    0.306794   0.376991    0.265625
# smartshark_wss4j                   0.099424   0.117347    0.080000
#
#                                   HIT5_locus  HIT10_locus  MAP_blizzard  \
# project
# smartshark_ant-ivy                  0.647059     0.754011      0.332016
# smartshark_archiva                  0.383178     0.514019      0.283810
# smartshark_calcite                  0.650327     0.741830      0.661462
# smartshark_cayenne                  0.318182     0.450413      0.318740
# smartshark_commons-bcel             0.357143     0.464286      0.343043
# smartshark_commons-beanutils        0.541667     0.541667      0.638323
# smartshark_commons-codec            0.666667     0.733333      0.998113
# smartshark_commons-collections      0.219512     0.219512      0.400831
# smartshark_commons-compress         0.688679     0.820755      0.498699
# smartshark_commons-configuration    0.601626     0.731707      0.498954
# smartshark_commons-dbcp             0.369231     0.430769      0.372420
# smartshark_commons-digester         0.000000     0.166667      0.465152
# smartshark_commons-io               0.377778     0.422222      0.724632
# smartshark_commons-jcs              0.277778     0.277778      0.241268
# smartshark_commons-jexl             0.533333     0.555556      0.299008
# smartshark_commons-lang             0.594406     0.643357      0.832636
# smartshark_commons-math             0.367647     0.401961      0.425798
# smartshark_commons-net              0.769231     0.820513      0.570368
# smartshark_commons-scxml            0.470588     0.823529      0.451146
# smartshark_commons-validator        0.688889     0.777778      0.537459
# smartshark_commons-vfs              0.023810     0.023810      0.347959
# smartshark_deltaspike               0.449153     0.559322      0.433986
# smartshark_eagle                    0.480000     0.580000      0.320228
# smartshark_giraph                   0.422018     0.522936      0.561540
# smartshark_gora                     0.647059     0.725490      0.587114
# smartshark_jspwiki                  0.126050     0.142857      0.095989
# smartshark_knox                     0.580645     0.717742      0.593351
# smartshark_kylin                    0.458781     0.569892      0.318255
# smartshark_lens                     0.554348     0.679348      0.371659
# smartshark_mahout                   0.391892     0.463964      0.487345
# smartshark_manifoldcf               0.793893     0.881679      0.476083
# smartshark_nutch                    0.521277     0.614362      0.443553
# smartshark_opennlp                  0.482759     0.586207      0.478717
# smartshark_parquet-mr               0.346939     0.489796      0.508280
# smartshark_santuario-java           0.595745     0.659574      0.449190
# smartshark_systemml                 0.519380     0.616279      0.343453
# smartshark_tika                     0.525000     0.615625      0.520047
# smartshark_wss4j                    0.160000     0.206667      0.227173
#
#                                   MRR_blizzard  HIT1_blizzard  HIT5_blizzard  \
# project
# smartshark_ant-ivy                    0.329682            0.0       0.754011
# smartshark_archiva                    0.282379            0.0       0.640187
# smartshark_calcite                    0.644654            0.0       1.460784
# smartshark_cayenne                    0.314903            0.0       0.727273
# smartshark_commons-bcel               0.335531            0.0       0.750000
# smartshark_commons-beanutils          0.626786            0.0       1.541667
# smartshark_commons-codec              0.973333            0.0       2.200000
# smartshark_commons-collections        0.386364            0.0       0.853659
# smartshark_commons-compress           0.506443            0.0       1.094340
# smartshark_commons-configuration      0.477607            0.0       1.048780
# smartshark_commons-dbcp               0.373523            0.0       0.892308
# smartshark_commons-digester           0.459596            0.0       0.833333
# smartshark_commons-io                 0.706147            0.0       1.466667
# smartshark_commons-jcs                0.244312            0.0       0.537037
# smartshark_commons-jexl               0.275767            0.0       0.600000
# smartshark_commons-lang               0.795724            0.0       1.685315
# smartshark_commons-math               0.423640            0.0       0.970588
# smartshark_commons-net                0.563316            0.0       1.230769
# smartshark_commons-scxml              0.453175            0.0       1.058824
# smartshark_commons-validator          0.516296            0.0       1.177778
# smartshark_commons-vfs                0.344450            0.0       0.738095
# smartshark_deltaspike                 0.427129            0.0       1.000000
# smartshark_eagle                      0.325775            0.0       0.700000
# smartshark_giraph                     0.552878            0.0       1.266055
# smartshark_gora                       0.575475            0.0       1.372549
# smartshark_jspwiki                    0.093277            0.0       0.210084
# smartshark_knox                       0.583696            0.0       1.338710
# smartshark_kylin                      0.316579            0.0       0.698925
# smartshark_lens                       0.374882            0.0       0.864130
# smartshark_mahout                     0.482755            0.0       1.094595
# smartshark_manifoldcf                 0.463938            0.0       1.087786
# smartshark_nutch                      0.442079            0.0       0.986702
# smartshark_opennlp                    0.479977            0.0       1.126437
# smartshark_parquet-mr                 0.516109            0.0       1.122449
# smartshark_santuario-java             0.454974            0.0       1.000000
# smartshark_systemml                   0.349762            0.0       0.821705
# smartshark_tika                       0.513870            0.0       1.137500
# smartshark_wss4j                      0.228257            0.0       0.506667
#
#                                   HIT10_blizzard
# project
# smartshark_ant-ivy                      0.887701
# smartshark_archiva                      0.780374
# smartshark_calcite                      1.656863
# smartshark_cayenne                      0.884298
# smartshark_commons-bcel                 0.892857
# smartshark_commons-beanutils            1.583333
# smartshark_commons-codec                2.266667
# smartshark_commons-collections          0.878049
# smartshark_commons-compress             1.207547
# smartshark_commons-configuration        1.089431
# smartshark_commons-dbcp                 1.000000
# smartshark_commons-digester             1.000000
# smartshark_commons-io                   1.555556
# smartshark_commons-jcs                  0.574074
# smartshark_commons-jexl                 0.733333
# smartshark_commons-lang                 1.727273
# smartshark_commons-math                 1.004902
# smartshark_commons-net                  1.324786
# smartshark_commons-scxml                1.176471
# smartshark_commons-validator            1.200000
# smartshark_commons-vfs                  0.785714
# smartshark_deltaspike                   1.161017
# smartshark_eagle                        1.000000
# smartshark_giraph                       1.449541
# smartshark_gora                         1.490196
# smartshark_jspwiki                      0.268908
# smartshark_knox                         1.637097
# smartshark_kylin                        0.863799
# smartshark_lens                         1.038043
# smartshark_mahout                       1.247748
# smartshark_manifoldcf                   1.217557
# smartshark_nutch                        1.095745
# smartshark_opennlp                      1.218391
# smartshark_parquet-mr                   1.306122
# smartshark_santuario-java               1.170213
# smartshark_systemml                     1.011628
# smartshark_tika                         1.296875
# smartshark_wss4j                        0.633333
#
# [38 rows x 37 columns]

# %%
import os
import pandas as pd

data_mp = pd.read_csv('../other/statistic.csv')
data_mp
# Out:
#           Project      Version  Bugs  Result
# 0    Apache_CAMEL  CAMEL_1_6_0   299     NaN
# 1    Apache_CAMEL  CAMEL_1_6_1    39     NaN
# 2    Apache_CAMEL  CAMEL_1_6_2     6     NaN
# 3    Apache_CAMEL  CAMEL_1_6_3     2     NaN
# 4    Apache_CAMEL  CAMEL_1_6_4    67     NaN
# ..            ...          ...   ...     ...
# 706  Wildfly_WFLY   WFLY_8_2_1     2     NaN
# 707  Wildfly_WFLY   WFLY_9_0_0    74     NaN
# 708  Wildfly_WFLY   WFLY_9_0_1     5     NaN
# 709  Wildfly_WFLY   WFLY_9_0_2     5     NaN
# 710  Wildfly_WFMP   WFMP_1_1_0     3     NaN
#
# [711 rows x 4 columns]

# %%
data = pd.DataFrame()
for file in os.listdir("../other/amalgam"):
    project = "_".join(file.replace('_output.txt','').split("_")[:2])
    version = "_".join(file.replace('_output.txt','').split("_")[2:])
    #print(project,version)
    element = data_mp.loc[(data_mp['Project'] == project) & (data_mp['Version'] == version), 'Bugs'].values[0]
    data = data.append({"project" : project, "version" : version, "bugs": element}, ignore_index=True)

# %%
agg_funcs = {'bugs' : 'sum', 
         'version' : 'count'
}

data = data.groupby("project").agg(agg_funcs)

data
# Out:
#                          bugs  version
# project
# Apache_CAMEL           1452.0       62
# Apache_HBASE            858.0       70
# Apache_HIVE            1219.0       21
# Commons_CODEC            41.0        9
# Commons_COLLECTIONS      93.0        7
# Commons_COMPRESS        111.0       15
# Commons_CONFIGURATION   135.0       11
# Commons_CRYPTO            8.0        1
# Commons_CSV              14.0        3
# Commons_IO               88.0       13
# Commons_LANG            209.0       16
# Commons_MATH            224.0       15
# Commons_WEAVER            2.0        1
# JBoss_ENTESB             39.0        3
# JBoss_JBMETA             26.0        5
# Previous_AspectJ       1140.0        4
# Previous_JDT             94.0        1
# Previous_PDE             59.0        1
# Previous_SWT            294.0        3
# Previous_ZXing           20.0        1
# Spring_AMQP             101.0       32
# Spring_ANDROID            9.0        2
# Spring_BATCH            412.0       33
# Spring_BATCHADM          19.0        4
# Spring_DATACMNS         155.0       33
# Spring_DATAGRAPH         95.0       18
# Spring_DATAJPA          148.0       38
# Spring_DATAMONGO        261.0       40
# Spring_DATAREDIS         48.0       17
# Spring_DATAREST         132.0       23
# Spring_LDAP              53.0        5
# Spring_MOBILE            11.0        3
# Spring_ROO              707.0       15
# Spring_SEC              541.0       42
# Spring_SECOAUTH          96.0        7
# Spring_SGF              105.0       19
# Spring_SHDP              41.0        8
# Spring_SHL                9.0        2
# Spring_SOCIAL            15.0        4
# Spring_SOCIALFB          15.0        5
# Spring_SOCIALLI           3.0        1
# Spring_SOCIALTW           8.0        5
# Spring_SPR              126.0       10
# Spring_SWF              134.0       20
# Spring_SWS              172.0       25
# Wildfly_ELY              23.0        3
# Wildfly_SWARM            56.0        6
# Wildfly_WFARQ             1.0        1
# Wildfly_WFCORE          339.0       16
# Wildfly_WFLY            910.0       11
# Wildfly_WFMP              3.0        1

# %%
from pandas.errors import EmptyDataError

def evaluateForAlgo(base, factor=0):
    data_map = dict()
    data_mrr = dict()
    data_hit1 = dict()
    data_hit5 = dict()
    data_hit10 = dict()
    
    for file in os.listdir('../other/' + base):
        print(file)
        project = "_".join(file.replace('_output.txt','').split("_")[:2])
        version = "_".join(file.replace('_output.txt','').split("_")[2:])
        if project not in data_map:
            data_map[project] = 0
            data_mrr[project] = 0
            data_hit1[project] = 0
            data_hit5[project] = 0
            data_hit10[project] = 0
        try:
            data_mp = pd.read_csv('../other/' + base + "/" + file, header=None,error_bad_lines=False,sep='\t')  
            a_group = data_mp.groupby(0)
            for name, group in a_group:
                rr = 0;
                    
                summe = 0;
                retrieved_d = 0;   
                c = 0
                best_value = -1;
                for index, element in group.iterrows():
                    if element[2] < best_value or best_value == -1:
                        best_value = element[2]
                    c += 1
                    retrieved_d += 1;
                    summe += retrieved_d /(element[2]+1)
                if best_value != -1:
                    data_mrr[project] += (1/ (best_value+1))
                data_map[project] += (summe/c)
                # These outputs are zero based!
                #print(best_value)
                if best_value != -1 and best_value == 0 + factor:
                    data_hit1[project] += 1
                if best_value != -1 and best_value <= 4 + factor:
                    data_hit5[project] += 1
                if best_value != -1 and best_value <= 9 + factor:
                    data_hit10[project] += 1
        except EmptyDataError:
             data_mp = pd.DataFrame()
    

    #data_mrr[project] = (1/ (data_mp[2]+1))    
    #print(data_mp)
    #c += 1
    #retrieved_d += 1;
    #summe += retrieved_d /(i+1)
    data['MAP_' + base] = pd.Series(data_map) /data["bugs"]
    data['MRR_' + base] =  pd.Series(data_mrr) / data["bugs"]
    data['HIT1_' + base] =  pd.Series(data_hit1) / data["bugs"]
    data['HIT5_' + base] =  pd.Series(data_hit5) / data["bugs"]
    data['HIT10_' + base] =  pd.Series(data_hit10) / data["bugs"]


evaluateForAlgo('buglocator')
evaluateForAlgo('bluir')
evaluateForAlgo('brtracer')
evaluateForAlgo('amalgam')
evaluateForAlgo('blia')
evaluateForAlgo('locus')
evaluateForAlgo('blizzard', 1)
data.to_csv('results_other_bench4bl.csv')
data
# Out:
# Apache_CAMEL_CAMEL_2_13_0_output.txt
# Spring_DATAMONGO_DATAMONGO_1_3_3_output.txt
# Spring_DATAREST_DATAREST_2_1_6_output.txt
# Spring_BATCH_BATCH_3_0_3_output.txt
# Spring_SWF_SWF_2_0_5_output.txt
# Apache_HBASE_HBASE_0_99_2_output.txt
# Apache_CAMEL_CAMEL_2_9_4_output.txt
# Spring_DATAGRAPH_DATAGRAPH_4_1_1_output.txt
# Spring_DATAJPA_DATAJPA_1_7_3_output.txt
# Commons_MATH_MATH_3_3_output.txt
# Commons_COMPRESS_COMPRESS_1_12_output.txt
# Spring_DATACMNS_DATACMNS_1_3_2_output.txt
# Spring_DATAREDIS_DATAREDIS_1_4_4_output.txt
# Apache_CAMEL_CAMEL_2_16_2_output.txt
# Spring_DATAJPA_DATAJPA_1_4_3_output.txt
# Spring_ANDROID_ANDROID_1_0_1_output.txt
# Spring_SWS_SWS_1_0_2_output.txt
# Commons_COMPRESS_COMPRESS_1_1_output.txt
# JBoss_JBMETA_JBMETA_8_0_0_output.txt
# Spring_SWS_SWS_2_1_2_output.txt
# Apache_HBASE_HBASE_1_2_0_output.txt
# Apache_HBASE_HBASE_0_99_0_output.txt
# Spring_DATAJPA_DATAJPA_1_0_3_output.txt
# Commons_CODEC_CODEC_1_3_output.txt
# Spring_DATACMNS_DATACMNS_1_5_3_output.txt
# Spring_SEC_SEC_3_2_7_output.txt
# Apache_HIVE_HIVE_0_13_1_output.txt
# Apache_HBASE_HBASE_0_90_2_output.txt
# Spring_SECOAUTH_SECOAUTH_2_0_0_output.txt
# Commons_MATH_MATH_3_5_output.txt
# Apache_HBASE_HBASE_0_94_17_output.txt
# Spring_DATAREDIS_DATAREDIS_1_0_0_output.txt
# Apache_CAMEL_CAMEL_2_12_4_output.txt
# Spring_DATAREDIS_DATAREDIS_1_7_1_output.txt
# Spring_DATAGRAPH_DATAGRAPH_2_3_5_output.txt
# Spring_SPR_SPR_3_1_1_output.txt
# Apache_HIVE_HIVE_0_12_0_output.txt
# Commons_IO_IO_2_5_output.txt
# Commons_MATH_MATH_3_4_output.txt
# Spring_DATACMNS_DATACMNS_1_7_2_output.txt
# Spring_DATAREDIS_DATAREDIS_1_3_2_output.txt
# Spring_SGF_SGF_1_4_6_output.txt
# Apache_HBASE_HBASE_0_98_4_output.txt
# Spring_BATCH_BATCH_2_0_2_output.txt
# Spring_SEC_SEC_3_2_0_output.txt
# Wildfly_WFCORE_WFCORE_2_0_1_output.txt
# Apache_HIVE_HIVE_1_2_1_output.txt
# Spring_BATCH_BATCH_2_2_7_output.txt
# Apache_CAMEL_CAMEL_2_11_3_output.txt
# Spring_SGF_SGF_1_3_2_output.txt
# Apache_CAMEL_CAMEL_2_15_4_output.txt
# Wildfly_ELY_ELY_1_0_3_output.txt
# Apache_HBASE_HBASE_0_92_0_output.txt
# Spring_DATAREST_DATAREST_2_2_1_output.txt
# Spring_DATAREDIS_DATAREDIS_1_6_6_output.txt
# Commons_COMPRESS_COMPRESS_1_8_output.txt
# Spring_DATAJPA_DATAJPA_1_6_2_output.txt
# Apache_HIVE_HIVE_0_7_0_output.txt
# Spring_SHDP_SHDP_2_0_2_output.txt
# Apache_CAMEL_CAMEL_1_6_2_output.txt
# Wildfly_WFCORE_WFCORE_2_0_0_output.txt
# Spring_SECOAUTH_SECOAUTH_1_0_4_output.txt
# Spring_LDAP_LDAP_1_3_2_output.txt
# Apache_CAMEL_CAMEL_2_8_1_output.txt
# Spring_AMQP_AMQP_1_6_1_output.txt
# Spring_DATAMONGO_DATAMONGO_1_9_3_output.txt
# Spring_BATCH_BATCH_2_1_8_output.txt
# Spring_SEC_SEC_3_1_0_output.txt
# Spring_DATAMONGO_DATAMONGO_1_4_1_output.txt
# Spring_DATAREDIS_DATAREDIS_1_2_0_output.txt
# Commons_COMPRESS_COMPRESS_1_10_output.txt
# Commons_CRYPTO_CRYPTO_1_0_0_output.txt
# Commons_CSV_CSV_1_1_output.txt
# Commons_COMPRESS_COMPRESS_1_3_output.txt
# Spring_BATCH_BATCH_1_1_0_output.txt
# Spring_MOBILE_MOBILE_1_0_1_output.txt
# Spring_SOCIALFB_SOCIALFB_2_0_0_output.txt
# Spring_DATAJPA_DATAJPA_1_3_1_output.txt
# Apache_CAMEL_CAMEL_2_11_0_output.txt
# Spring_DATAJPA_DATAJPA_1_5_2_output.txt
# Spring_DATAJPA_DATAJPA_1_3_5_output.txt
# Spring_SHDP_SHDP_2_0_0_output.txt
# Spring_DATAJPA_DATAJPA_1_3_2_output.txt
# Spring_SWS_SWS_2_2_4_output.txt
# Spring_AMQP_AMQP_1_5_6_output.txt
# Commons_CONFIGURATION_CONFIGURATION_1_7_output.txt
# Apache_CAMEL_CAMEL_2_12_2_output.txt
# Spring_SOCIALLI_SOCIALLI_1_0_0_output.txt
# Apache_CAMEL_CAMEL_1_6_4_output.txt
# Spring_DATAJPA_DATAJPA_1_9_5_output.txt
# Spring_ROO_ROO_1_2_2_output.txt
# Spring_DATAREST_DATAREST_2_1_4_output.txt
# Spring_ROO_ROO_1_1_1_output.txt
# Spring_AMQP_AMQP_1_3_7_output.txt
# Spring_SWS_SWS_1_5_4_output.txt
# Spring_SWS_SWS_1_5_8_output.txt
# Commons_LANG_LANG_3_1_output.txt
# Spring_DATAGRAPH_DATAGRAPH_3_4_6_output.txt
# Apache_HBASE_HBASE_0_96_0_output.txt
# Spring_AMQP_AMQP_1_5_3_output.txt
# Spring_DATAMONGO_DATAMONGO_1_6_2_output.txt
# Commons_MATH_MATH_2_1_output.txt
# Spring_SECOAUTH_SECOAUTH_1_0_0_output.txt
# Apache_HBASE_HBASE_1_0_0_output.txt
# Spring_SHDP_SHDP_2_0_1_output.txt
# Wildfly_WFLY_WFLY_7_1_1_output.txt
# Spring_SWF_SWF_2_0_3_output.txt
# Spring_SHDP_SHDP_2_2_0_output.txt
# Spring_SGF_SGF_1_2_0_output.txt
# Apache_HBASE_HBASE_0_98_21_output.txt
# Apache_CAMEL_CAMEL_2_12_5_output.txt
# Wildfly_WFCORE_WFCORE_1_0_1_output.txt
# Spring_SEC_SEC_3_0_0_output.txt
# Spring_DATAREST_DATAREST_2_5_5_output.txt
# Apache_HBASE_HBASE_0_90_6_output.txt
# Spring_SHL_SHL_1_0_0_output.txt
# Wildfly_WFCORE_WFCORE_2_0_6_output.txt
# Spring_AMQP_AMQP_1_6_3_output.txt
# Spring_DATAJPA_DATAJPA_1_6_6_output.txt
# Spring_SWS_SWS_2_0_1_output.txt
# Spring_DATACMNS_DATACMNS_1_9_2_output.txt
# Spring_DATAREDIS_DATAREDIS_1_3_4_output.txt
# Spring_DATAJPA_DATAJPA_1_4_4_output.txt
# Apache_HBASE_HBASE_1_2_1_output.txt
# Apache_CAMEL_CAMEL_2_10_4_output.txt
# Wildfly_WFLY_WFLY_9_0_2_output.txt
# Spring_DATAJPA_DATAJPA_1_9_2_output.txt
# Spring_DATAJPA_DATAJPA_1_5_1_output.txt
# Wildfly_WFLY_WFLY_7_2_0_output.txt
# Apache_HBASE_HBASE_0_94_18_output.txt
# Commons_CONFIGURATION_CONFIGURATION_1_6_output.txt
# Apache_HBASE_HBASE_1_1_5_output.txt
# Spring_BATCH_BATCH_2_1_2_output.txt
# Commons_COLLECTIONS_COLLECTIONS_3_2_output.txt
# Apache_HBASE_HBASE_0_98_12_output.txt
# Spring_DATAMONGO_DATAMONGO_1_4_3_output.txt
# Commons_COMPRESS_COMPRESS_1_9_output.txt
# Spring_DATAMONGO_DATAMONGO_1_0_3_output.txt
# Apache_HIVE_HIVE_0_9_0_output.txt
# Spring_DATAJPA_DATAJPA_1_3_3_output.txt
# Spring_MOBILE_MOBILE_1_1_0_output.txt
# Spring_SEC_SEC_3_0_7_output.txt
# Spring_SOCIALFB_SOCIALFB_1_0_0_output.txt
# Spring_DATACMNS_DATACMNS_1_0_0_output.txt
# Spring_SHDP_SHDP_2_0_3_output.txt
# Spring_LDAP_LDAP_2_0_0_output.txt
# Spring_BATCH_BATCH_2_2_2_output.txt
# Wildfly_WFCORE_WFCORE_2_0_7_output.txt
# Apache_HBASE_HBASE_0_98_1_output.txt
# Spring_DATAREST_DATAREST_2_4_1_output.txt
# Commons_CONFIGURATION_CONFIGURATION_1_10_output.txt
# Spring_DATACMNS_DATACMNS_1_9_4_output.txt
# Commons_IO_IO_1_3_1_output.txt
# Spring_DATAMONGO_DATAMONGO_1_2_3_output.txt
# Spring_DATAGRAPH_DATAGRAPH_2_2_3_output.txt
# Spring_DATACMNS_DATACMNS_1_9_1_output.txt
# Spring_BATCH_BATCH_2_0_4_output.txt
# Apache_HBASE_HBASE_0_94_10_output.txt
# Apache_CAMEL_CAMEL_2_14_1_output.txt
# Commons_COMPRESS_COMPRESS_1_7_output.txt
# Spring_SEC_SEC_2_0_0_output.txt
# Apache_CAMEL_CAMEL_2_17_0_output.txt
# Spring_ROO_ROO_1_1_2_output.txt
# Spring_BATCH_BATCH_2_0_0_output.txt
# Spring_MOBILE_MOBILE_1_0_0_output.txt
# Spring_ROO_ROO_1_2_0_output.txt
# Spring_SEC_SEC_4_0_3_output.txt
# Commons_LANG_LANG_3_0_1_output.txt
# Spring_ANDROID_ANDROID_1_0_0_output.txt
# Spring_SWS_SWS_1_0_1_output.txt
# Spring_SGF_SGF_1_3_1_output.txt
# Apache_HIVE_HIVE_0_11_0_output.txt
# Spring_DATAJPA_DATAJPA_1_4_1_output.txt
# Spring_DATAMONGO_DATAMONGO_1_5_1_output.txt
# Spring_DATAGRAPH_DATAGRAPH_2_0_1_output.txt
# Spring_BATCH_BATCH_2_2_1_output.txt
# Spring_SEC_SEC_3_2_3_output.txt
# Spring_DATAJPA_DATAJPA_1_5_3_output.txt
# Apache_HBASE_HBASE_0_90_4_output.txt
# Spring_SOCIALTW_SOCIALTW_1_0_1_output.txt
# Spring_DATACMNS_DATACMNS_1_12_1_output.txt
# Spring_SOCIAL_SOCIAL_1_0_0_output.txt
# Spring_SEC_SEC_2_0_3_output.txt
# Spring_SEC_SEC_3_1_1_output.txt
# Apache_CAMEL_CAMEL_2_2_0_output.txt
# Spring_SGF_SGF_1_5_2_output.txt
# Apache_HBASE_HBASE_1_1_0_output.txt
# Spring_SECOAUTH_SECOAUTH_1_0_5_output.txt
# Spring_DATAJPA_DATAJPA_1_8_1_output.txt
# Spring_AMQP_AMQP_1_1_3_output.txt
# Apache_HIVE_HIVE_1_1_0_output.txt
# Spring_BATCH_BATCH_2_2_4_output.txt
# Spring_DATACMNS_DATACMNS_1_1_0_output.txt
# Commons_MATH_MATH_3_1_1_output.txt
# Commons_MATH_MATH_1_0_output.txt
# Spring_SGF_SGF_1_4_4_output.txt
# Spring_DATAMONGO_DATAMONGO_1_3_5_output.txt
# Spring_BATCH_BATCH_1_0_0_output.txt
# Spring_DATAREDIS_DATAREDIS_1_5_2_output.txt
# Spring_SWS_SWS_2_0_2_output.txt
# Commons_COMPRESS_COMPRESS_1_4_output.txt
# Spring_SEC_SEC_2_0_4_output.txt
# Spring_SGF_SGF_1_2_1_output.txt
# Spring_AMQP_AMQP_1_4_4_output.txt
# Previous_AspectJ_AspectJ_1_6_0_M2_up_output.txt
# Spring_DATACMNS_DATACMNS_1_4_1_output.txt
# Spring_SEC_SEC_4_0_2_output.txt
# Spring_SEC_SEC_2_0_6_output.txt
# Spring_DATAMONGO_DATAMONGO_1_0_0_output.txt
# Apache_HBASE_HBASE_0_98_6_output.txt
# Spring_DATAMONGO_DATAMONGO_1_6_4_output.txt
# Commons_COLLECTIONS_COLLECTIONS_3_0_output.txt
# Spring_DATAMONGO_DATAMONGO_1_8_5_output.txt
# Apache_HBASE_HBASE_0_98_16_output.txt
# Spring_DATAJPA_DATAJPA_1_10_3_output.txt
# Commons_LANG_LANG_2_5_output.txt
# Spring_SPR_SPR_3_0_5_output.txt
# Commons_IO_IO_1_2_output.txt
# Commons_CODEC_CODEC_1_8_output.txt
# Spring_SWS_SWS_1_5_1_output.txt
# Wildfly_WFLY_WFLY_8_2_0_output.txt
# Spring_DATAREST_DATAREST_2_4_5_output.txt
# Commons_IO_IO_2_0_output.txt
# Spring_SOCIALTW_SOCIALTW_1_1_0_output.txt
# Commons_CODEC_CODEC_1_10_output.txt
# Spring_DATAMONGO_DATAMONGO_1_0_1_output.txt
# Commons_CONFIGURATION_CONFIGURATION_1_3_output.txt
# Spring_DATAMONGO_DATAMONGO_1_9_4_output.txt
# Previous_PDE_PDE_4_4_output.txt
# JBoss_JBMETA_JBMETA_7_1_1_output.txt
# Commons_CODEC_CODEC_1_6_output.txt
# Spring_BATCH_BATCH_1_1_2_output.txt
# Spring_DATACMNS_DATACMNS_1_7_3_output.txt
# Spring_DATACMNS_DATACMNS_1_8_4_output.txt
# Commons_IO_IO_1_0_output.txt
# Spring_AMQP_AMQP_1_2_1_output.txt
# Spring_DATAMONGO_DATAMONGO_1_7_2_output.txt
# Spring_SWF_SWF_2_2_0_output.txt
# Wildfly_ELY_ELY_1_0_2_output.txt
# Commons_LANG_LANG_3_2_output.txt
# Spring_DATAGRAPH_DATAGRAPH_2_1_0_output.txt
# Spring_SPR_SPR_3_0_4_output.txt
# Spring_DATAGRAPH_DATAGRAPH_4_0_0_output.txt
# Apache_HIVE_HIVE_0_10_0_output.txt
# Spring_AMQP_AMQP_1_1_0_output.txt
# Spring_BATCH_BATCH_2_0_3_output.txt
# Spring_SPR_SPR_4_2_5_output.txt
# Spring_DATAMONGO_DATAMONGO_1_3_4_output.txt
# Spring_DATAGRAPH_DATAGRAPH_3_0_3_output.txt
# Spring_BATCH_BATCH_2_1_5_output.txt
# Spring_SEC_SEC_3_1_4_output.txt
# Apache_HIVE_HIVE_0_7_1_output.txt
# Commons_COLLECTIONS_COLLECTIONS_3_2_1_output.txt
# Spring_ROO_ROO_1_2_1_output.txt
# Apache_HIVE_HIVE_0_14_0_output.txt
# Commons_COMPRESS_COMPRESS_1_11_output.txt
# Spring_SWF_SWF_2_0_6_output.txt
# Apache_HBASE_HBASE_1_0_2_output.txt
# Apache_CAMEL_CAMEL_1_6_0_output.txt
# Spring_ROO_ROO_1_1_4_output.txt
# Apache_CAMEL_CAMEL_2_14_2_output.txt
# Spring_SOCIAL_SOCIAL_1_1_0_output.txt
# Spring_DATACMNS_DATACMNS_1_8_6_output.txt
# Spring_DATAMONGO_DATAMONGO_1_2_1_output.txt
# Spring_DATAREST_DATAREST_2_0_3_output.txt
# Apache_HBASE_HBASE_0_90_0_output.txt
# Spring_DATACMNS_DATACMNS_1_6_1_output.txt
# Commons_CONFIGURATION_CONFIGURATION_1_8_output.txt
# Apache_CAMEL_CAMEL_2_12_1_output.txt
# Apache_CAMEL_CAMEL_2_7_0_output.txt
# Spring_SWF_SWF_2_2_1_output.txt
# JBoss_ENTESB_ENTESB_6_2_0_output.txt
# Wildfly_WFCORE_WFCORE_2_1_0_output.txt
# Spring_SWS_SWS_2_0_3_output.txt
# Spring_AMQP_AMQP_1_4_3_output.txt
# Apache_CAMEL_CAMEL_2_14_3_output.txt
# Spring_SEC_SEC_3_0_6_output.txt
# Commons_CSV_CSV_1_0_output.txt
# Spring_SEC_SEC_3_2_9_output.txt
# Spring_DATAMONGO_DATAMONGO_1_0_4_output.txt
# Apache_CAMEL_CAMEL_2_11_2_output.txt
# Spring_DATAMONGO_DATAMONGO_1_8_2_output.txt
# Wildfly_WFCORE_WFCORE_2_0_8_output.txt
# Commons_CONFIGURATION_CONFIGURATION_1_2_output.txt
# Spring_DATAREST_DATAREST_1_1_0_output.txt
# Wildfly_WFCORE_WFCORE_1_0_2_output.txt
# Apache_HBASE_HBASE_1_1_7_output.txt
# Apache_HBASE_HBASE_0_95_2_output.txt
# Spring_SWS_SWS_1_0_4_output.txt
# Spring_DATAMONGO_DATAMONGO_1_5_2_output.txt
# Spring_BATCH_BATCH_2_2_5_output.txt
# Apache_CAMEL_CAMEL_2_10_0_output.txt
# Spring_DATAJPA_DATAJPA_1_6_4_output.txt
# Spring_BATCHADM_BATCHADM_1_2_1_output.txt
# Spring_DATAMONGO_DATAMONGO_1_5_6_output.txt
# Spring_DATAREST_DATAREST_2_5_1_output.txt
# Spring_DATAREST_DATAREST_2_3_1_output.txt
# Spring_SGF_SGF_1_4_1_output.txt
# Spring_DATAJPA_DATAJPA_1_4_2_output.txt
# Spring_SOCIAL_SOCIAL_1_0_1_output.txt
# Apache_HBASE_HBASE_0_98_11_output.txt
# Spring_DATAREST_DATAREST_2_1_1_output.txt
# Spring_DATAREST_DATAREST_2_1_2_output.txt
# Spring_SEC_SEC_2_0_2_output.txt
# Spring_AMQP_AMQP_1_4_6_output.txt
# Apache_CAMEL_CAMEL_2_13_4_output.txt
# Apache_HBASE_HBASE_0_98_23_output.txt
# Spring_SEC_SEC_3_2_8_output.txt
# Spring_DATAREST_DATAREST_2_0_2_output.txt
# Spring_DATAMONGO_DATAMONGO_1_8_4_output.txt
# Spring_SWF_SWF_2_1_1_output.txt
# Spring_DATAJPA_DATAJPA_1_10_2_output.txt
# Commons_COMPRESS_COMPRESS_1_5_output.txt
# Spring_DATAJPA_DATAJPA_1_7_2_output.txt
# Spring_DATAREDIS_DATAREDIS_1_4_1_output.txt
# Spring_DATACMNS_DATACMNS_1_5_1_output.txt
# Spring_SWS_SWS_2_2_0_output.txt
# Spring_DATACMNS_DATACMNS_1_10_2_output.txt
# Spring_BATCH_BATCH_2_2_0_output.txt
# Apache_HBASE_HBASE_0_90_1_output.txt
# Spring_DATAREDIS_DATAREDIS_1_3_5_output.txt
# Spring_SWS_SWS_1_5_5_output.txt
# Apache_CAMEL_CAMEL_2_13_2_output.txt
# Spring_SOCIALTW_SOCIALTW_1_0_2_output.txt
# Commons_COLLECTIONS_COLLECTIONS_4_1_output.txt
# Apache_CAMEL_CAMEL_2_16_1_output.txt
# Spring_AMQP_AMQP_1_3_0_output.txt
# Apache_CAMEL_CAMEL_2_14_0_output.txt
# Spring_BATCH_BATCH_2_2_6_output.txt
# Commons_WEAVER_WEAVER_1_2_output.txt
# Spring_DATAMONGO_DATAMONGO_1_7_1_output.txt
# Apache_HBASE_HBASE_0_98_13_output.txt
# Apache_HBASE_HBASE_0_92_1_output.txt
# Spring_DATAMONGO_DATAMONGO_1_3_2_output.txt
# Commons_COMPRESS_COMPRESS_1_2_output.txt
# Spring_SGF_SGF_1_3_4_output.txt
# Commons_MATH_MATH_2_2_output.txt
# Apache_HBASE_HBASE_0_98_7_output.txt
# Spring_DATAREDIS_DATAREDIS_1_6_4_output.txt
# Commons_LANG_LANG_2_0_output.txt
# Spring_DATAGRAPH_DATAGRAPH_1_0_0_output.txt
# Commons_COLLECTIONS_COLLECTIONS_3_2_2_output.txt
# Spring_SWF_SWF_2_0_4_output.txt
# Spring_DATAREST_DATAREST_2_3_2_output.txt
# Wildfly_WFCORE_WFCORE_2_0_10_output.txt
# Spring_SEC_SEC_1_0_4_output.txt
# Commons_CODEC_CODEC_1_4_output.txt
# Spring_SOCIALFB_SOCIALFB_1_1_0_output.txt
# Spring_DATAJPA_DATAJPA_1_10_1_output.txt
# Spring_DATAJPA_DATAJPA_1_7_1_output.txt
# Spring_AMQP_AMQP_1_6_2_output.txt
# Apache_CAMEL_CAMEL_2_7_1_output.txt
# Apache_HBASE_HBASE_0_98_20_output.txt
# Apache_HBASE_HBASE_0_98_15_output.txt
# Wildfly_WFLY_WFLY_9_0_0_output.txt
# Spring_BATCH_BATCH_1_1_3_output.txt
# Commons_MATH_MATH_3_0_output.txt
# Spring_DATAREDIS_DATAREDIS_1_3_1_output.txt
# Spring_SHDP_SHDP_2_3_0_output.txt
# Spring_ROO_ROO_1_2_4_output.txt
# Apache_CAMEL_CAMEL_2_11_4_output.txt
# Spring_AMQP_AMQP_1_2_0_output.txt
# Wildfly_WFLY_WFLY_8_0_0_output.txt
# Spring_DATAGRAPH_DATAGRAPH_3_0_1_output.txt
# Commons_CONFIGURATION_CONFIGURATION_1_4_output.txt
# Apache_CAMEL_CAMEL_2_9_5_output.txt
# Spring_DATAJPA_DATAJPA_1_10_4_output.txt
# Apache_HBASE_HBASE_1_0_1_output.txt
# Spring_AMQP_AMQP_1_4_1_output.txt
# Spring_SEC_SEC_3_1_3_output.txt
# Spring_BATCH_BATCH_2_1_6_output.txt
# Spring_DATAMONGO_DATAMONGO_1_4_2_output.txt
# Spring_DATACMNS_DATACMNS_1_12_2_output.txt
# Spring_DATAREST_DATAREST_2_0_1_output.txt
# Spring_SEC_SEC_1_0_1_output.txt
# Spring_SWF_SWF_2_0_2_output.txt
# Spring_SWS_SWS_1_5_6_output.txt
# Spring_ROO_ROO_1_1_5_output.txt
# Wildfly_WFMP_WFMP_1_1_0_output.txt
# Apache_HBASE_HBASE_1_1_1_output.txt
# Spring_SGF_SGF_1_3_3_output.txt
# Spring_BATCH_BATCH_3_0_1_output.txt
# Spring_DATAJPA_DATAJPA_1_6_5_output.txt
# Spring_SWS_SWS_1_5_10_output.txt
# Apache_HBASE_HBASE_0_20_5_output.txt
# Spring_AMQP_AMQP_1_3_6_output.txt
# Commons_CODEC_CODEC_1_1_output.txt
# Spring_SEC_SEC_1_0_5_output.txt
# Spring_SEC_SEC_3_2_4_output.txt
# Spring_SGF_SGF_1_5_3_output.txt
# Spring_SGF_SGF_1_6_2_output.txt
# Previous_AspectJ_AspectJ_1_5_0_M2_output.txt
# Apache_HBASE_HBASE_0_92_2_output.txt
# Spring_AMQP_AMQP_1_3_3_output.txt
# Apache_HIVE_HIVE_0_8_0_output.txt
# Apache_HBASE_HBASE_0_98_10_output.txt
# Apache_HBASE_HBASE_0_94_3_output.txt
# Spring_SEC_SEC_3_0_4_output.txt
# Wildfly_WFLY_WFLY_10_1_0_output.txt
# Spring_SGF_SGF_1_4_5_output.txt
# Apache_HBASE_HBASE_0_98_19_output.txt
# Apache_HBASE_HBASE_0_94_2_output.txt
# Spring_DATAGRAPH_DATAGRAPH_1_1_0_output.txt
# Commons_COLLECTIONS_COLLECTIONS_4_0_output.txt
# Spring_DATACMNS_DATACMNS_1_12_3_output.txt
# Apache_CAMEL_CAMEL_2_9_0_output.txt
# Spring_SEC_SEC_3_0_2_output.txt
# Spring_SGF_SGF_1_0_0_output.txt
# JBoss_ENTESB_ENTESB_6_3_0_output.txt
# Apache_CAMEL_CAMEL_2_10_6_output.txt
# Previous_AspectJ_AspectJ_1_5_3_final_output.txt
# Apache_HBASE_HBASE_1_1_4_output.txt
# Commons_IO_IO_2_1_output.txt
# Wildfly_SWARM_SWARM_2016_8_output.txt
# Spring_DATAGRAPH_DATAGRAPH_4_1_6_output.txt
# Apache_HBASE_HBASE_0_94_27_output.txt
# Spring_BATCH_BATCH_2_1_7_output.txt
# Spring_SEC_SEC_2_0_5_output.txt
# Spring_DATAMONGO_DATAMONGO_1_6_3_output.txt
# Apache_HIVE_HIVE_0_6_0_output.txt
# Commons_MATH_MATH_1_1_output.txt
# Spring_SGF_SGF_1_7_6_output.txt
# Spring_SWS_SWS_1_5_7_output.txt
# Spring_DATAMONGO_DATAMONGO_1_9_6_output.txt
# Spring_SWF_SWF_1_0_5_output.txt
# Wildfly_SWARM_SWARM_1_0_0_output.txt
# Apache_CAMEL_CAMEL_2_6_0_output.txt
# Wildfly_WFCORE_WFCORE_2_2_0_output.txt
# Spring_ROO_ROO_1_1_3_output.txt
# Apache_HIVE_HIVE_1_1_1_output.txt
# Spring_ROO_ROO_1_0_2_output.txt
# Wildfly_WFARQ_WFARQ_1_1_0_output.txt
# Spring_DATAREST_DATAREST_2_5_2_output.txt
# Apache_CAMEL_CAMEL_2_17_1_output.txt
# Spring_BATCHADM_BATCHADM_1_0_0_output.txt
# Apache_CAMEL_CAMEL_2_11_1_output.txt
# Wildfly_SWARM_SWARM_2016_9_output.txt
# Spring_SWF_SWF_2_1_0_output.txt
# Spring_DATACMNS_DATACMNS_1_12_6_output.txt
# Apache_CAMEL_CAMEL_2_13_1_output.txt
# Spring_SPR_SPR_3_0_1_output.txt
# Apache_HBASE_HBASE_0_89_20100621_output.txt
# Apache_HBASE_HBASE_0_90_5_output.txt
# Spring_BATCH_BATCH_1_1_1_output.txt
# Wildfly_WFCORE_WFCORE_2_0_5_output.txt
# Spring_DATAMONGO_DATAMONGO_1_1_1_output.txt
# Commons_COMPRESS_COMPRESS_1_0_output.txt
# Spring_DATAJPA_DATAJPA_1_1_2_output.txt
# Commons_CONFIGURATION_CONFIGURATION_1_9_output.txt
# Commons_IO_IO_1_4_output.txt
# Spring_DATAMONGO_DATAMONGO_1_1_2_output.txt
# Spring_AMQP_AMQP_1_0_0_output.txt
# Spring_SEC_SEC_1_0_6_output.txt
# Spring_DATACMNS_DATACMNS_1_11_6_output.txt
# Apache_HBASE_HBASE_0_98_2_output.txt
# Spring_AMQP_AMQP_1_6_6_output.txt
# Spring_BATCH_BATCH_2_0_1_output.txt
# Apache_CAMEL_CAMEL_2_17_2_output.txt
# Previous_SWT_SWT_3_659_output.txt
# Apache_CAMEL_CAMEL_2_15_6_output.txt
# Apache_CAMEL_CAMEL_2_10_7_output.txt
# Spring_DATAJPA_DATAJPA_1_8_2_output.txt
# Spring_SECOAUTH_SECOAUTH_1_0_3_output.txt
# Spring_SWF_SWF_2_0_8_output.txt
# Spring_DATAMONGO_DATAMONGO_1_5_5_output.txt
# Spring_BATCH_BATCH_2_1_9_output.txt
# Spring_SEC_SEC_4_0_0_output.txt
# Spring_DATAREST_DATAREST_2_4_2_output.txt
# Apache_HBASE_HBASE_0_98_0_output.txt
# Apache_CAMEL_CAMEL_2_18_0_output.txt
# Spring_BATCH_BATCH_2_1_1_output.txt
# Commons_MATH_MATH_1_2_output.txt
# Commons_IO_IO_2_4_output.txt
# Spring_SWS_SWS_2_2_1_output.txt
# Spring_DATAREST_DATAREST_2_2_2_output.txt
# Apache_HBASE_HBASE_0_98_14_output.txt
# Spring_AMQP_AMQP_1_4_2_output.txt
# Apache_CAMEL_CAMEL_2_15_3_output.txt
# Spring_SWS_SWS_1_5_9_output.txt
# Spring_SHL_SHL_1_1_0_output.txt
# Wildfly_SWARM_SWARM_2016_11_0_output.txt
# Spring_AMQP_AMQP_1_5_1_output.txt
# Commons_IO_IO_1_1_output.txt
# Apache_HIVE_HIVE_1_0_0_output.txt
# Spring_BATCH_BATCH_2_1_3_output.txt
# Wildfly_WFCORE_WFCORE_2_0_3_output.txt
# Spring_DATAGRAPH_DATAGRAPH_2_3_1_output.txt
# Spring_DATAGRAPH_DATAGRAPH_3_4_4_output.txt
# Apache_CAMEL_CAMEL_2_8_0_output.txt
# Spring_DATACMNS_DATACMNS_1_8_2_output.txt
# Spring_AMQP_AMQP_1_3_4_output.txt
# Commons_LANG_LANG_3_5_output.txt
# Apache_CAMEL_CAMEL_2_16_3_output.txt
# Spring_SPR_SPR_3_0_6_output.txt
# Spring_DATAJPA_DATAJPA_1_6_1_output.txt
# Spring_SWF_SWF_1_0_3_output.txt
# Spring_DATAJPA_DATAJPA_1_3_4_output.txt
# Apache_CAMEL_CAMEL_2_17_3_output.txt
# Spring_BATCHADM_BATCHADM_1_3_0_output.txt
# Spring_ROO_ROO_1_0_0_output.txt
# Spring_AMQP_AMQP_1_5_5_output.txt
# Spring_SWF_SWF_2_3_0_output.txt
# Commons_COLLECTIONS_COLLECTIONS_3_1_output.txt
# JBoss_JBMETA_JBMETA_7_0_4_output.txt
# Spring_DATAREST_DATAREST_2_5_4_output.txt
# Wildfly_WFLY_WFLY_8_2_1_output.txt
# Spring_DATACMNS_DATACMNS_1_6_2_output.txt
# Apache_CAMEL_CAMEL_2_5_0_output.txt
# Spring_SGF_SGF_1_2_2_output.txt
# Apache_HIVE_HIVE_2_0_0_output.txt
# Spring_SEC_SEC_1_0_2_output.txt
# Spring_DATAREDIS_DATAREDIS_1_2_1_output.txt
# Apache_HIVE_HIVE_0_8_1_output.txt
# Apache_CAMEL_CAMEL_2_15_1_output.txt
# Spring_SWF_SWF_2_0_1_output.txt
# Commons_IO_IO_2_0_1_output.txt
# Apache_HBASE_HBASE_1_1_2_output.txt
# Spring_AMQP_AMQP_1_1_1_output.txt
# Apache_HBASE_HBASE_0_94_6_output.txt
# Spring_SEC_SEC_3_2_6_output.txt
# Spring_DATAMONGO_DATAMONGO_1_9_5_output.txt
# Apache_HBASE_HBASE_1_0_3_output.txt
# Apache_HBASE_HBASE_1_2_2_output.txt
# Spring_SWS_SWS_2_0_5_output.txt
# Spring_SEC_SEC_1_0_3_output.txt
# Apache_HBASE_HBASE_0_94_5_output.txt
# Wildfly_ELY_ELY_1_0_0_output.txt
# Spring_DATAREST_DATAREST_2_2_4_output.txt
# Spring_SEC_SEC_2_0_7_output.txt
# Apache_HIVE_HIVE_1_0_1_output.txt
# Spring_LDAP_LDAP_2_0_3_output.txt
# Wildfly_WFLY_WFLY_8_1_0_output.txt
# Wildfly_WFCORE_WFCORE_2_0_2_output.txt
# Spring_SWS_SWS_2_0_4_output.txt
# Commons_LANG_LANG_3_3_output.txt
# Wildfly_WFLY_WFLY_10_0_0_output.txt
# Spring_AMQP_AMQP_1_5_2_output.txt
# Spring_LDAP_LDAP_2_0_1_output.txt
# Spring_DATAMONGO_DATAMONGO_1_2_4_output.txt
# Spring_SEC_SEC_2_0_1_output.txt
# Commons_CONFIGURATION_CONFIGURATION_1_5_output.txt
# Apache_HBASE_HBASE_0_94_1_output.txt
# Spring_ROO_ROO_1_1_0_output.txt
# Apache_CAMEL_CAMEL_2_8_3_output.txt
# Commons_CODEC_CODEC_1_2_output.txt
# Apache_HBASE_HBASE_1_1_3_output.txt
# Spring_SEC_SEC_3_0_1_output.txt
# Spring_AMQP_AMQP_1_3_9_output.txt
# Spring_SWF_SWF_2_0_7_output.txt
# Spring_DATAREST_DATAREST_2_4_6_output.txt
# Commons_COMPRESS_COMPRESS_1_4_1_output.txt
# Commons_MATH_MATH_3_6_1_output.txt
# Spring_SOCIALFB_SOCIALFB_2_0_1_output.txt
# Apache_HBASE_HBASE_0_98_5_output.txt
# Commons_LANG_LANG_2_3_output.txt
# Spring_SPR_SPR_3_0_0_output.txt
# Spring_SWS_SWS_1_5_3_output.txt
# Spring_SWF_SWF_2_0_9_output.txt
# Previous_ZXing_ZXing_1_6_output.txt
# Spring_DATAJPA_DATAJPA_1_4_5_output.txt
# Spring_DATAJPA_DATAJPA_1_9_4_output.txt
# Spring_DATAMONGO_DATAMONGO_1_6_1_output.txt
# Wildfly_WFCORE_WFCORE_3_0_0_output.txt
# Spring_SPR_SPR_3_0_3_output.txt
# Spring_SHDP_SHDP_2_1_0_output.txt
# Spring_BATCH_BATCH_2_2_3_output.txt
# Apache_HBASE_HBASE_0_98_8_output.txt
# Spring_DATACMNS_DATACMNS_1_11_4_output.txt
# Commons_MATH_MATH_3_2_output.txt
# Spring_SEC_SEC_4_0_1_output.txt
# Spring_DATAJPA_DATAJPA_1_2_1_output.txt
# Spring_BATCH_BATCH_1_1_4_output.txt
# Apache_HBASE_HBASE_1_2_4_output.txt
# Wildfly_WFCORE_WFCORE_2_0_4_output.txt
# Spring_DATACMNS_DATACMNS_1_6_5_output.txt
# Spring_DATAJPA_DATAJPA_1_0_1_output.txt
# Apache_HIVE_HIVE_0_13_0_output.txt
# Spring_AMQP_AMQP_1_3_5_output.txt
# Wildfly_WFLY_WFLY_9_0_1_output.txt
# Spring_DATACMNS_DATACMNS_1_6_3_output.txt
# Apache_CAMEL_CAMEL_2_15_0_output.txt
# Spring_DATAMONGO_DATAMONGO_1_9_2_output.txt
# Spring_SEC_SEC_1_0_0_output.txt
# Spring_DATACMNS_DATACMNS_1_7_1_output.txt
# Commons_MATH_MATH_3_4_1_output.txt
# Commons_CODEC_CODEC_1_9_output.txt
# Commons_LANG_LANG_2_4_output.txt
# Spring_DATAMONGO_DATAMONGO_1_9_1_output.txt
# JBoss_JBMETA_JBMETA_8_1_1_output.txt
# Commons_LANG_LANG_2_1_output.txt
# Spring_SEC_SEC_3_1_2_output.txt
# Spring_LDAP_LDAP_2_0_2_output.txt
# Spring_SWS_SWS_1_5_2_output.txt
# Spring_SOCIALTW_SOCIALTW_1_0_0_output.txt
# Spring_DATAMONGO_DATAMONGO_1_8_6_output.txt
# Spring_SEC_SEC_3_0_5_output.txt
# Spring_SGF_SGF_1_8_1_output.txt
# Commons_COMPRESS_COMPRESS_1_8_1_output.txt
# Apache_HIVE_HIVE_1_2_0_output.txt
# Commons_CONFIGURATION_CONFIGURATION_2_0_output.txt
# Apache_HBASE_HBASE_0_94_0_output.txt
# Spring_SWS_SWS_0_9_1_output.txt
# JBoss_ENTESB_ENTESB_6_2_1_output.txt
# Spring_DATAMONGO_DATAMONGO_1_0_2_output.txt
# Spring_ROO_ROO_1_0_1_output.txt
# Spring_BATCHADM_BATCHADM_1_2_0_output.txt
# Apache_HBASE_HBASE_1_1_6_output.txt
# Apache_CAMEL_CAMEL_2_8_6_output.txt
# Spring_AMQP_AMQP_1_4_5_output.txt
# Spring_AMQP_AMQP_1_1_4_output.txt
# Spring_DATAREST_DATAREST_2_4_4_output.txt
# Commons_MATH_MATH_3_1_output.txt
# Spring_SEC_SEC_3_2_2_output.txt
# Spring_DATAJPA_DATAJPA_1_0_0_output.txt
# Spring_BATCH_BATCH_3_0_0_output.txt
# Apache_CAMEL_CAMEL_1_6_1_output.txt
# Spring_DATACMNS_DATACMNS_1_2_1_output.txt
# Apache_HBASE_HBASE_0_94_21_output.txt
# Spring_DATAMONGO_DATAMONGO_1_3_1_output.txt
# Spring_DATAMONGO_DATAMONGO_1_8_1_output.txt
# Spring_SEC_SEC_3_2_5_output.txt
# Previous_AspectJ_AspectJ_1_6_0_M2_output.txt
# Commons_LANG_LANG_2_2_output.txt
# Spring_DATACMNS_DATACMNS_1_5_2_output.txt
# Spring_SOCIAL_SOCIAL_1_0_2_output.txt
# Apache_CAMEL_CAMEL_2_12_0_output.txt
# Spring_AMQP_AMQP_1_5_4_output.txt
# Spring_SWF_SWF_1_0_1_output.txt
# Apache_CAMEL_CAMEL_2_12_3_output.txt
# Spring_DATAJPA_DATAJPA_1_7_4_output.txt
# Wildfly_SWARM_SWARM_2016_10_0_output.txt
# Spring_DATAGRAPH_DATAGRAPH_3_2_4_output.txt
# Apache_HIVE_HIVE_2_1_0_output.txt
# Commons_LANG_LANG_2_6_output.txt
# Spring_DATACMNS_DATACMNS_1_12_5_output.txt
# Previous_JDT_JDT_4_5_output.txt
# Apache_HBASE_HBASE_1_2_3_output.txt
# Spring_DATACMNS_DATACMNS_1_10_1_output.txt
# Previous_SWT_SWT_3_139_output.txt
# JBoss_JBMETA_JBMETA_7_0_0_output.txt
# Apache_HBASE_HBASE_0_94_4_output.txt
# Spring_DATAGRAPH_DATAGRAPH_3_1_1_output.txt
# Commons_IO_IO_1_3_output.txt
# Apache_HBASE_HBASE_0_98_22_output.txt
# Spring_DATAMONGO_DATAMONGO_1_5_4_output.txt
# Spring_BATCH_BATCH_1_0_1_output.txt
# Spring_DATAREDIS_DATAREDIS_1_7_2_output.txt
# Spring_AMQP_AMQP_1_3_8_output.txt
# Spring_SOCIALFB_SOCIALFB_1_0_1_output.txt
# Commons_LANG_LANG_3_0_output.txt
# Spring_DATAGRAPH_DATAGRAPH_3_3_1_output.txt
# Commons_LANG_LANG_3_3_2_output.txt
# Apache_HBASE_HBASE_0_90_3_output.txt
# Spring_BATCH_BATCH_2_1_4_output.txt
# Spring_ROO_ROO_2_0_0_output.txt
# Commons_IO_IO_2_3_output.txt
# Commons_CODEC_CODEC_1_5_output.txt
# Spring_SEC_SEC_3_0_3_output.txt
# Apache_CAMEL_CAMEL_2_15_5_output.txt
# Commons_CSV_CSV_1_2_output.txt
# Spring_DATACMNS_DATACMNS_1_9_3_output.txt
# Spring_SOCIALTW_SOCIALTW_1_0_5_output.txt
# Apache_CAMEL_CAMEL_2_15_2_output.txt
# Spring_BATCH_BATCH_2_1_0_output.txt
# Apache_HBASE_HBASE_0_98_17_output.txt
# Spring_SWS_SWS_2_2_3_output.txt
# Apache_CAMEL_CAMEL_1_6_3_output.txt
# Spring_SPR_SPR_3_0_7_output.txt
# Spring_DATAREST_DATAREST_1_0_0_output.txt
# Spring_SGF_SGF_1_1_0_output.txt
# Previous_SWT_SWT_3_138_output.txt
# Commons_IO_IO_1_3_2_output.txt
# Spring_SWF_SWF_1_0_4_output.txt
# Spring_SWF_SWF_2_0_0_output.txt
# Spring_DATAJPA_DATAJPA_1_0_2_output.txt
# Spring_SECOAUTH_SECOAUTH_1_0_1_output.txt
# Commons_MATH_MATH_2_0_output.txt
# Spring_SPR_SPR_3_0_2_output.txt
# Spring_DATAGRAPH_DATAGRAPH_3_1_6_output.txt
# Commons_COMPRESS_COMPRESS_1_6_output.txt
# Commons_LANG_LANG_3_2_1_output.txt
# Apache_CAMEL_CAMEL_2_9_2_output.txt
# Apache_HBASE_HBASE_0_94_24_output.txt
# Apache_CAMEL_CAMEL_2_16_0_output.txt
# Commons_CONFIGURATION_CONFIGURATION_2_1_output.txt
# Wildfly_WFCORE_WFCORE_1_0_0_output.txt
# Spring_SWS_SWS_1_0_3_output.txt
# Spring_ROO_ROO_1_2_5_output.txt
# Spring_DATAJPA_DATAJPA_1_10_5_output.txt
# Apache_CAMEL_CAMEL_2_0_0_output.txt
# Spring_DATACMNS_DATACMNS_1_11_2_output.txt
# Apache_CAMEL_CAMEL_2_1_0_output.txt
# Spring_SWF_SWF_1_0_2_output.txt
# Spring_AMQP_AMQP_1_1_2_output.txt
# Spring_DATAREDIS_DATAREDIS_1_6_2_output.txt
# Apache_HBASE_HBASE_0_89_20100924_output.txt
# Apache_CAMEL_CAMEL_2_4_0_output.txt
# Apache_HIVE_HIVE_2_0_1_output.txt
# Spring_DATAREDIS_DATAREDIS_1_0_5_output.txt
# Spring_SHDP_SHDP_1_0_0_output.txt
# Wildfly_SWARM_SWARM_2016_12_0_output.txt
# Spring_SGF_SGF_1_1_1_output.txt
# Apache_HBASE_HBASE_0_98_3_output.txt
# Spring_DATAREDIS_DATAREDIS_1_1_0_output.txt
# Apache_CAMEL_CAMEL_2_3_0_output.txt
# Spring_SEC_SEC_3_2_1_output.txt
# Spring_SECOAUTH_SECOAUTH_1_0_2_output.txt
# Spring_DATACMNS_DATACMNS_1_8_5_output.txt
# Apache_HBASE_HBASE_0_94_8_output.txt
# Commons_LANG_LANG_3_4_output.txt
# Apache_CAMEL_CAMEL_2_13_3_output.txt
# Apache_CAMEL_CAMEL_2_13_0_output.txt
# Spring_DATAMONGO_DATAMONGO_1_3_3_output.txt
# Spring_DATAREST_DATAREST_2_1_6_output.txt
# Spring_BATCH_BATCH_3_0_3_output.txt
# Spring_SWF_SWF_2_0_5_output.txt
# Apache_HBASE_HBASE_0_99_2_output.txt
# Apache_CAMEL_CAMEL_2_9_4_output.txt
# Spring_DATAGRAPH_DATAGRAPH_4_1_1_output.txt
# Spring_DATAJPA_DATAJPA_1_7_3_output.txt
# Commons_MATH_MATH_3_3_output.txt
# Commons_COMPRESS_COMPRESS_1_12_output.txt
# Spring_DATACMNS_DATACMNS_1_3_2_output.txt
# Spring_DATAREDIS_DATAREDIS_1_4_4_output.txt
# Apache_CAMEL_CAMEL_2_16_2_output.txt
# Spring_DATAJPA_DATAJPA_1_4_3_output.txt
# Spring_ANDROID_ANDROID_1_0_1_output.txt
# Spring_SWS_SWS_1_0_2_output.txt
# Commons_COMPRESS_COMPRESS_1_1_output.txt
# JBoss_JBMETA_JBMETA_8_0_0_output.txt
# Spring_SWS_SWS_2_1_2_output.txt
# Apache_HBASE_HBASE_1_2_0_output.txt
# Apache_HBASE_HBASE_0_99_0_output.txt
# Spring_DATAJPA_DATAJPA_1_0_3_output.txt
# Commons_CODEC_CODEC_1_3_output.txt
# Spring_DATACMNS_DATACMNS_1_5_3_output.txt
# Spring_SEC_SEC_3_2_7_output.txt
# Apache_HIVE_HIVE_0_13_1_output.txt
# Apache_HBASE_HBASE_0_90_2_output.txt
# Spring_SECOAUTH_SECOAUTH_2_0_0_output.txt
# Commons_MATH_MATH_3_5_output.txt
# Apache_HBASE_HBASE_0_94_17_output.txt
# Spring_DATAREDIS_DATAREDIS_1_0_0_output.txt
# Apache_CAMEL_CAMEL_2_12_4_output.txt
# Spring_DATAREDIS_DATAREDIS_1_7_1_output.txt
# Spring_DATAGRAPH_DATAGRAPH_2_3_5_output.txt
# Spring_SPR_SPR_3_1_1_output.txt
# Apache_HIVE_HIVE_0_12_0_output.txt
# Commons_IO_IO_2_5_output.txt
# Commons_MATH_MATH_3_4_output.txt
# Spring_DATACMNS_DATACMNS_1_7_2_output.txt
# Spring_DATAREDIS_DATAREDIS_1_3_2_output.txt
# Spring_SGF_SGF_1_4_6_output.txt
# Apache_HBASE_HBASE_0_98_4_output.txt
# Spring_BATCH_BATCH_2_0_2_output.txt
# Spring_SEC_SEC_3_2_0_output.txt
# Wildfly_WFCORE_WFCORE_2_0_1_output.txt
# Apache_HIVE_HIVE_1_2_1_output.txt
# Spring_BATCH_BATCH_2_2_7_output.txt
# Apache_CAMEL_CAMEL_2_11_3_output.txt
# Spring_SGF_SGF_1_3_2_output.txt
# Apache_CAMEL_CAMEL_2_15_4_output.txt
# Wildfly_ELY_ELY_1_0_3_output.txt
# Apache_HBASE_HBASE_0_92_0_output.txt
# Spring_DATAREST_DATAREST_2_2_1_output.txt
# Spring_DATAREDIS_DATAREDIS_1_6_6_output.txt
# Commons_COMPRESS_COMPRESS_1_8_output.txt
# Spring_DATAJPA_DATAJPA_1_6_2_output.txt
# Apache_HIVE_HIVE_0_7_0_output.txt
# Spring_SHDP_SHDP_2_0_2_output.txt
# Apache_CAMEL_CAMEL_1_6_2_output.txt
# Wildfly_WFCORE_WFCORE_2_0_0_output.txt
# Spring_SECOAUTH_SECOAUTH_1_0_4_output.txt
# Spring_LDAP_LDAP_1_3_2_output.txt
# Apache_CAMEL_CAMEL_2_8_1_output.txt
# Spring_AMQP_AMQP_1_6_1_output.txt
# Spring_DATAMONGO_DATAMONGO_1_9_3_output.txt
# Spring_BATCH_BATCH_2_1_8_output.txt
# Spring_SEC_SEC_3_1_0_output.txt
# Spring_DATAMONGO_DATAMONGO_1_4_1_output.txt
# Spring_DATAREDIS_DATAREDIS_1_2_0_output.txt
# Commons_COMPRESS_COMPRESS_1_10_output.txt
# Commons_CRYPTO_CRYPTO_1_0_0_output.txt
# Commons_CSV_CSV_1_1_output.txt
# Commons_COMPRESS_COMPRESS_1_3_output.txt
# Spring_BATCH_BATCH_1_1_0_output.txt
# Spring_MOBILE_MOBILE_1_0_1_output.txt
# Spring_SOCIALFB_SOCIALFB_2_0_0_output.txt
# Spring_DATAJPA_DATAJPA_1_3_1_output.txt
# Apache_CAMEL_CAMEL_2_11_0_output.txt
# Spring_DATAJPA_DATAJPA_1_5_2_output.txt
# Spring_DATAJPA_DATAJPA_1_3_5_output.txt
# Spring_SHDP_SHDP_2_0_0_output.txt
# Spring_DATAJPA_DATAJPA_1_3_2_output.txt
# Spring_SWS_SWS_2_2_4_output.txt
# Spring_AMQP_AMQP_1_5_6_output.txt
# Commons_CONFIGURATION_CONFIGURATION_1_7_output.txt
# Apache_CAMEL_CAMEL_2_12_2_output.txt
# Spring_SOCIALLI_SOCIALLI_1_0_0_output.txt
# Apache_CAMEL_CAMEL_1_6_4_output.txt
# Spring_DATAJPA_DATAJPA_1_9_5_output.txt
# Spring_ROO_ROO_1_2_2_output.txt
# Spring_DATAREST_DATAREST_2_1_4_output.txt
# Spring_ROO_ROO_1_1_1_output.txt
# Spring_AMQP_AMQP_1_3_7_output.txt
# Spring_SWS_SWS_1_5_4_output.txt
# Spring_SWS_SWS_1_5_8_output.txt
# Commons_LANG_LANG_3_1_output.txt
# Spring_DATAGRAPH_DATAGRAPH_3_4_6_output.txt
# Apache_HBASE_HBASE_0_96_0_output.txt
# Spring_AMQP_AMQP_1_5_3_output.txt
# Spring_DATAMONGO_DATAMONGO_1_6_2_output.txt
# Commons_MATH_MATH_2_1_output.txt
# Spring_SECOAUTH_SECOAUTH_1_0_0_output.txt
# Apache_HBASE_HBASE_1_0_0_output.txt
# Spring_SHDP_SHDP_2_0_1_output.txt
# Wildfly_WFLY_WFLY_7_1_1_output.txt
# Spring_SWF_SWF_2_0_3_output.txt
# Spring_SHDP_SHDP_2_2_0_output.txt
# Spring_SGF_SGF_1_2_0_output.txt
# Apache_HBASE_HBASE_0_98_21_output.txt
# Apache_CAMEL_CAMEL_2_12_5_output.txt
# Wildfly_WFCORE_WFCORE_1_0_1_output.txt
# Spring_SEC_SEC_3_0_0_output.txt
# Spring_DATAREST_DATAREST_2_5_5_output.txt
# Apache_HBASE_HBASE_0_90_6_output.txt
# Spring_SHL_SHL_1_0_0_output.txt
# Wildfly_WFCORE_WFCORE_2_0_6_output.txt
# Spring_AMQP_AMQP_1_6_3_output.txt
# Spring_DATAJPA_DATAJPA_1_6_6_output.txt
# Spring_SWS_SWS_2_0_1_output.txt
# Spring_DATACMNS_DATACMNS_1_9_2_output.txt
# Spring_DATAREDIS_DATAREDIS_1_3_4_output.txt
# Spring_DATAJPA_DATAJPA_1_4_4_output.txt
# Apache_HBASE_HBASE_1_2_1_output.txt
# Apache_CAMEL_CAMEL_2_10_4_output.txt
# Wildfly_WFLY_WFLY_9_0_2_output.txt
# Spring_DATAJPA_DATAJPA_1_9_2_output.txt
# Spring_DATAJPA_DATAJPA_1_5_1_output.txt
# Wildfly_WFLY_WFLY_7_2_0_output.txt
# Apache_HBASE_HBASE_0_94_18_output.txt
# Commons_CONFIGURATION_CONFIGURATION_1_6_output.txt
# Apache_HBASE_HBASE_1_1_5_output.txt
# Spring_BATCH_BATCH_2_1_2_output.txt
# Commons_COLLECTIONS_COLLECTIONS_3_2_output.txt
# Apache_HBASE_HBASE_0_98_12_output.txt
# Spring_DATAMONGO_DATAMONGO_1_4_3_output.txt
# Commons_COMPRESS_COMPRESS_1_9_output.txt
# Spring_DATAMONGO_DATAMONGO_1_0_3_output.txt
# Apache_HIVE_HIVE_0_9_0_output.txt
# Spring_DATAJPA_DATAJPA_1_3_3_output.txt
# Spring_MOBILE_MOBILE_1_1_0_output.txt
# Spring_SEC_SEC_3_0_7_output.txt
# Spring_SOCIALFB_SOCIALFB_1_0_0_output.txt
# Spring_DATACMNS_DATACMNS_1_0_0_output.txt
# Spring_SHDP_SHDP_2_0_3_output.txt
# Spring_LDAP_LDAP_2_0_0_output.txt
# Spring_BATCH_BATCH_2_2_2_output.txt
# Wildfly_WFCORE_WFCORE_2_0_7_output.txt
# Apache_HBASE_HBASE_0_98_1_output.txt
# Spring_DATAREST_DATAREST_2_4_1_output.txt
# Commons_CONFIGURATION_CONFIGURATION_1_10_output.txt
# Spring_DATACMNS_DATACMNS_1_9_4_output.txt
# Commons_IO_IO_1_3_1_output.txt
# Spring_DATAMONGO_DATAMONGO_1_2_3_output.txt
# Spring_DATAGRAPH_DATAGRAPH_2_2_3_output.txt
# Spring_DATACMNS_DATACMNS_1_9_1_output.txt
# Spring_BATCH_BATCH_2_0_4_output.txt
# Apache_HBASE_HBASE_0_94_10_output.txt
# Apache_CAMEL_CAMEL_2_14_1_output.txt
# Commons_COMPRESS_COMPRESS_1_7_output.txt
# Spring_SEC_SEC_2_0_0_output.txt
# Apache_CAMEL_CAMEL_2_17_0_output.txt
# Spring_ROO_ROO_1_1_2_output.txt
# Spring_BATCH_BATCH_2_0_0_output.txt
# Spring_MOBILE_MOBILE_1_0_0_output.txt
# Spring_ROO_ROO_1_2_0_output.txt
# Spring_SEC_SEC_4_0_3_output.txt
# Commons_LANG_LANG_3_0_1_output.txt
# Spring_ANDROID_ANDROID_1_0_0_output.txt
# Spring_SWS_SWS_1_0_1_output.txt
# Spring_SGF_SGF_1_3_1_output.txt
# Apache_HIVE_HIVE_0_11_0_output.txt
# Spring_DATAJPA_DATAJPA_1_4_1_output.txt
# Spring_DATAMONGO_DATAMONGO_1_5_1_output.txt
# Spring_DATAGRAPH_DATAGRAPH_2_0_1_output.txt
# Spring_BATCH_BATCH_2_2_1_output.txt
# Spring_SEC_SEC_3_2_3_output.txt
# Spring_DATAJPA_DATAJPA_1_5_3_output.txt
# Apache_HBASE_HBASE_0_90_4_output.txt
# Spring_SOCIALTW_SOCIALTW_1_0_1_output.txt
# Spring_DATACMNS_DATACMNS_1_12_1_output.txt
# Spring_SOCIAL_SOCIAL_1_0_0_output.txt
# Spring_SEC_SEC_2_0_3_output.txt
# Spring_SEC_SEC_3_1_1_output.txt
# Apache_CAMEL_CAMEL_2_2_0_output.txt
# Spring_SGF_SGF_1_5_2_output.txt
# Apache_HBASE_HBASE_1_1_0_output.txt
# Spring_SECOAUTH_SECOAUTH_1_0_5_output.txt
# Spring_DATAJPA_DATAJPA_1_8_1_output.txt
# Spring_AMQP_AMQP_1_1_3_output.txt
# Apache_HIVE_HIVE_1_1_0_output.txt
# Spring_BATCH_BATCH_2_2_4_output.txt
# Spring_DATACMNS_DATACMNS_1_1_0_output.txt
# Commons_MATH_MATH_3_1_1_output.txt
# Commons_MATH_MATH_1_0_output.txt
# Spring_SGF_SGF_1_4_4_output.txt
# Spring_DATAMONGO_DATAMONGO_1_3_5_output.txt
# Spring_BATCH_BATCH_1_0_0_output.txt
# Spring_DATAREDIS_DATAREDIS_1_5_2_output.txt
# Spring_SWS_SWS_2_0_2_output.txt
# Commons_COMPRESS_COMPRESS_1_4_output.txt
# Spring_SEC_SEC_2_0_4_output.txt
# Spring_SGF_SGF_1_2_1_output.txt
# Spring_AMQP_AMQP_1_4_4_output.txt
# Previous_AspectJ_AspectJ_1_6_0_M2_up_output.txt
# Spring_DATACMNS_DATACMNS_1_4_1_output.txt
# Spring_SEC_SEC_4_0_2_output.txt
# Spring_SEC_SEC_2_0_6_output.txt
# Spring_DATAMONGO_DATAMONGO_1_0_0_output.txt
# Apache_HBASE_HBASE_0_98_6_output.txt
# Spring_DATAMONGO_DATAMONGO_1_6_4_output.txt
# Commons_COLLECTIONS_COLLECTIONS_3_0_output.txt
# Spring_DATAMONGO_DATAMONGO_1_8_5_output.txt
# Apache_HBASE_HBASE_0_98_16_output.txt
# Spring_DATAJPA_DATAJPA_1_10_3_output.txt
# Commons_LANG_LANG_2_5_output.txt
# Spring_SPR_SPR_3_0_5_output.txt
# Commons_IO_IO_1_2_output.txt
# Commons_CODEC_CODEC_1_8_output.txt
# Spring_SWS_SWS_1_5_1_output.txt
# Wildfly_WFLY_WFLY_8_2_0_output.txt
# Spring_DATAREST_DATAREST_2_4_5_output.txt
# Commons_IO_IO_2_0_output.txt
# Spring_SOCIALTW_SOCIALTW_1_1_0_output.txt
# Commons_CODEC_CODEC_1_10_output.txt
# Spring_DATAMONGO_DATAMONGO_1_0_1_output.txt
# Commons_CONFIGURATION_CONFIGURATION_1_3_output.txt
# Spring_DATAMONGO_DATAMONGO_1_9_4_output.txt
# Previous_PDE_PDE_4_4_output.txt
# JBoss_JBMETA_JBMETA_7_1_1_output.txt
# Commons_CODEC_CODEC_1_6_output.txt
# Spring_BATCH_BATCH_1_1_2_output.txt
# Spring_DATACMNS_DATACMNS_1_7_3_output.txt
# Spring_DATACMNS_DATACMNS_1_8_4_output.txt
# Commons_IO_IO_1_0_output.txt
# Spring_AMQP_AMQP_1_2_1_output.txt
# Spring_DATAMONGO_DATAMONGO_1_7_2_output.txt
# Spring_SWF_SWF_2_2_0_output.txt
# Wildfly_ELY_ELY_1_0_2_output.txt
# Commons_LANG_LANG_3_2_output.txt
# Spring_DATAGRAPH_DATAGRAPH_2_1_0_output.txt
# Spring_SPR_SPR_3_0_4_output.txt
# Spring_DATAGRAPH_DATAGRAPH_4_0_0_output.txt
# Apache_HIVE_HIVE_0_10_0_output.txt
# Spring_AMQP_AMQP_1_1_0_output.txt
# Spring_BATCH_BATCH_2_0_3_output.txt
# Spring_SPR_SPR_4_2_5_output.txt
# Spring_DATAMONGO_DATAMONGO_1_3_4_output.txt
# Spring_DATAGRAPH_DATAGRAPH_3_0_3_output.txt
# Spring_BATCH_BATCH_2_1_5_output.txt
# Spring_SEC_SEC_3_1_4_output.txt
# Apache_HIVE_HIVE_0_7_1_output.txt
# Commons_COLLECTIONS_COLLECTIONS_3_2_1_output.txt
# Spring_ROO_ROO_1_2_1_output.txt
# Apache_HIVE_HIVE_0_14_0_output.txt
# Commons_COMPRESS_COMPRESS_1_11_output.txt
# Spring_SWF_SWF_2_0_6_output.txt
# Apache_HBASE_HBASE_1_0_2_output.txt
# Apache_CAMEL_CAMEL_1_6_0_output.txt
# Spring_ROO_ROO_1_1_4_output.txt
# Apache_CAMEL_CAMEL_2_14_2_output.txt
# Spring_SOCIAL_SOCIAL_1_1_0_output.txt
# Spring_DATACMNS_DATACMNS_1_8_6_output.txt
# Spring_DATAMONGO_DATAMONGO_1_2_1_output.txt
# Spring_DATAREST_DATAREST_2_0_3_output.txt
# Apache_HBASE_HBASE_0_90_0_output.txt
# Spring_DATACMNS_DATACMNS_1_6_1_output.txt
# Commons_CONFIGURATION_CONFIGURATION_1_8_output.txt
# Apache_CAMEL_CAMEL_2_12_1_output.txt
# Apache_CAMEL_CAMEL_2_7_0_output.txt
# Spring_SWF_SWF_2_2_1_output.txt
# JBoss_ENTESB_ENTESB_6_2_0_output.txt
# Wildfly_WFCORE_WFCORE_2_1_0_output.txt
# Spring_SWS_SWS_2_0_3_output.txt
# Spring_AMQP_AMQP_1_4_3_output.txt
# Apache_CAMEL_CAMEL_2_14_3_output.txt
# Spring_SEC_SEC_3_0_6_output.txt
# Commons_CSV_CSV_1_0_output.txt
# Spring_SEC_SEC_3_2_9_output.txt
# Spring_DATAMONGO_DATAMONGO_1_0_4_output.txt
# Apache_CAMEL_CAMEL_2_11_2_output.txt
# Spring_DATAMONGO_DATAMONGO_1_8_2_output.txt
# Wildfly_WFCORE_WFCORE_2_0_8_output.txt
# Commons_CONFIGURATION_CONFIGURATION_1_2_output.txt
# Spring_DATAREST_DATAREST_1_1_0_output.txt
# Wildfly_WFCORE_WFCORE_1_0_2_output.txt
# Apache_HBASE_HBASE_1_1_7_output.txt
# Apache_HBASE_HBASE_0_95_2_output.txt
# Spring_SWS_SWS_1_0_4_output.txt
# Spring_DATAMONGO_DATAMONGO_1_5_2_output.txt
# Spring_BATCH_BATCH_2_2_5_output.txt
# Apache_CAMEL_CAMEL_2_10_0_output.txt
# Spring_DATAJPA_DATAJPA_1_6_4_output.txt
# Spring_BATCHADM_BATCHADM_1_2_1_output.txt
# Spring_DATAMONGO_DATAMONGO_1_5_6_output.txt
# Spring_DATAREST_DATAREST_2_5_1_output.txt
# Spring_DATAREST_DATAREST_2_3_1_output.txt
# Spring_SGF_SGF_1_4_1_output.txt
# Spring_DATAJPA_DATAJPA_1_4_2_output.txt
# Spring_SOCIAL_SOCIAL_1_0_1_output.txt
# Apache_HBASE_HBASE_0_98_11_output.txt
# Spring_DATAREST_DATAREST_2_1_1_output.txt
# Spring_DATAREST_DATAREST_2_1_2_output.txt
# Spring_SEC_SEC_2_0_2_output.txt
# Spring_AMQP_AMQP_1_4_6_output.txt
# Apache_CAMEL_CAMEL_2_13_4_output.txt
# Apache_HBASE_HBASE_0_98_23_output.txt
# Spring_SEC_SEC_3_2_8_output.txt
# Spring_DATAREST_DATAREST_2_0_2_output.txt
# Spring_DATAMONGO_DATAMONGO_1_8_4_output.txt
# Spring_SWF_SWF_2_1_1_output.txt
# Spring_DATAJPA_DATAJPA_1_10_2_output.txt
# Commons_COMPRESS_COMPRESS_1_5_output.txt
# Spring_DATAJPA_DATAJPA_1_7_2_output.txt
# Spring_DATAREDIS_DATAREDIS_1_4_1_output.txt
# Spring_DATACMNS_DATACMNS_1_5_1_output.txt
# Spring_SWS_SWS_2_2_0_output.txt
# Spring_DATACMNS_DATACMNS_1_10_2_output.txt
# Spring_BATCH_BATCH_2_2_0_output.txt
# Apache_HBASE_HBASE_0_90_1_output.txt
# Spring_DATAREDIS_DATAREDIS_1_3_5_output.txt
# Spring_SWS_SWS_1_5_5_output.txt
# Apache_CAMEL_CAMEL_2_13_2_output.txt
# Spring_SOCIALTW_SOCIALTW_1_0_2_output.txt
# Commons_COLLECTIONS_COLLECTIONS_4_1_output.txt
# Apache_CAMEL_CAMEL_2_16_1_output.txt
# Spring_AMQP_AMQP_1_3_0_output.txt
# Apache_CAMEL_CAMEL_2_14_0_output.txt
# Spring_BATCH_BATCH_2_2_6_output.txt
# Commons_WEAVER_WEAVER_1_2_output.txt
# Spring_DATAMONGO_DATAMONGO_1_7_1_output.txt
# Apache_HBASE_HBASE_0_98_13_output.txt
# Apache_HBASE_HBASE_0_92_1_output.txt
# Spring_DATAMONGO_DATAMONGO_1_3_2_output.txt
# Commons_COMPRESS_COMPRESS_1_2_output.txt
# Spring_SGF_SGF_1_3_4_output.txt
# Commons_MATH_MATH_2_2_output.txt
# Apache_HBASE_HBASE_0_98_7_output.txt
# Spring_DATAREDIS_DATAREDIS_1_6_4_output.txt
# Commons_LANG_LANG_2_0_output.txt
# Spring_DATAGRAPH_DATAGRAPH_1_0_0_output.txt
# Commons_COLLECTIONS_COLLECTIONS_3_2_2_output.txt
# Spring_SWF_SWF_2_0_4_output.txt
# Spring_DATAREST_DATAREST_2_3_2_output.txt
# Wildfly_WFCORE_WFCORE_2_0_10_output.txt
# Spring_SEC_SEC_1_0_4_output.txt
# Commons_CODEC_CODEC_1_4_output.txt
# Spring_SOCIALFB_SOCIALFB_1_1_0_output.txt
# Spring_DATAJPA_DATAJPA_1_10_1_output.txt
# Spring_DATAJPA_DATAJPA_1_7_1_output.txt
# Spring_AMQP_AMQP_1_6_2_output.txt
# Apache_CAMEL_CAMEL_2_7_1_output.txt
# Apache_HBASE_HBASE_0_98_20_output.txt
# Apache_HBASE_HBASE_0_98_15_output.txt
# Wildfly_WFLY_WFLY_9_0_0_output.txt
# Spring_BATCH_BATCH_1_1_3_output.txt
# Commons_MATH_MATH_3_0_output.txt
# Spring_DATAREDIS_DATAREDIS_1_3_1_output.txt
# Spring_SHDP_SHDP_2_3_0_output.txt
# Spring_ROO_ROO_1_2_4_output.txt
# Apache_CAMEL_CAMEL_2_11_4_output.txt
# Spring_AMQP_AMQP_1_2_0_output.txt
# Wildfly_WFLY_WFLY_8_0_0_output.txt
# Spring_DATAGRAPH_DATAGRAPH_3_0_1_output.txt
# Commons_CONFIGURATION_CONFIGURATION_1_4_output.txt
# Apache_CAMEL_CAMEL_2_9_5_output.txt
# Spring_DATAJPA_DATAJPA_1_10_4_output.txt
# Apache_HBASE_HBASE_1_0_1_output.txt
# Spring_AMQP_AMQP_1_4_1_output.txt
# Spring_SEC_SEC_3_1_3_output.txt
# Spring_BATCH_BATCH_2_1_6_output.txt
# Spring_DATAMONGO_DATAMONGO_1_4_2_output.txt
# Spring_DATACMNS_DATACMNS_1_12_2_output.txt
# Spring_DATAREST_DATAREST_2_0_1_output.txt
# Spring_SEC_SEC_1_0_1_output.txt
# Spring_SWF_SWF_2_0_2_output.txt
# Spring_SWS_SWS_1_5_6_output.txt
# Spring_ROO_ROO_1_1_5_output.txt
# Wildfly_WFMP_WFMP_1_1_0_output.txt
# Apache_HBASE_HBASE_1_1_1_output.txt
# Spring_SGF_SGF_1_3_3_output.txt
# Spring_BATCH_BATCH_3_0_1_output.txt
# Spring_DATAJPA_DATAJPA_1_6_5_output.txt
# Spring_SWS_SWS_1_5_10_output.txt
# Apache_HBASE_HBASE_0_20_5_output.txt
# Spring_AMQP_AMQP_1_3_6_output.txt
# Commons_CODEC_CODEC_1_1_output.txt
# Spring_SEC_SEC_1_0_5_output.txt
# Spring_SEC_SEC_3_2_4_output.txt
# Spring_SGF_SGF_1_5_3_output.txt
# Spring_SGF_SGF_1_6_2_output.txt
# Previous_AspectJ_AspectJ_1_5_0_M2_output.txt
# Apache_HBASE_HBASE_0_92_2_output.txt
# Spring_AMQP_AMQP_1_3_3_output.txt
# Apache_HIVE_HIVE_0_8_0_output.txt
# Apache_HBASE_HBASE_0_98_10_output.txt
# Apache_HBASE_HBASE_0_94_3_output.txt
# Spring_SEC_SEC_3_0_4_output.txt
# Wildfly_WFLY_WFLY_10_1_0_output.txt
# Spring_SGF_SGF_1_4_5_output.txt
# Apache_HBASE_HBASE_0_98_19_output.txt
# Apache_HBASE_HBASE_0_94_2_output.txt
# Spring_DATAGRAPH_DATAGRAPH_1_1_0_output.txt
# Commons_COLLECTIONS_COLLECTIONS_4_0_output.txt
# Spring_DATACMNS_DATACMNS_1_12_3_output.txt
# Apache_CAMEL_CAMEL_2_9_0_output.txt
# Spring_SEC_SEC_3_0_2_output.txt
# Spring_SGF_SGF_1_0_0_output.txt
# JBoss_ENTESB_ENTESB_6_3_0_output.txt
# Apache_CAMEL_CAMEL_2_10_6_output.txt
# Previous_AspectJ_AspectJ_1_5_3_final_output.txt
# Apache_HBASE_HBASE_1_1_4_output.txt
# Commons_IO_IO_2_1_output.txt
# Wildfly_SWARM_SWARM_2016_8_output.txt
# Spring_DATAGRAPH_DATAGRAPH_4_1_6_output.txt
# Apache_HBASE_HBASE_0_94_27_output.txt
# Spring_BATCH_BATCH_2_1_7_output.txt
# Spring_SEC_SEC_2_0_5_output.txt
# Spring_DATAMONGO_DATAMONGO_1_6_3_output.txt
# Apache_HIVE_HIVE_0_6_0_output.txt
# Commons_MATH_MATH_1_1_output.txt
# Spring_SGF_SGF_1_7_6_output.txt
# Spring_SWS_SWS_1_5_7_output.txt
# Spring_DATAMONGO_DATAMONGO_1_9_6_output.txt
# Spring_SWF_SWF_1_0_5_output.txt
# Wildfly_SWARM_SWARM_1_0_0_output.txt
# Apache_CAMEL_CAMEL_2_6_0_output.txt
# Wildfly_WFCORE_WFCORE_2_2_0_output.txt
# Spring_ROO_ROO_1_1_3_output.txt
# Apache_HIVE_HIVE_1_1_1_output.txt
# Spring_ROO_ROO_1_0_2_output.txt
# Wildfly_WFARQ_WFARQ_1_1_0_output.txt
# Spring_DATAREST_DATAREST_2_5_2_output.txt
# Apache_CAMEL_CAMEL_2_17_1_output.txt
# Spring_BATCHADM_BATCHADM_1_0_0_output.txt
# Apache_CAMEL_CAMEL_2_11_1_output.txt
# Wildfly_SWARM_SWARM_2016_9_output.txt
# Spring_SWF_SWF_2_1_0_output.txt
# Spring_DATACMNS_DATACMNS_1_12_6_output.txt
# Apache_CAMEL_CAMEL_2_13_1_output.txt
# Spring_SPR_SPR_3_0_1_output.txt
# Apache_HBASE_HBASE_0_89_20100621_output.txt
# Apache_HBASE_HBASE_0_90_5_output.txt
# Spring_BATCH_BATCH_1_1_1_output.txt
# Wildfly_WFCORE_WFCORE_2_0_5_output.txt
# Spring_DATAMONGO_DATAMONGO_1_1_1_output.txt
# Commons_COMPRESS_COMPRESS_1_0_output.txt
# Spring_DATAJPA_DATAJPA_1_1_2_output.txt
# Commons_CONFIGURATION_CONFIGURATION_1_9_output.txt
# Commons_IO_IO_1_4_output.txt
# Spring_DATAMONGO_DATAMONGO_1_1_2_output.txt
# Spring_AMQP_AMQP_1_0_0_output.txt
# Spring_SEC_SEC_1_0_6_output.txt
# Spring_DATACMNS_DATACMNS_1_11_6_output.txt
# Apache_HBASE_HBASE_0_98_2_output.txt
# Spring_AMQP_AMQP_1_6_6_output.txt
# Spring_BATCH_BATCH_2_0_1_output.txt
# Apache_CAMEL_CAMEL_2_17_2_output.txt
# Previous_SWT_SWT_3_659_output.txt
# Apache_CAMEL_CAMEL_2_15_6_output.txt
# Apache_CAMEL_CAMEL_2_10_7_output.txt
# Spring_DATAJPA_DATAJPA_1_8_2_output.txt
# Spring_SECOAUTH_SECOAUTH_1_0_3_output.txt
# Spring_SWF_SWF_2_0_8_output.txt
# Spring_DATAMONGO_DATAMONGO_1_5_5_output.txt
# Spring_BATCH_BATCH_2_1_9_output.txt
# Spring_SEC_SEC_4_0_0_output.txt
# Spring_DATAREST_DATAREST_2_4_2_output.txt
# Apache_HBASE_HBASE_0_98_0_output.txt
# Apache_CAMEL_CAMEL_2_18_0_output.txt
# Spring_BATCH_BATCH_2_1_1_output.txt
# Commons_MATH_MATH_1_2_output.txt
# Commons_IO_IO_2_4_output.txt
# Spring_SWS_SWS_2_2_1_output.txt
# Spring_DATAREST_DATAREST_2_2_2_output.txt
# Apache_HBASE_HBASE_0_98_14_output.txt
# Spring_AMQP_AMQP_1_4_2_output.txt
# Apache_CAMEL_CAMEL_2_15_3_output.txt
# Spring_SWS_SWS_1_5_9_output.txt
# Spring_SHL_SHL_1_1_0_output.txt
# Wildfly_SWARM_SWARM_2016_11_0_output.txt
# Spring_AMQP_AMQP_1_5_1_output.txt
# Commons_IO_IO_1_1_output.txt
# Apache_HIVE_HIVE_1_0_0_output.txt
# Spring_BATCH_BATCH_2_1_3_output.txt
# Wildfly_WFCORE_WFCORE_2_0_3_output.txt
# Spring_DATAGRAPH_DATAGRAPH_2_3_1_output.txt
# Spring_DATAGRAPH_DATAGRAPH_3_4_4_output.txt
# Apache_CAMEL_CAMEL_2_8_0_output.txt
# Spring_DATACMNS_DATACMNS_1_8_2_output.txt
# Spring_AMQP_AMQP_1_3_4_output.txt
# Commons_LANG_LANG_3_5_output.txt
# Apache_CAMEL_CAMEL_2_16_3_output.txt
# Spring_SPR_SPR_3_0_6_output.txt
# Spring_DATAJPA_DATAJPA_1_6_1_output.txt
# Spring_SWF_SWF_1_0_3_output.txt
# Spring_DATAJPA_DATAJPA_1_3_4_output.txt
# Apache_CAMEL_CAMEL_2_17_3_output.txt
# Spring_BATCHADM_BATCHADM_1_3_0_output.txt
# Spring_ROO_ROO_1_0_0_output.txt
# Spring_AMQP_AMQP_1_5_5_output.txt
# Spring_SWF_SWF_2_3_0_output.txt
# Commons_COLLECTIONS_COLLECTIONS_3_1_output.txt
# JBoss_JBMETA_JBMETA_7_0_4_output.txt
# Spring_DATAREST_DATAREST_2_5_4_output.txt
# Wildfly_WFLY_WFLY_8_2_1_output.txt
# Spring_DATACMNS_DATACMNS_1_6_2_output.txt
# Apache_CAMEL_CAMEL_2_5_0_output.txt
# Spring_SGF_SGF_1_2_2_output.txt
# Apache_HIVE_HIVE_2_0_0_output.txt
# Spring_SEC_SEC_1_0_2_output.txt
# Spring_DATAREDIS_DATAREDIS_1_2_1_output.txt
# Apache_HIVE_HIVE_0_8_1_output.txt
# Apache_CAMEL_CAMEL_2_15_1_output.txt
# Spring_SWF_SWF_2_0_1_output.txt
# Commons_IO_IO_2_0_1_output.txt
# Apache_HBASE_HBASE_1_1_2_output.txt
# Spring_AMQP_AMQP_1_1_1_output.txt
# Apache_HBASE_HBASE_0_94_6_output.txt
# Spring_SEC_SEC_3_2_6_output.txt
# Spring_DATAMONGO_DATAMONGO_1_9_5_output.txt
# Apache_HBASE_HBASE_1_0_3_output.txt
# Apache_HBASE_HBASE_1_2_2_output.txt
# Spring_SWS_SWS_2_0_5_output.txt
# Spring_SEC_SEC_1_0_3_output.txt
# Apache_HBASE_HBASE_0_94_5_output.txt
# Wildfly_ELY_ELY_1_0_0_output.txt
# Spring_DATAREST_DATAREST_2_2_4_output.txt
# Spring_SEC_SEC_2_0_7_output.txt
# Apache_HIVE_HIVE_1_0_1_output.txt
# Spring_LDAP_LDAP_2_0_3_output.txt
# Wildfly_WFLY_WFLY_8_1_0_output.txt
# Wildfly_WFCORE_WFCORE_2_0_2_output.txt
# Spring_SWS_SWS_2_0_4_output.txt
# Commons_LANG_LANG_3_3_output.txt
# Wildfly_WFLY_WFLY_10_0_0_output.txt
# Spring_AMQP_AMQP_1_5_2_output.txt
# Spring_LDAP_LDAP_2_0_1_output.txt
# Spring_DATAMONGO_DATAMONGO_1_2_4_output.txt
# Spring_SEC_SEC_2_0_1_output.txt
# Commons_CONFIGURATION_CONFIGURATION_1_5_output.txt
# Apache_HBASE_HBASE_0_94_1_output.txt
# Spring_ROO_ROO_1_1_0_output.txt
# Apache_CAMEL_CAMEL_2_8_3_output.txt
# Commons_CODEC_CODEC_1_2_output.txt
# Apache_HBASE_HBASE_1_1_3_output.txt
# Spring_SEC_SEC_3_0_1_output.txt
# Spring_AMQP_AMQP_1_3_9_output.txt
# Spring_SWF_SWF_2_0_7_output.txt
# Spring_DATAREST_DATAREST_2_4_6_output.txt
# Commons_COMPRESS_COMPRESS_1_4_1_output.txt
# Commons_MATH_MATH_3_6_1_output.txt
# Spring_SOCIALFB_SOCIALFB_2_0_1_output.txt
# Apache_HBASE_HBASE_0_98_5_output.txt
# Commons_LANG_LANG_2_3_output.txt
# Spring_SPR_SPR_3_0_0_output.txt
# Spring_SWS_SWS_1_5_3_output.txt
# Spring_SWF_SWF_2_0_9_output.txt
# Previous_ZXing_ZXing_1_6_output.txt
# Spring_DATAJPA_DATAJPA_1_4_5_output.txt
# Spring_DATAJPA_DATAJPA_1_9_4_output.txt
# Spring_DATAMONGO_DATAMONGO_1_6_1_output.txt
# Wildfly_WFCORE_WFCORE_3_0_0_output.txt
# Spring_SPR_SPR_3_0_3_output.txt
# Spring_SHDP_SHDP_2_1_0_output.txt
# Spring_BATCH_BATCH_2_2_3_output.txt
# Apache_HBASE_HBASE_0_98_8_output.txt
# Spring_DATACMNS_DATACMNS_1_11_4_output.txt
# Commons_MATH_MATH_3_2_output.txt
# Spring_SEC_SEC_4_0_1_output.txt
# Spring_DATAJPA_DATAJPA_1_2_1_output.txt
# Spring_BATCH_BATCH_1_1_4_output.txt
# Apache_HBASE_HBASE_1_2_4_output.txt
# ...
# Spring_MOBILE                 0.272727         0.636364          0.909091
# Spring_ROO                    0.319661         0.647808          0.775106
# Spring_SEC                    0.467652         0.707948          0.774492
# Spring_SECOAUTH               0.312500         0.531250          0.625000
# Spring_SGF                    0.457143         0.704762          0.752381
# Spring_SHDP                   0.463415         0.731707          0.780488
# Spring_SHL                    0.555556         0.555556          0.666667
# Spring_SOCIAL                 0.533333         0.733333          0.733333
# Spring_SOCIALFB               0.466667         0.933333          1.000000
# Spring_SOCIALLI               0.333333         1.000000          1.000000
# Spring_SOCIALTW               0.500000         0.625000          0.875000
# Spring_SPR                    0.293651         0.507937          0.595238
# Spring_SWF                    0.358209         0.574627          0.649254
# Spring_SWS                    0.395349         0.546512          0.610465
# Wildfly_ELY                   0.086957         0.260870          0.260870
# Wildfly_SWARM                 0.214286         0.589286          0.660714
# Wildfly_WFARQ                 0.000000         1.000000          1.000000
# Wildfly_WFCORE                0.289086         0.528024          0.628319
# Wildfly_WFLY                  0.261538         0.485714          0.605495
# Wildfly_WFMP                  0.333333         1.000000          1.000000
#
#                        MAP_bluir  MRR_bluir  HIT1_bluir  ...  MAP_locus  \
# project                                                  ...
# Apache_CAMEL            0.215749   0.215884    0.125344  ...   0.468673
# Apache_HBASE            0.252355   0.260922    0.165501  ...   0.463303
# Apache_HIVE             0.213947   0.216826    0.139459  ...   0.359737
# Commons_CODEC           0.703630   0.707046    0.560976  ...   0.737634
# Commons_COLLECTIONS     0.378350   0.363965    0.247312  ...   0.702980
# Commons_COMPRESS        0.390213   0.398244    0.216216  ...   0.705223
# Commons_CONFIGURATION   0.389311   0.393490    0.288889  ...   0.572495
# Commons_CRYPTO          0.184375   0.184375    0.125000  ...   0.381819
# Commons_CSV             0.579167   0.588690    0.500000  ...   0.636395
# Commons_IO              0.391656   0.391373    0.250000  ...   0.698486
# Commons_LANG            0.398922   0.396146    0.258373  ...   0.605167
# Commons_MATH            0.510787   0.501555    0.370536  ...   0.501548
# Commons_WEAVER          0.102679   0.071429    0.000000  ...   0.367923
# JBoss_ENTESB            0.061955   0.048768    0.025641  ...   0.050929
# JBoss_JBMETA            0.181984   0.172840    0.115385  ...   0.319096
# Previous_AspectJ        0.012033   0.012719    0.009649  ...   0.219378
# Previous_JDT            0.161768   0.163812    0.117021  ...   0.223988
# Previous_PDE            0.176371   0.178709    0.101695  ...   0.402320
# Previous_SWT            0.391655   0.389067    0.278912  ...   0.088689
# Previous_ZXing          0.303437   0.318027    0.250000  ...   0.466918
# Spring_AMQP             0.340249   0.354718    0.217822  ...   0.533102
# Spring_ANDROID          0.328013   0.350840    0.222222  ...   0.618962
# Spring_BATCH            0.274105   0.285747    0.177184  ...   0.489880
# Spring_BATCHADM         0.234675   0.213523    0.105263  ...   0.552318
# Spring_DATACMNS         0.303119   0.307538    0.200000  ...   0.517731
# Spring_DATAGRAPH        0.125130   0.128498    0.094737  ...   0.078892
# Spring_DATAJPA          0.314225   0.325512    0.216216  ...   0.542809
# Spring_DATAMONGO        0.289282   0.296357    0.183908  ...   0.513963
# Spring_DATAREDIS        0.462408   0.455604    0.291667  ...   0.618467
# Spring_DATAREST         0.318553   0.317156    0.219697  ...   0.472073
# Spring_LDAP             0.419945   0.427036    0.339623  ...   0.406178
# Spring_MOBILE           0.451348   0.439984    0.181818  ...   0.531497
# Spring_ROO              0.269440   0.259540    0.158416  ...   0.423928
# Spring_SEC              0.326767   0.337886    0.227357  ...   0.547538
# Spring_SECOAUTH         0.186998   0.204179    0.125000  ...   0.388184
# Spring_SGF              0.355329   0.326725    0.180952  ...   0.455032
# Spring_SHDP             0.241071   0.242157    0.097561  ...   0.550398
# Spring_SHL              0.425926   0.425926    0.333333  ...   0.568578
# Spring_SOCIAL           0.361667   0.356111    0.200000  ...   0.702792
# Spring_SOCIALFB         0.512954   0.545505    0.333333  ...   0.568452
# Spring_SOCIALLI         0.242063   0.242063    0.000000  ...   0.633121
# Spring_SOCIALTW         0.405991   0.434524    0.250000  ...   0.577083
# Spring_SPR              0.213607   0.223241    0.150794  ...   0.403643
# Spring_SWF              0.331715   0.345411    0.261194  ...   0.451223
# Spring_SWS              0.275989   0.274190    0.209302  ...   0.406825
# Wildfly_ELY             0.222826   0.217391    0.173913  ...   0.184783
# Wildfly_SWARM           0.213848   0.221048    0.125000  ...   0.323471
# Wildfly_WFARQ           0.166667   0.166667    0.000000  ...   0.500000
# Wildfly_WFCORE          0.225835   0.233030    0.150442  ...   0.385561
# Wildfly_WFLY            0.171508   0.178111    0.110989  ...   0.346362
# Wildfly_WFMP            0.444264   0.440476    0.333333  ...   0.705556
#
#                        MRR_locus  HIT1_locus  HIT5_locus  HIT10_locus  \
# project
# Apache_CAMEL            0.559306    0.439394    0.707300     0.783058
# Apache_HBASE            0.553281    0.441725    0.698135     0.769231
# Apache_HIVE             0.454056    0.334701    0.596390     0.701395
# Commons_CODEC           0.781010    0.658537    0.951220     0.951220
# Commons_COLLECTIONS     0.735188    0.677419    0.806452     0.838710
# Commons_COMPRESS        0.787693    0.693694    0.918919     0.990991
# Commons_CONFIGURATION   0.607351    0.444444    0.800000     0.881481
# Commons_CRYPTO          0.458333    0.375000    0.625000     0.625000
# Commons_CSV             0.660204    0.500000    0.857143     1.000000
# Commons_IO              0.713533    0.613636    0.840909     0.852273
# Commons_LANG            0.619024    0.473684    0.789474     0.822967
# Commons_MATH            0.547835    0.428571    0.691964     0.754464
# Commons_WEAVER          0.550000    0.500000    0.500000     1.000000
# JBoss_ENTESB            0.076970    0.025641    0.128205     0.205128
# JBoss_JBMETA            0.365193    0.307692    0.423077     0.423077
# Previous_AspectJ        0.284249    0.171930    0.387719     0.507895
# Previous_JDT            0.302293    0.202128    0.414894     0.500000
# Previous_PDE            0.500353    0.372881    0.644068     0.745763
# Previous_SWT            0.104999    0.064626    0.163265     0.193878
# Previous_ZXing          0.551225    0.450000    0.650000     0.800000
# Spring_AMQP             0.592964    0.445545    0.732673     0.841584
# Spring_ANDROID          0.600570    0.444444    0.777778     0.888889
# Spring_BATCH            0.569451    0.456311    0.703883     0.769417
# Spring_BATCHADM         0.634370    0.526316    0.842105     0.842105
# Spring_DATACMNS         0.547275    0.438710    0.696774     0.761290
# Spring_DATAGRAPH        0.087895    0.063158    0.126316     0.126316
# Spring_DATAJPA          0.575657    0.472973    0.689189     0.783784
# Spring_DATAMONGO        0.552663    0.417625    0.735632     0.846743
# Spring_DATAREDIS        0.690791    0.562500    0.854167     0.895833
# Spring_DATAREST         0.534446    0.409091    0.696970     0.787879
# Spring_LDAP             0.450276    0.358491    0.584906     0.603774
# Spring_MOBILE           0.568687    0.454545    0.818182     0.909091
# Spring_ROO              0.498547    0.363508    0.654880     0.763791
# Spring_SEC              0.592149    0.484288    0.724584     0.785582
# Spring_SECOAUTH         0.467468    0.395833    0.572917     0.593750
# Spring_SGF              0.596366    0.495238    0.723810     0.790476
# Spring_SHDP             0.620637    0.487805    0.804878     0.829268
# Spring_SHL              0.566975    0.444444    0.666667     0.888889
# Spring_SOCIAL           0.702792    0.666667    0.733333     0.733333
# Spring_SOCIALFB         0.600109    0.466667    0.733333     0.866667
# Spring_SOCIALLI         0.833333    0.666667    1.000000     1.000000
# Spring_SOCIALTW         0.587500    0.375000    0.875000     0.875000
# Spring_SPR              0.507979    0.428571    0.595238     0.706349
# Spring_SWF              0.508723    0.402985    0.619403     0.708955
# Spring_SWS              0.489638    0.424419    0.569767     0.627907
# Wildfly_ELY             0.192029    0.130435    0.304348     0.304348
# Wildfly_SWARM           0.388877    0.267857    0.517857     0.589286
# Wildfly_WFARQ           0.500000    0.000000    1.000000     1.000000
# Wildfly_WFCORE          0.468271    0.345133    0.604720     0.699115
# Wildfly_WFLY            0.429815    0.321978    0.551648     0.652747
# Wildfly_WFMP            0.833333    0.666667    1.000000     1.000000
#
#                        MAP_blizzard  MRR_blizzard  HIT1_blizzard  \
# project
# Apache_CAMEL               0.209513      0.207293       0.278926
# Apache_HBASE               0.282126      0.278388       0.396270
# Apache_HIVE                0.219608      0.216124       0.274815
# Commons_CODEC              0.427676      0.425813       0.756098
# Commons_COLLECTIONS        0.346136      0.339956       0.494624
# Commons_COMPRESS           0.369854      0.369249       0.603604
# Commons_CONFIGURATION      0.330659      0.332878       0.503704
# Commons_CRYPTO             0.156250      0.138889       0.250000
# Commons_CSV                0.440476      0.428571       0.642857
# Commons_IO                 0.405193      0.401867       0.647727
# Commons_LANG               0.394735      0.389248       0.645933
# Commons_MATH               0.342118      0.335474       0.549107
# Commons_WEAVER             0.312500      0.291667       0.000000
# JBoss_ENTESB               0.033466      0.035287       0.025641
# JBoss_JBMETA               0.128016      0.121766       0.153846
# Previous_AspectJ           0.036936      0.038030       0.049123
# Previous_JDT               0.000000      0.000000       0.000000
# Previous_PDE               0.152985      0.157977       0.220339
# Previous_SWT               0.290096      0.276234       0.367347
# Previous_ZXing             0.227879      0.228333       0.300000
# Spring_AMQP                0.302594      0.290186       0.386139
# Spring_ANDROID             0.262787      0.240741       0.444444
# Spring_BATCH               0.279517      0.276119       0.385922
# Spring_BATCHADM            0.279532      0.279532       0.368421
# Spring_DATACMNS            0.241711      0.242466       0.322581
# Spring_DATAGRAPH           0.068583      0.067273       0.073684
# Spring_DATAJPA             0.290383      0.291230       0.432432
# Spring_DATAMONGO           0.245129      0.246244       0.283525
# Spring_DATAREDIS           0.337211      0.333425       0.520833
# Spring_DATAREST            0.250484      0.246916       0.303030
# Spring_LDAP                0.280649      0.275696       0.377358
# Spring_MOBILE              0.329149      0.329149       0.454545
# Spring_ROO                 0.211100      0.208391       0.251768
# Spring_SEC                 0.300328      0.300562       0.452865
# Spring_SECOAUTH            0.172328      0.171809       0.208333
# Spring_SGF                 0.302329      0.300756       0.466667
# Spring_SHDP                0.377671      0.377642       0.609756
# Spring_SHL                 0.209392      0.201058       0.111111
# Spring_SOCIAL              0.302222      0.296667       0.466667
# Spring_SOCIALFB            0.292963      0.292963       0.400000
# Spring_SOCIALLI            0.314815      0.314815       0.333333
# Spring_SOCIALTW            0.362500      0.362500       0.625000
# Spring_SPR                 0.244428      0.240285       0.325397
# Spring_SWF                 0.277495      0.275533       0.432836
# Spring_SWS                 0.215859      0.209180       0.296512
# Wildfly_ELY                0.112077      0.110628       0.173913
# Wildfly_SWARM              0.128083      0.128381       0.160714
# Wildfly_WFARQ              0.000000      0.000000       0.000000
# Wildfly_WFCORE             0.182133      0.183596       0.218289
# Wildfly_WFLY               0.152995      0.153110       0.187912
# Wildfly_WFMP               0.416667      0.388889       0.333333
#
#                        HIT5_blizzard  HIT10_blizzard
# project
# Apache_CAMEL                0.502755        0.570248
# Apache_HBASE                0.665501        0.727273
# Apache_HIVE                 0.521739        0.632486
# Commons_CODEC               0.902439        0.926829
# Commons_COLLECTIONS         0.806452        0.827957
# Commons_COMPRESS            0.810811        0.918919
# Commons_CONFIGURATION       0.762963        0.822222
# Commons_CRYPTO              0.250000        0.375000
# Commons_CSV                 1.000000        1.000000
# Commons_IO                  0.875000        0.931818
# Commons_LANG                0.870813        0.880383
# Commons_MATH                0.750000        0.785714
# Commons_WEAVER              1.000000        1.000000
# JBoss_ENTESB                0.102564        0.128205
# JBoss_JBMETA                0.269231        0.423077
# Previous_AspectJ            0.092105        0.110526
# Previous_JDT                0.000000        0.000000
# Previous_PDE                0.372881        0.491525
# Previous_SWT                0.670068        0.775510
# Previous_ZXing              0.600000        0.600000
# Spring_AMQP                 0.702970        0.811881
# Spring_ANDROID              0.555556        0.555556
# Spring_BATCH                0.638350        0.728155
# Spring_BATCHADM             0.736842        0.789474
# Spring_DATACMNS             0.606452        0.670968
# Spring_DATAGRAPH            0.168421        0.221053
# Spring_DATAJPA              0.675676        0.777027
# Spring_DATAMONGO            0.616858        0.750958
# Spring_DATAREDIS            0.729167        0.833333
# Spring_DATAREST             0.643939        0.727273
# Spring_LDAP                 0.641509        0.773585
# Spring_MOBILE               0.727273        0.909091
# Spring_ROO                  0.512023        0.632249
# Spring_SEC                  0.691312        0.763401
# Spring_SECOAUTH             0.385417        0.541667
# Spring_SGF                  0.676190        0.742857
# Spring_SHDP                 0.878049        0.902439
# Spring_SHL                  0.555556        0.666667
# Spring_SOCIAL               0.733333        0.733333
# Spring_SOCIALFB             0.733333        0.800000
# Spring_SOCIALLI             0.666667        1.000000
# Spring_SOCIALTW             0.875000        0.875000
# Spring_SPR                  0.595238        0.682540
# Spring_SWF                  0.626866        0.686567
# Spring_SWS                  0.488372        0.581395
# Wildfly_ELY                 0.217391        0.304348
# Wildfly_SWARM               0.303571        0.410714
# Wildfly_WFARQ               0.000000        0.000000
# Wildfly_WFCORE              0.457227        0.533923
# Wildfly_WFLY                0.367033        0.468132
# Wildfly_WFMP                1.000000        1.000000
#
# [51 rows x 37 columns]
