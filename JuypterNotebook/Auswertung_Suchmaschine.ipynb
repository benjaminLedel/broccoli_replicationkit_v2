# %%
# data from Bench4BL
import pandas as pd

data = pd.DataFrame()
data["Apache_CAMEL"] = "test"

# %%
import xgboost as xgb
import pandas as pd

projectVersionMap = ["Apache_CAMEL","Apache_HBASE","Apache_HIVE","Commons_CODEC","Commons_COLLECTIONS","Commons_COMPRESS","Commons_CONFIGURATION","Commons_CRYPTO","Commons_CSV","Commons_IO","Commons_LANG","Commons_MATH","Commons_WEAVER","JBoss_ENTESB","JBoss_JBMETA","Previous_AspectJ","Previous_PDE","Previous_SWT","Previous_ZXing","Spring_AMQP","Spring_ANDROID","Spring_BATCHADM","Spring_BATCH","Spring_DATACMNS","Spring_DATAGRAPH","Spring_DATAJPA","Spring_DATAMONGO","Spring_DATAREDIS","Spring_DATAREST","Spring_LDAP","Spring_MOBILE","Spring_ROO","Spring_SECOAUTH","Spring_SEC","Spring_SGF","Spring_SHDP","Spring_SHL","Spring_SOCIALFB","Spring_SOCIALLI","Spring_SOCIALTW","Spring_SOCIAL","Spring_SPR","Spring_SWF","Spring_SWS","Wildfly_ELY","Wildfly_SWARM","Wildfly_WFARQ","Wildfly_WFCORE","Wildfly_WFLY","Wildfly_WFMP"]
print(len(projectVersionMap))

projectVersionMap = ["Apache_CAMEL","Apache_HBASE","Commons_CODEC", "Commons_COLLECTIONS", "Commons_COMPRESS", "Commons_CONFIGURATION","Commons_CRYPTO","Commons_CSV","Commons_IO" ,"Commons_LANG","Commons_MATH","Commons_WEAVER","JBoss_ENTESB","JBoss_JBMETA","Previous_AspectJ","Previous_PDE","Previous_SWT","Previous_ZXing","Spring_AMQP","Spring_ANDROID","Spring_BATCHADM","Spring_BATCH","Spring_DATACMNS","Spring_DATAGRAPH","Spring_DATAJPA","Spring_DATAMONGO","Spring_DATAREDIS","Spring_DATAREST","Spring_LDAP","Wildfly_WFMP"]
print(len(projectVersionMap))
# Out:
# 50
# 30

# %%
for key in projectVersionMap:
    print("Project " + key)
    #gbm = xgb.Booster(model_file='model/' + key + '.json')
    
    test = pd.read_csv('data/' + key + '.csv')    
    #columns = test.drop(['Unnamed: 0','project','bug','Result','description_matching'], axis=1).columns
    result = pd.DataFrame(test)
    result['Result2'] = test['elastic_full'] #gbm.predict(xgb.DMatrix(test[columns]))
    result.to_csv('results/' + key + '.csv', index=False, sep=',')
# Out:
# Project Apache_CAMEL
# Project Apache_HBASE
# Project Commons_CODEC
# Project Commons_COLLECTIONS
# Project Commons_COMPRESS
# Project Commons_CONFIGURATION
# Project Commons_CRYPTO
# Project Commons_CSV
# Project Commons_IO
# Project Commons_LANG
# Project Commons_MATH
# Project Commons_WEAVER
# Project JBoss_ENTESB
# Project JBoss_JBMETA
# Project Previous_AspectJ
# Project Previous_PDE
# Project Previous_SWT
# Project Previous_ZXing
# Project Spring_AMQP
# Project Spring_ANDROID
# Project Spring_BATCHADM
# Project Spring_BATCH
# Project Spring_DATACMNS
# Project Spring_DATAGRAPH
# Project Spring_DATAJPA
# Project Spring_DATAMONGO
# Project Spring_DATAREDIS
# Project Spring_DATAREST
# Project Spring_LDAP
# Project Wildfly_WFMP

# %%
def evaluate_for_key(key, bugs_length=None):
    resultData = pd.read_csv('results/' + key + '.csv')     
    bugs = resultData.bug.unique()
    print("Project " + key)
    if bugs_length == None:
        bugs_length = len(bugs)
    print(bugs_length)
    count1 = 0;
    count5 = 0;
    count10 = 0;
    mapValue = 0;
    mrr = 0;
    for bug in bugs:
        subData = resultData[resultData['bug'] == bug]
        subDataSorted = subData.sort_values('Result2',ascending=False)
        
        if subDataSorted.iloc[0,-2] == 1:
            count1 += 1;
        if 1 in subDataSorted.values[0:5,-2]:
            count5 += 1;
        if 1 in subDataSorted.values[0:10,-2]:
            count10 += 1;
        
        summe = 0;
        rr = 0;
        retrieved_d = 0;
        i = 0
        c = 0
        for resultV in subDataSorted.values[:,-2]:
            if resultV == 1 and c < 10:
                c += 1
                retrieved_d += 1;
                summe += (retrieved_d /(i+1))
            if resultV == 1 and rr == 0:    
                rr += (1/ (i+1))
            i += 1
        if c != 0:
            mapValue += (summe/c)
        else: 
            print("c zero!" + str(bug))
            mapValue +=0
            #rr = 1
        mrr += rr
    return count1/bugs_length,count5/bugs_length,count10/bugs_length,mapValue/bugs_length,mrr/bugs_length

# %%
import statistics

maps = []
mrrs = []
top1s = []
top5s = []
top10s = []

for key in projectVersionMap:
    count1, count5, count10, mapValue, mrr = evaluate_for_key(key)
    print("Count 1: " + str(count1) + " Count 5: " + str(count5) + " Count 10:" + str(count10))
    print("MAP " + str(mapValue))
    print("MRR " + str(mrr))
    
    top1s.append(count1)
    top5s.append(count5)
    top10s.append(count10)
    maps.append(mapValue)
    mrrs.append(mrr)
# Out:
# Project Apache_CAMEL
# 1452
# c zero!509
# c zero!1803
# c zero!2209
# c zero!1442
# c zero!1630
# c zero!1671
# c zero!1755
# c zero!1839
# c zero!1870
# c zero!1917
# c zero!1927
# c zero!1957
# c zero!2251
# c zero!2318
# c zero!2447
# c zero!3082
# c zero!8315
# c zero!7320
# c zero!7772
# c zero!8214
# c zero!9202
# c zero!8189
# c zero!9205
# c zero!8690
# c zero!9101
# c zero!9281
# c zero!2485
# c zero!2639
# c zero!2671
# c zero!2740
# c zero!3193
# c zero!3752
# c zero!3104
# Count 1: 0.3037190082644628 Count 5: 0.540633608815427 Count 10:0.6143250688705234
# MAP 0.3311348682391097
# MRR 0.4123831252475707
# Project Apache_HBASE
# 858
# c zero!437
# c zero!444
# c zero!428
# c zero!281
# c zero!516
# c zero!524
# c zero!514
# c zero!497
# c zero!550
# c zero!552
# c zero!564
# c zero!577
# c zero!680
# c zero!686
# c zero!694
# c zero!707
# c zero!716
# c zero!744
# c zero!756
# c zero!764
# c zero!812
# c zero!858
# c zero!500
# c zero!1039
# c zero!1238
# c zero!1107
# c zero!1352
# c zero!1600
# c zero!14431
# c zero!14343
# c zero!16061
# c zero!13722
# c zero!14011
# c zero!14660
# c zero!15063
# c zero!15231
# c zero!15578
# c zero!15668
# c zero!15634
# c zero!15828
# c zero!15848
# c zero!15928
# c zero!15899
# c zero!15986
# c zero!15862
# c zero!16064
# c zero!16065
# c zero!16125
# c zero!15682
# c zero!16110
# c zero!16430
# c zero!16456
# c zero!16197
# c zero!16614
# c zero!16624
# c zero!16654
# c zero!16645
# c zero!16767
# c zero!16866
# c zero!15684
# c zero!16938
# Count 1: 0.3484848484848485 Count 5: 0.6235431235431236 Count 10:0.7191142191142191
# MAP 0.3851688709012769
# MRR 0.47247231091971986
# Project Commons_CODEC
# 41
# Count 1: 0.43902439024390244 Count 5: 0.6585365853658537 Count 10:0.8048780487804879
# MAP 0.5127883858143301
# MRR 0.5522502769650379
# Project Commons_COLLECTIONS
# 93
# c zero!454
# c zero!453
# c zero!472
# c zero!493
# c zero!488
# c zero!524
# c zero!536
# c zero!470
# c zero!314
# c zero!363
# c zero!313
# c zero!237
# Count 1: 0.40860215053763443 Count 5: 0.6236559139784946 Count 10:0.7096774193548387
# MAP 0.4869948023749751
# MRR 0.523802908499355
# Project Commons_COMPRESS
# 111
# Count 1: 0.2702702702702703 Count 5: 0.4144144144144144 Count 10:0.4864864864864865
# MAP 0.30450232948651895
# MRR 0.3374284763585787
# Project Commons_CONFIGURATION
# 135
# c zero!427
# c zero!604
# c zero!564
# c zero!632
# c zero!598
# Count 1: 0.4222222222222222 Count 5: 0.7407407407407407 Count 10:0.7851851851851852
# MAP 0.5330155449979739
# MRR 0.5582227304471854
# Project Commons_CRYPTO
# 8
# c zero!34
# c zero!32
# c zero!29
# Count 1: 0.25 Count 5: 0.25 Count 10:0.5
# MAP 0.2669074817448416
# MRR 0.2859375
# Project Commons_CSV
# 14
# Count 1: 0.5714285714285714 Count 5: 0.8571428571428571 Count 10:1.0
# MAP 0.676984126984127
# MRR 0.6984126984126985
# Project Commons_IO
# 88
# c zero!220
# c zero!132
# c zero!79
# c zero!339
# Count 1: 0.625 Count 5: 0.8522727272727273 Count 10:0.9318181818181818
# MAP 0.6924468314973775
# MRR 0.7162248105429926
# Project Commons_LANG
# 209
# c zero!428
# c zero!581
# c zero!617
# c zero!606
# c zero!631
# c zero!656
# c zero!646
# c zero!672
# c zero!719
# c zero!593
# c zero!805
# c zero!754
# c zero!917
# c zero!807
# c zero!693
# c zero!1087
# c zero!1152
# c zero!1209
# c zero!1215
# c zero!1230
# c zero!826
# c zero!828
# Count 1: 0.44976076555023925 Count 5: 0.7703349282296651 Count 10:0.8277511961722488
# MAP 0.5786375922833156
# MRR 0.5885611229989218
# Project Commons_MATH
# 224
# c zero!214
# c zero!723
# c zero!718
# c zero!644
# c zero!578
# c zero!415
# c zero!466
# c zero!519
# c zero!546
# c zero!572
# c zero!573
# c zero!619
# c zero!645
# c zero!669
# c zero!728
# c zero!881
# c zero!899
# c zero!914
# c zero!1384
# c zero!1206
# c zero!1205
# c zero!1192
# c zero!760
# c zero!1229
# c zero!1230
# c zero!1231
# c zero!1356
# c zero!1376
# c zero!1396
# Count 1: 0.46875 Count 5: 0.6919642857142857 Count 10:0.7589285714285714
# MAP 0.530639709549017
# MRR 0.5779479570855912
# Project Commons_WEAVER
# 2
# Count 1: 0.5 Count 5: 0.5 Count 10:0.5
# MAP 0.38524436090225567
# MRR 0.5357142857142857
# Project JBoss_ENTESB
# 39
# c zero!591
# c zero!665
# c zero!693
# c zero!737
# c zero!937
# c zero!932
# c zero!936
# c zero!1150
# c zero!1236
# c zero!1225
# c zero!1249
# c zero!1181
# c zero!1260
# c zero!1154
# c zero!2305
# c zero!2592
# c zero!2620
# c zero!2910
# c zero!3522
# c zero!3642
# c zero!102
# c zero!257
# c zero!419
# c zero!497
# c zero!498
# c zero!522
# c zero!523
# c zero!648
# c zero!605
# Count 1: 0.02564102564102564 Count 5: 0.05128205128205128 Count 10:0.10256410256410256
# MAP 0.04635874422462237
# MRR 0.047488759606406666
# Project JBoss_JBMETA
# 26
# c zero!207
# c zero!232
# c zero!286
# c zero!289
# c zero!305
# c zero!326
# c zero!327
# Count 1: 0.15384615384615385 Count 5: 0.38461538461538464 Count 10:0.46153846153846156
# MAP 0.24235389507693464
# MRR 0.2720558271040117
# Project Previous_AspectJ
# 285
# Count 1: 0.04912280701754386 Count 5: 0.21052631578947367 Count 10:0.29473684210526313
# MAP 0.05951334421804262
# MRR 0.1280073923839176
# Project Previous_PDE
# 59
# Count 1: 0.23728813559322035 Count 5: 0.3220338983050847 Count 10:0.4406779661016949
# MAP 0.20488104791870865
# MRR 0.29486942423547685
# Project Previous_SWT
# 98
# Count 1: 0.29591836734693877 Count 5: 0.4897959183673469 Count 10:0.6122448979591837
# MAP 0.3285719110746766
# MRR 0.38435751903127596
# Project Previous_ZXing
# 20
# Count 1: 0.3 Count 5: 0.5 Count 10:0.6
# MAP 0.3739412199330526
# MRR 0.4040735289598449
# Project Spring_AMQP
# 101
# Count 1: 0.39603960396039606 Count 5: 0.7326732673267327 Count 10:0.8118811881188119
# MAP 0.4699868981961205
# MRR 0.5365156747997549
# Project Spring_ANDROID
# 9
# Count 1: 0.3333333333333333 Count 5: 0.6666666666666666 Count 10:0.6666666666666666
# MAP 0.3579784348362076
# MRR 0.43282297624402893
# Project Spring_BATCHADM
# 19
# Count 1: 0.3684210526315789 Count 5: 0.6842105263157895 Count 10:0.7894736842105263
# MAP 0.4266660378864995
# MRR 0.507681714943796
# Project Spring_BATCH
# 412
# c zero!244
# c zero!250
# c zero!170
# c zero!285
# c zero!293
# c zero!281
# c zero!305
# c zero!312
# c zero!322
# c zero!367
# c zero!373
# c zero!376
# c zero!349
# c zero!334
# c zero!380
# c zero!402
# c zero!408
# c zero!393
# c zero!406
# c zero!413
# c zero!427
# c zero!423
# c zero!439
# c zero!329
# c zero!443
# c zero!449
# c zero!663
# c zero!1059
# c zero!853
# c zero!887
# c zero!931
# c zero!1002
# c zero!1005
# c zero!1004
# c zero!1567
# Count 1: 0.3640776699029126 Count 5: 0.6529126213592233 Count 10:0.7402912621359223
# MAP 0.41761763890166514
# MRR 0.4841010068353565
# Project Spring_DATACMNS
# 155
# c zero!52
# c zero!65
# c zero!69
# c zero!70
# c zero!99
# c zero!153
# c zero!158
# c zero!760
# c zero!779
# c zero!828
# c zero!916
# c zero!170
# c zero!239
# c zero!343
# c zero!352
# c zero!353
# c zero!663
# c zero!722
# Count 1: 0.33548387096774196 Count 5: 0.5870967741935483 Count 10:0.6838709677419355
# MAP 0.41956693437543247
# MRR 0.45588960104122844
# Project Spring_DATAGRAPH
# 95
# c zero!98
# c zero!123
# c zero!276
# c zero!293
# c zero!330
# c zero!444
# c zero!545
# c zero!552
# c zero!567
# c zero!565
# c zero!588
# c zero!590
# c zero!591
# c zero!589
# c zero!586
# c zero!595
# c zero!594
# c zero!600
# c zero!604
# c zero!596
# c zero!606
# c zero!582
# c zero!611
# c zero!610
# c zero!614
# c zero!616
# c zero!628
# c zero!631
# c zero!630
# c zero!634
# c zero!637
# c zero!639
# c zero!638
# c zero!627
# c zero!739
# c zero!700
# c zero!830
# c zero!602
# c zero!659
# c zero!876
# c zero!922
# Count 1: 0.06315789473684211 Count 5: 0.12631578947368421 Count 10:0.18947368421052632
# MAP 0.08389496136222285
# MRR 0.1014089091306808
# Project Spring_DATAJPA
# 148
# c zero!268
# c zero!243
# c zero!494
# Count 1: 0.41216216216216217 Count 5: 0.6554054054054054 Count 10:0.777027027027027
# MAP 0.4928371679314966
# MRR 0.5247725251066999
# Project Spring_DATAMONGO
# 261
# c zero!408
# c zero!407
# c zero!517
# c zero!570
# c zero!534
# c zero!741
# c zero!926
# c zero!949
# c zero!962
# Count 1: 0.2950191570881226 Count 5: 0.6206896551724138 Count 10:0.7624521072796935
# MAP 0.40718283298568325
# MRR 0.44429236589624604
# Project Spring_DATAREDIS
# 48
# c zero!392
# Count 1: 0.4375 Count 5: 0.75 Count 10:0.8333333333333334
# MAP 0.5271096267826675
# MRR 0.5644065612356053
# Project Spring_DATAREST
# 132
# c zero!163
# c zero!200
# c zero!107
# c zero!222
# c zero!216
# c zero!250
# c zero!507
# c zero!522
# c zero!582
# c zero!565
# c zero!720
# Count 1: 0.3333333333333333 Count 5: 0.6439393939393939 Count 10:0.7424242424242424
# MAP 0.42003507614283925
# MRR 0.4701003641410341
# Project Spring_LDAP
# 53
# c zero!15
# c zero!271
# Count 1: 0.37735849056603776 Count 5: 0.7547169811320755 Count 10:0.8490566037735849
# MAP 0.4918165092949396
# MRR 0.5381494107076793
# Project Wildfly_WFMP
# 3
# Count 1: 0.0 Count 5: 1.0 Count 10:1.0
# MAP 0.40277777777777773
# MRR 0.4166666666666667

# %%
print("Average MAP: " + str(statistics.mean(maps)))
print("Average MRR: " + str(statistics.mean(mrrs)))
print("Average 1: " + str(statistics.mean(top1s)))
print("Average 5: " + str(statistics.mean(top5s)))
print("Average 10: " + str(statistics.mean(top10s)))
# Out:
# Average MAP: 0.39525183212315695
# Average MRR: 0.4422339477087216
# Average 1: 0.32783217617098315
# Average 5: 0.5785373278187288
# Average 10: 0.666529247146724

# %%
mrrs
# Out:
# [0.489204304544912,
#  0.5284718239018517,
#  0.7637721357233551,
#  0.6479190134835298,
#  0.7333699245463955,
#  0.6749959536348425,
#  0.328125,
#  0.7809523809523808,
#  0.8089556277056278,
#  0.7366032730774034,
#  0.6470665984703324,
#  0.6,
#  0.07188012043211692,
#  0.2558959669237463,
#  0.2833333333333333]

# %%
import pandas as pd

data = pd.read_csv('model_data_SMARTSHARK_compress.csv')
projects = data.project.unique()
projectVersionMap = {}
for project in projects:
    projectParts = project.split("_")
    groupName = projectParts[0] + "_" + projectParts[1]
    if groupName not in projectVersionMap:
        projectVersionMap[groupName] = []
    projectVersionMap[groupName].append(project)

projectVersionMap
# Out:
# {'smartshark_ant-ivy': ['smartshark_ant-ivy_1.4.1',
#   'smartshark_ant-ivy_2.0.0',
#   'smartshark_ant-ivy_2.1.0',
#   'smartshark_ant-ivy_2.2.0',
#   'smartshark_ant-ivy_2.3.0',
#   'smartshark_ant-ivy_2.4.0'],
#  'smartshark_archiva': ['smartshark_archiva_1.0',
#   'smartshark_archiva_1.1',
#   'smartshark_archiva_1.2',
#   'smartshark_archiva_1.3',
#   'smartshark_archiva_2.0.0',
#   'smartshark_archiva_2.1.0',
#   'smartshark_archiva_2.2.0'],
#  'smartshark_calcite': ['smartshark_calcite_1.0.0',
#   'smartshark_calcite_1.1.0',
#   'smartshark_calcite_1.10.0',
#   'smartshark_calcite_1.11.0',
#   'smartshark_calcite_1.12.0',
#   'smartshark_calcite_1.13.0',
#   'smartshark_calcite_1.14.0',
#   'smartshark_calcite_1.15.0',
#   'smartshark_calcite_1.2.0',
#   'smartshark_calcite_1.3.0',
#   'smartshark_calcite_1.4.0',
#   'smartshark_calcite_1.5.0',
#   'smartshark_calcite_1.6.0',
#   'smartshark_calcite_1.7.0',
#   'smartshark_calcite_1.8.0',
#   'smartshark_calcite_1.9.0'],
#  'smartshark_cayenne': ['smartshark_cayenne_3.0.0',
#   'smartshark_cayenne_3.1.0'],
#  'smartshark_commons-bcel': ['smartshark_commons-bcel_6.0',
#   'smartshark_commons-bcel_6.1',
#   'smartshark_commons-bcel_6.2'],
#  'smartshark_commons-beanutils': ['smartshark_commons-beanutils_1.8.0',
#   'smartshark_commons-beanutils_1.9.0'],
#  'smartshark_commons-codec': ['smartshark_commons-codec_1.11',
#   'smartshark_commons-codec_1.4',
#   'smartshark_commons-codec_1.6',
#   'smartshark_commons-codec_1.8',
#   'smartshark_commons-codec_1.9'],
#  'smartshark_commons-collections': ['smartshark_commons-collections_4.0',
#   'smartshark_commons-collections_4.1'],
#  'smartshark_commons-compress': ['smartshark_commons-compress_1.0',
#   'smartshark_commons-compress_1.10',
#   'smartshark_commons-compress_1.11',
#   'smartshark_commons-compress_1.12',
#   'smartshark_commons-compress_1.13',
#   'smartshark_commons-compress_1.14',
#   'smartshark_commons-compress_1.15',
#   'smartshark_commons-compress_1.16',
#   'smartshark_commons-compress_1.1',
#   'smartshark_commons-compress_1.2',
#   'smartshark_commons-compress_1.3',
#   'smartshark_commons-compress_1.4',
#   'smartshark_commons-compress_1.5',
#   'smartshark_commons-compress_1.6',
#   'smartshark_commons-compress_1.7',
#   'smartshark_commons-compress_1.8',
#   'smartshark_commons-compress_1.9'],
#  'smartshark_commons-configuration': ['smartshark_commons-configuration_1.10',
#   'smartshark_commons-configuration_1.7',
#   'smartshark_commons-configuration_1.8',
#   'smartshark_commons-configuration_1.9',
#   'smartshark_commons-configuration_2.0',
#   'smartshark_commons-configuration_2.1',
#   'smartshark_commons-configuration_2.2'],
#  'smartshark_commons-dbcp': ['smartshark_commons-dbcp_1.3',
#   'smartshark_commons-dbcp_2.0',
#   'smartshark_commons-dbcp_2.1',
#   'smartshark_commons-dbcp_2.2.0',
#   'smartshark_commons-dbcp_2.3.0',
#   'smartshark_commons-dbcp_2.4.0'],
#  'smartshark_commons-digester': ['smartshark_commons-digester_2.0',
#   'smartshark_commons-digester_2.1',
#   'smartshark_commons-digester_3.1'],
#  'smartshark_commons-io': ['smartshark_commons-io_1.3',
#   'smartshark_commons-io_1.4',
#   'smartshark_commons-io_2.0',
#   'smartshark_commons-io_2.1',
#   'smartshark_commons-io_2.2',
#   'smartshark_commons-io_2.5'],
#  'smartshark_commons-jcs': ['smartshark_commons-jcs_1.3',
#   'smartshark_commons-jcs_2.0',
#   'smartshark_commons-jcs_2.2'],
#  'smartshark_commons-jexl': ['smartshark_commons-jexl_2.1',
#   'smartshark_commons-jexl_3.0',
#   'smartshark_commons-jexl_3.1'],
#  'smartshark_commons-lang': ['smartshark_commons-lang_2.2',
#   'smartshark_commons-lang_2.3',
#   'smartshark_commons-lang_2.4',
#   'smartshark_commons-lang_2.5',
#   'smartshark_commons-lang_2.6',
#   'smartshark_commons-lang_3.0',
#   'smartshark_commons-lang_3.1',
#   'smartshark_commons-lang_3.2',
#   'smartshark_commons-lang_3.3',
#   'smartshark_commons-lang_3.4',
#   'smartshark_commons-lang_3.5',
#   'smartshark_commons-lang_3.6',
#   'smartshark_commons-lang_3.7'],
#  'smartshark_commons-math': ['smartshark_commons-math_1.2',
#   'smartshark_commons-math_2.0',
#   'smartshark_commons-math_2.2',
#   'smartshark_commons-math_3.0',
#   'smartshark_commons-math_3.1',
#   'smartshark_commons-math_3.2',
#   'smartshark_commons-math_3.3',
#   'smartshark_commons-math_3.4',
#   'smartshark_commons-math_3.5',
#   'smartshark_commons-math_3.6'],
#  'smartshark_commons-net': ['smartshark_commons-net_2.0',
#   'smartshark_commons-net_2.1',
#   'smartshark_commons-net_2.2',
#   'smartshark_commons-net_3.1',
#   'smartshark_commons-net_3.2',
#   'smartshark_commons-net_3.3',
#   'smartshark_commons-net_3.4',
#   'smartshark_commons-net_3.5',
#   'smartshark_commons-net_3.6'],
#  'smartshark_commons-scxml': ['smartshark_commons-scxml_0.8',
#   'smartshark_commons-scxml_0.9'],
#  'smartshark_commons-validator': ['smartshark_commons-validator_1.4.0',
#   'smartshark_commons-validator_1.5.0',
#   'smartshark_commons-validator_1.6.0'],
#  'smartshark_commons-vfs': ['smartshark_commons-vfs_1.0',
#   'smartshark_commons-vfs_2.0',
#   'smartshark_commons-vfs_2.1',
#   'smartshark_commons-vfs_2.2'],
#  'smartshark_deltaspike': ['smartshark_deltaspike_0.3',
#   'smartshark_deltaspike_0.4',
#   'smartshark_deltaspike_0.5',
#   'smartshark_deltaspike_0.6',
#   'smartshark_deltaspike_0.7',
#   'smartshark_deltaspike_1.0.0',
#   'smartshark_deltaspike_1.1.0',
#   'smartshark_deltaspike_1.2.0',
#   'smartshark_deltaspike_1.3.0',
#   'smartshark_deltaspike_1.4.0',
#   'smartshark_deltaspike_1.5.0',
#   'smartshark_deltaspike_1.6.0',
#   'smartshark_deltaspike_1.7.0',
#   'smartshark_deltaspike_1.8.0'],
#  'smartshark_eagle': ['smartshark_eagle_0.3.0',
#   'smartshark_eagle_0.4.0',
#   'smartshark_eagle_0.5.0'],
#  'smartshark_giraph': ['smartshark_giraph_0.1.0',
#   'smartshark_giraph_1.0.0',
#   'smartshark_giraph_1.1.0'],
#  'smartshark_gora': ['smartshark_gora_0.3',
#   'smartshark_gora_0.4',
#   'smartshark_gora_0.5',
#   'smartshark_gora_0.6',
#   'smartshark_gora_0.7',
#   'smartshark_gora_0.8'],
#  'smartshark_jspwiki': ['smartshark_jspwiki_2.10.0',
#   'smartshark_jspwiki_2.6.0',
#   'smartshark_jspwiki_2.8.0',
#   'smartshark_jspwiki_2.9.0'],
#  'smartshark_knox': ['smartshark_knox_0.10.0',
#   'smartshark_knox_0.11.0',
#   'smartshark_knox_0.12.0',
#   'smartshark_knox_0.13.0',
#   'smartshark_knox_0.14.0',
#   'smartshark_knox_0.3.0',
#   'smartshark_knox_0.4.0',
#   'smartshark_knox_0.5.0',
#   'smartshark_knox_0.6.0',
#   'smartshark_knox_0.7.0',
#   'smartshark_knox_0.8.0',
#   'smartshark_knox_0.9.0',
#   'smartshark_knox_1.0.0'],
#  'smartshark_kylin': ['smartshark_kylin_0.7.1',
#   'smartshark_kylin_1.0',
#   'smartshark_kylin_1.1',
#   'smartshark_kylin_1.2',
#   'smartshark_kylin_1.3',
#   'smartshark_kylin_1.6.0',
#   'smartshark_kylin_2.0.0',
#   'smartshark_kylin_2.1.0',
#   'smartshark_kylin_2.2.0'],
#  'smartshark_lens': ['smartshark_lens_2.6.0', 'smartshark_lens_2.7.0'],
#  'smartshark_mahout': ['smartshark_mahout_0.10.0',
#   'smartshark_mahout_0.11.0',
#   'smartshark_mahout_0.12.0',
#   'smartshark_mahout_0.13.0',
#   'smartshark_mahout_0.1',
#   'smartshark_mahout_0.2',
#   'smartshark_mahout_0.3',
#   'smartshark_mahout_0.5',
#   'smartshark_mahout_0.6',
#   'smartshark_mahout_0.7',
#   'smartshark_mahout_0.8',
#   'smartshark_mahout_0.9'],
#  'smartshark_manifoldcf': ['smartshark_manifoldcf_0.1',
#   'smartshark_manifoldcf_0.2',
#   'smartshark_manifoldcf_0.4',
#   'smartshark_manifoldcf_0.5',
#   'smartshark_manifoldcf_0.6',
#   'smartshark_manifoldcf_1.0',
#   'smartshark_manifoldcf_1.10',
#   'smartshark_manifoldcf_1.1',
#   'smartshark_manifoldcf_1.2',
#   'smartshark_manifoldcf_1.3',
#   'smartshark_manifoldcf_1.4',
#   'smartshark_manifoldcf_1.5',
#   'smartshark_manifoldcf_1.6',
#   'smartshark_manifoldcf_1.7',
#   'smartshark_manifoldcf_1.8',
#   'smartshark_manifoldcf_1.9',
#   'smartshark_manifoldcf_2.10',
#   'smartshark_manifoldcf_2.1',
#   'smartshark_manifoldcf_2.2',
#   'smartshark_manifoldcf_2.3',
#   'smartshark_manifoldcf_2.4',
#   'smartshark_manifoldcf_2.5',
#   'smartshark_manifoldcf_2.6',
#   'smartshark_manifoldcf_2.7',
#   'smartshark_manifoldcf_2.8',
#   'smartshark_manifoldcf_2.9'],
#  'smartshark_nutch': ['smartshark_nutch_0.7',
#   'smartshark_nutch_0.8',
#   'smartshark_nutch_0.9',
#   'smartshark_nutch_1.0',
#   'smartshark_nutch_1.10',
#   'smartshark_nutch_1.11',
#   'smartshark_nutch_1.12',
#   'smartshark_nutch_1.13',
#   'smartshark_nutch_1.14',
#   'smartshark_nutch_1.1',
#   'smartshark_nutch_1.2',
#   'smartshark_nutch_1.3',
#   'smartshark_nutch_1.4',
#   'smartshark_nutch_1.5',
#   'smartshark_nutch_1.6',
#   'smartshark_nutch_1.7',
#   'smartshark_nutch_1.8',
#   'smartshark_nutch_1.9',
#   'smartshark_nutch_2.1',
#   'smartshark_nutch_2.2',
#   'smartshark_nutch_2.3'],
#  'smartshark_opennlp': ['smartshark_opennlp_1.7.0',
#   'smartshark_opennlp_1.8.0'],
#  'smartshark_parquet-mr': ['smartshark_parquet-mr_1.6.0',
#   'smartshark_parquet-mr_1.7.0',
#   'smartshark_parquet-mr_1.8.0',
#   'smartshark_parquet-mr_1.9.0'],
#  'smartshark_santuario-java': ['smartshark_santuario-java_1.4.5',
#   'smartshark_santuario-java_1.5.9',
#   'smartshark_santuario-java_2.0.0',
#   'smartshark_santuario-java_2.1.0'],
#  'smartshark_systemml': ['smartshark_systemml_0.10',
#   'smartshark_systemml_0.11',
#   'smartshark_systemml_0.12',
#   'smartshark_systemml_0.13',
#   'smartshark_systemml_0.14',
#   'smartshark_systemml_0.15',
#   'smartshark_systemml_0.9',
#   'smartshark_systemml_1.0.0',
#   'smartshark_systemml_1.1.0',
#   'smartshark_systemml_1.2.0'],
#  'smartshark_tika': ['smartshark_tika_0.10',
#   'smartshark_tika_0.1',
#   'smartshark_tika_0.4',
#   'smartshark_tika_0.5',
#   'smartshark_tika_0.6',
#   'smartshark_tika_0.7',
#   'smartshark_tika_0.8',
#   'smartshark_tika_0.9',
#   'smartshark_tika_1.0',
#   'smartshark_tika_1.10',
#   'smartshark_tika_1.11',
#   'smartshark_tika_1.12',
#   'smartshark_tika_1.13',
#   'smartshark_tika_1.14',
#   'smartshark_tika_1.15',
#   'smartshark_tika_1.16',
#   'smartshark_tika_1.17',
#   'smartshark_tika_1.1',
#   'smartshark_tika_1.2',
#   'smartshark_tika_1.3',
#   'smartshark_tika_1.5',
#   'smartshark_tika_1.6',
#   'smartshark_tika_1.7',
#   'smartshark_tika_1.8',
#   'smartshark_tika_1.9'],
#  'smartshark_wss4j': ['smartshark_wss4j_1.5.0',
#   'smartshark_wss4j_1.6.0',
#   'smartshark_wss4j_2.0.0',
#   'smartshark_wss4j_2.1.0',
#   'smartshark_wss4j_2.2.0']}

# %%
import os
import pandas as pd

data_mp = pd.read_csv('smartshark_other/statistic_smartshark.csv')

data = pd.DataFrame()
for file in os.listdir("smartshark_other/amalgam"):
    project, version = file.replace('smartshark_','').replace('_output.txt','').split("_")
    element = data_mp.loc[(data_mp['Project'] == "smartshark_" + project) & (data_mp['Version'] == version), 'Bugs'].values[0]
    data = data.append({"project" : project, "version" : version, "bugs": element}, ignore_index=True)

agg_funcs = {'bugs' : 'sum', 
         'version' : 'count'
}

data = data.groupby("project").agg(agg_funcs)

# %%
import xgboost as xgb
import pandas as pd

maps = []
mrrs = []
top1s = []
top5s = []
top10s = []

    
gbm = xgb.Booster(model_file='model/smartshark4.json')
for key in projectVersionMap:
    print(key)
    test = pd.read_csv('data_notTimeAware/' + key +'.csv')    
    columns = test.drop(['project','bug','Result'], axis=1).columns
    result = pd.DataFrame(test)
    result['Result2'] = gbm.predict(xgb.DMatrix(test[columns]))
    result.to_csv('results_notTimeAware/' + key +'.csv', index=False, sep=',')
    
    pro = key.replace('smartshark_','')
    
    count1, count5, count10, mapValue, mrr = evaluate_for_key(key)
    print("Count 1: " + str(count1) + " Count 5: " + str(count5) + " Count 10:" + str(count10))
    print("MAP " + str(mapValue))
    print("MRR " + str(mrr))
        
    top1s.append(count1)
    top5s.append(count5)
    top10s.append(count10)
    maps.append(mapValue)
    mrrs.append(mrr)
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-7-03d862f21012> in <module>()
#       9
#      10
# ---> 11 gbm = xgb.Booster(model_file='model/smartshark4.model')
#      12 for key in projectVersionMap:
#      13     print(key)
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py in __init__(self, params, cache, model_file)
#    1038             self.__dict__.update(state)
#    1039         elif isinstance(model_file, (STRING_TYPES, os.PathLike, bytearray)):
# -> 1040             self.load_model(model_file)
#    1041         elif model_file is None:
#    1042             pass
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py in load_model(self, fname)
#    1727             # from URL.
#    1728             _check_call(_LIB.XGBoosterLoadModel(
# -> 1729                 self.handle, c_str(os.fspath(fname))))
#    1730         elif isinstance(fname, bytearray):
#    1731             buf = fname
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py in _check_call(ret)
#     187     """
#     188     if ret != 0:
# --> 189         raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#     190
#     191
#
# XGBoostError: [12:15:44] /tmp/pip-build-6ifawm9w/xgboost/build/temp.linux-x86_64-3.6/xgboost/dmlc-core/src/io/local_filesys.cc:209: Check failed: allow_null:  LocalFileSystem::Open "model/smartshark4.model": No such file or directory
# Stack trace:
#   [bt] (0) /usr/local/lib/python3.6/dist-packages/xgboost/lib/libxgboost.so(+0x33680f) [0x7f0eb2a5680f]
#   [bt] (1) /usr/local/lib/python3.6/dist-packages/xgboost/lib/libxgboost.so(+0x3099ea) [0x7f0eb2a299ea]
#   [bt] (2) /usr/local/lib/python3.6/dist-packages/xgboost/lib/libxgboost.so(XGBoosterLoadModel+0x693) [0x7f0eb2760f03]
#   [bt] (3) /usr/lib/x86_64-linux-gnu/libffi.so.6(ffi_call_unix64+0x4c) [0x7f10f0d95dae]
#   [bt] (4) /usr/lib/x86_64-linux-gnu/libffi.so.6(ffi_call+0x22f) [0x7f10f0d9571f]
#   [bt] (5) /usr/lib/python3.6/lib-dynload/_ctypes.cpython-36m-x86_64-linux-gnu.so(_ctypes_callproc+0x2b4) [0x7f10f0fb15a4]
#   [bt] (6) /usr/lib/python3.6/lib-dynload/_ctypes.cpython-36m-x86_64-linux-gnu.so(+0x11c13) [0x7f10f0fb1c13]
#   [bt] (7) /usr/bin/python3(_PyObject_FastCallKeywords+0x19c) [0x5a9d2c]
#   [bt] (8) /usr/bin/python3() [0x50a533]

# %%
import statistics 

print("Average MAP: " + str(statistics.median(maps)))
print("Average MRR: " + str(statistics.median(mrrs)))
print("Average 1: " + str(statistics.mean(top1s)))
print("Average 5: " + str(statistics.mean(top5s)))
print("Average 10: " + str(statistics.mean(top10s)))
# Out:
# Average MAP: 0.3978342314283729
# Average MRR: 0.5876896058356369
# Average 1: 0.5183934189804887
# Average 5: 0.7347663035363672
# Average 10: 0.776436133742397

# %%
sum(maps)/sum(data['bugs'])
Average MAP: 0.5821443800289604
Average MRR: 0.7551110616559689
Average 1: 0.6435088540648778
Average 5: 0.8512669335925249
Average 10: 0.89962887419386
# Out:
# 0.0817266315636614

# %%
top5s
# Out:
# [0.8445475638051044,
#  0.7709090909090909,
#  0.87893864013267,
#  0.6646341463414634,
#  0.896551724137931,
#  0.9230769230769231,
#  0.9714285714285714,
#  0.96,
#  0.916083916083916,
#  0.9354838709677419,
#  0.9279279279279279,
#  0.8571428571428571,
#  1.0,
#  0.8461538461538461,
#  0.8596491228070176,
#  0.9740740740740741,
#  0.9069069069069069,
#  0.96875,
#  1.0,
#  1.0,
#  0.9236641221374046,
#  0.755,
#  0.743421052631579,
#  0.8114035087719298,
#  0.8837209302325582,
#  0.5433526011560693,
#  0.7364620938628159,
#  0.7356020942408377,
#  0.7601476014760148,
#  0.8210526315789474,
#  0.8368794326241135,
#  0.8498233215547704,
#  0.8206896551724138,
#  0.8235294117647058,
#  0.8493150684931506,
#  0.7023498694516971,
#  0.8670634920634921,
#  0.7824074074074074]
